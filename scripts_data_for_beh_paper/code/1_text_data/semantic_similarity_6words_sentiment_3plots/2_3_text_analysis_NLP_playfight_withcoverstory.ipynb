# %%
# !pip install sentence-transformers
from sentence_transformers import SentenceTransformer, util

# %%
# Initialize the model
NLPmodel = SentenceTransformer('./sentence-transformers_all-MiniLM-L6-v2') # SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ## Use our data

# %%
# import other packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
param_name = 'playfight'

# %%
expt_type = 'playfight/with_cover_story/'
rootfile_loc = f'../../data/text_responses/{expt_type}'

# %%
df =  pd.read_csv(f'{rootfile_loc}/data_triallevel_sorted.csv',index_col=[0])
# df =  pd.read_csv('../data/collected_data/data_triallevel_sorted.csv',index_col=[0])
df.head()
# Out:
#    subID  stimset_rows  chargeSpeeds  \
# 6  24093            10           1.5
# 6  24066            59           1.5
# 6  24067            90           1.5
# 5  24068            57           1.5
# 4  24069            42           1.5
#
#                                     responses  \
# 6                          They are peaceful
# 6  Slowly coming together to bump each other.
# 6                     Bumping into each other
# 5                    They are kicking a ball.
# 4                             playing frisbee
#
#                                   movie  trial_num
# 6  29e7c94f-a6bf-4f1d-8ea1-46efbdb6a836          6
# 6  1a8cf3c1-690b-449c-bb36-fd3b251837c1          6
# 6  e838dadb-c02f-4273-ae93-210720dcd06c          6
# 5  31e1789e-459a-4f3d-bfdd-2f4c8c4e9f50          5
# 4  8ed7c0fc-1490-4e35-a000-7f7357a0772a          4

# %% [markdown]
# ## NLP algo

# %%
words_to_compare = df['responses'].to_list()
words_to_compare = [s.lower() for s in words_to_compare]
words_to_compare
# Out:
# ['they are peaceful ',
#  'slowly coming together to bump each other.',
#  'bumping into each other',
#  'they are kicking a ball.',
#  'playing frisbee',
#  'playing with each other',
#  'the dots were slowly drifting together and apart in a repetitive way',
#  'synchronised dancing',
#  'playing together ',
#  'interacting with each other by playing',
#  'charging',
#  'they were playing a game together',
#  'playing independently near each other',
#  'clashing',
#  'running around',
#  'slowly moving and touching one another',
#  'chase',
#  'playing a game',
#  'catch with a ball',
#  'playing',
#  'running',
#  'running around the park',
#  'dancing',
#  'playing red rover',
#  'playing catch',
#  'running toward each other',
#  'just running around',
#  'moving much slower around',
#  'interacting or bumping into each other',
#  'mirroring one another',
#  'talking and exploring the park',
#  'playing and handing each other objects',
#  'running back and forth like a relay race',
#  'the dots were gently bumping into each other repeatedly, much gentler than before',
#  'running and finding each other',
#  'running around and seeing each other',
#  'tag',
#  'running around ',
#  'the dots move randomly and then slowly collide or connect with each other.',
#  'the dots were coming together in a more friendly was',
#  'moving forward and backward',
#  'moving nw and slowly meeting',
#  'hugging',
#  'meeting and bouncing',
#  'engaging in a playful dance',
#  'bumping',
#  'hugging',
#  'tag',
#  'aimlessly running around',
#  'mirroring each other',
#  'hugging',
#  'high five',
#  'coming together softly',
#  'gently tapping.',
#  'playing football',
#  'playing around',
#  'handing a ball off back and forth',
#  'walking around',
#  'tag',
#  'playing catch',
#  'repelling',
#  'walking around before getting called to walk and meet in a centre point.',
#  'high fiving each other',
#  'playing tag',
#  'all the dots came together slowly',
#  'really lethargic, once contact is made the dots slowly remove themselves.',
#  'playing independently then making contact',
#  'pick a ball and drop on the same spot',
#  'dancing',
#  'walking',
#  'the dots were moving to and fro.',
#  'greeting each other',
#  'wrestling',
#  'moving in slow circles before slowly approaching each other',
#  'meeting',
#  'smooth fight',
#  'going to the movies',
#  'coping each other',
#  'they are playing musical chairs',
#  'coming together and then apart and then together again. playing i reckon',
#  'same game slower pace',
#  'interacting in a respectful manner',
#  'team',
#  'dancing',
#  'playing tag',
#  'playing',
#  'playing',
#  'the kids were sharing a toy',
#  'running around',
#  'play fighting, walking around and then attacking',
#  'walking around',
#  'they are calmer this time. i would say they are playing together.',
#  'they collided with each other',
#  'tag',
#  'fencing',
#  'the dots were colliding, then moving in opposite directions, then colliding again',
#  'dancing',
#  'slowly touched each other ',
#  'looking for something and checking with each other',
#  'playing',
#  'playing',
#  'the dots were playing ball',
#  'coming together then moving apart',
#  'bouncing off each other',
#  'the dots were moving to and fro.',
#  'same as before, maybe tag game',
#  'high fiving',
#  'basketball',
#  'the dots were playing',
#  'walking around before 1 dot would start moving to a centre point with the other dot reacting and trying to beat the first dot to the centre',
#  'somehow slowly approached one another',
#  'clicking from side to side',
#  'playing tag',
#  'hugging',
#  'going down a slide',
#  'they keep knocking into each other.',
#  'playing ball',
#  'enjoying the spacious environment',
#  'tag',
#  'walking around and seeking each other',
#  'the dots circle each other and then collide together.',
#  'running to each other',
#  'playing tag',
#  'they were going very slow and then they crashed',
#  'wanting to interactive with each other, and does, but hesitantly',
#  'playing hide and seek ',
#  'hugging',
#  'perhaps playing a game',
#  'going around in a circle touching for a short time',
#  'playing tag',
#  'playing',
#  'chasing ',
#  'playing tag',
#  'running',
#  'playing catch',
#  'running',
#  'run-up high-fiving',
#  'walking and touching',
#  'playing',
#  'playing hide and seek',
#  'chasing a dragonfly',
#  'playing',
#  'fighting',
#  'playing hide and seek',
#  'just playing',
#  'swings',
#  'playing  tag',
#  'playing mostly independantly',
#  'bouncing ',
#  'playing',
#  'playing tag',
#  'playing',
#  'enjoying the surroundings',
#  'meeting',
#  'playing tag',
#  'colliding',
#  'bumping together',
#  'they were moving apart before coming back together and appearing to strike each other',
#  'passing something to each other',
#  'this one is football. when the ball comes close, they come together and when the bass is not they more apart.',
#  'they are playing tag.',
#  'playing tag',
#  'wandering around',
#  'playing tag',
#  "riding in 'bumper' cars",
#  'lackadaisical in manner, less violent.  ',
#  'swinging ',
#  'bump run around and play',
#  'the dots hit them selves twice',
#  'running alongside one another than colliding',
#  'fighting',
#  'running',
#  'playing chase',
#  'running around',
#  'playing',
#  'grey dot at a distance and then coming up to the black dot to be bounced back',
#  'tagging each other',
#  'playing',
#  'moving around then coming together',
#  'the kids were playing a game',
#  'playing a game',
#  'dancing',
#  'playing, running into each other',
#  'circling and coming together',
#  'playing tag',
#  'playful mood',
#  'marco polo',
#  'grey dot was encouraging the other dot to make contact',
#  'running into each other',
#  'playing',
#  'running round park',
#  'saying hello to each other',
#  'they are gently approaching each other.',
#  'colliding',
#  'playing tag',
#  'circling then coming together',
#  'playing',
#  'moving around interacting bumping and playing',
#  'running back and forth',
#  'tagging',
#  'walking around the park',
#  'playing football',
#  'running around ',
#  'seems like they may be fighting or running at each other',
#  'going in the opposite direction to each other  ',
#  'moving around and slowly going towards each other ',
#  'hide and seek',
#  'tackling each other',
#  'something between chicken and self play',
#  'playing a game',
#  'playing tag',
#  "the grey dot appear to be running or approaching the other dot with speed. the black dot didn't move as much",
#  'circling',
#  'whoever touches each other first ',
#  'running away and towards each other',
#  'aloof and then confronting each other',
#  'bumping together ',
#  'running around then high fiving each other',
#  'playing a game',
#  'fighting',
#  'fighting',
#  'fighting',
#  'they are playing a game.',
#  'butting heads',
#  'playing with pets',
#  'playing tag',
#  'bumping into each other',
#  'hide and seek',
#  'playing catch',
#  'games',
#  'moving apart from each other then came back together twice',
#  'pushing each other for fun',
#  'running around ',
#  'running in circles then bumping in to each other ',
#  'catching up',
#  'they are running',
#  'walking around',
#  'fighting',
#  'the dots were moving to and fro.',
#  'run and touch game',
#  'they seemed attracted to one another',
#  'shared in some moments',
#  'they are cautiously moving then meeting each other in the middle.',
#  'walking or jogging around before rushing to a centre point.',
#  'does it represent bullying maybe? dark dot wont leave grey dot alone',
#  'they attracted each other to slowly collide',
#  'running',
#  'playing',
#  'collision (fighting)',
#  'the dots are dancing',
#  'playing a game',
#  'notiing each other and playing',
#  'slow and lethargic, but still headbutting in a seeking manner.',
#  'running towards each other',
#  'playing, running into each other',
#  'playing soccer',
#  'tag',
#  'running into each other',
#  'running around',
#  'they were chasing each other',
#  'purposely running into each other ',
#  'grey was more aggresive and catching up to the black dot and bouncing off them',
#  'hide and seek',
#  'chasing the other',
#  'the kids crossed path while roaming around',
#  'seems that they are attracted to each other?',
#  'connecting each other.',
#  'playing',
#  'grey dot was hassling the black dot',
#  'dancing',
#  'swimming',
#  'dont know',
#  'the dots moves around and later then they came together',
#  'playing apart and then joining eachother again',
#  'playing frog leap',
#  'playing ',
#  'moving up and down and hitting each other',
#  'playing a sword game',
#  'before slowly touching each other, move counterclockwise ',
#  'flowing',
#  'playing tag together',
#  'they were playing with each other',
#  'running back and forth into each other ',
#  'the grey dot has the higher power but the black dot kept doing after the grey dot.',
#  'swings',
#  'hide and seek',
#  'playing football',
#  'slowly moving, coming together and then splitting apart',
#  'playing tag',
#  'running',
#  'swordfighting',
#  'the dots are playing',
#  'fighting',
#  'the dots move away from each other and then collide. the grey dot seemed to instigate the collision.',
#  'running and tagging ',
#  'hide and seek',
#  'the dots were running into each other',
#  'playing tag ',
#  'fighting perhaps?',
#  'skateboarding',
#  'politely taking turns initiating the interaction ',
#  'hiding/walking around and play fighting eachother',
#  'colliding with each other',
#  'fighting ',
#  'playing',
#  'fighting',
#  'moving apart then clicking together again',
#  'playing video games',
#  'one chasing the other maybe',
#  'charging each other.',
#  'they got lower, knocking into each other.',
#  'attacking each other, fighting',
#  'coming together for a short time and then away from each other',
#  'running into each other ',
#  'pushing',
#  'getting tired of fighting.',
#  'it seems they are still fighting? ',
#  'chasing each other',
#  'playing',
#  'the grey one seemed to be pursuing the black dot',
#  'running at each other ',
#  'tag',
#  'they were running round',
#  'testing boundaries',
#  'play fighting',
#  'playing',
#  'the dots were colliding into each other when they got close',
#  'playing tag',
#  'they are running around and up to each other.',
#  'the dots were hitting each other',
#  'running',
#  'walk around and take it in turns to try and creep up on the other dot before they realise.',
#  'children',
#  'running and bumping',
#  'the grey dot follows the black dot and then sudden speed up. when it gets close to the black dot, the black then moves toward the grey dot causing them to collide.',
#  'chasing',
#  'playing tag.',
#  'tagging each other',
#  'tagging each other',
#  'playing',
#  'fighting',
#  'hide and seek',
#  'the dots were drifting, then first the grey approached the black fast, then they drifted again and then the black approached the grey fast.',
#  'bump run around play ',
#  'playing soccer',
#  'moved slowly before quickly striking each other',
#  'meandering then rushing together',
#  'they are playing soccer.',
#  'playing tag ',
#  'attracting towards each other',
#  'walking ',
#  'one child was following another',
#  'bouncing into each other',
#  'playing a wrestling game',
#  'crashing into each other',
#  'fighting',
#  'at this stage the white dot move to where the black dot is and later they meet together',
#  'fighting',
#  'running',
#  'they had two small approaches',
#  'tap and run',
#  'coming together',
#  'fighting',
#  'again, seems that they are running at each other and maybe fighting',
#  'playing a game running then coming together at intervals',
#  'calculated and with motive. ',
#  'move clockwise before slowly touching each other ',
#  'chasing one another',
#  'hitting ',
#  'football',
#  'fighting',
#  'play fighting ',
#  'jumping',
#  'i would say they were fighting, the coming together seemed more aggressive',
#  'skating ',
#  'wrestling',
#  'playing',
#  'hide and seek',
#  "pretending they're magnets",
#  'playing tag',
#  'the dots were running around and then hitting into each other',
#  'fighting',
#  'football',
#  'attract to collide slowly',
#  'racing',
#  'running then colliding',
#  'rough',
#  'playing',
#  'hide and seek',
#  'playing with a ball',
#  'running too and fro',
#  'playing tag',
#  'bouncing ',
#  'running around',
#  'doing in rhythm',
#  'charging at each other',
#  'colliding ',
#  'running at each other',
#  'playing musical chairs',
#  'fighting',
#  'playing tag',
#  'the dots are fighting',
#  'the dots collided with one another.',
#  'sprinting',
#  'charging at each other',
#  'chasing each other',
#  'running',
#  'the dots were repeatedly colliding into each other',
#  'slowly moving around and touching',
#  'red rover',
#  'fun mode',
#  'running at each other ',
#  'the kids were shoving each other',
#  'fighting',
#  'going left and right',
#  'collecting items and bringing them back to a pile',
#  'smashing into one another',
#  'dancing',
#  'running',
#  'joining together',
#  'all the dots came together like magnet ',
#  'runnign in circles then contact',
#  'the dots were dueling, sort of seeking each other out and headbutting when a certain distance was achieved. ',
#  'running and then hitting each other',
#  'playing soccer ',
#  'they were playing tag, not sure why when the person was not it went towards them when they got close though.',
#  'hiding and finding each other',
#  'dueling',
#  'racing',
#  'playing',
#  'jumping',
#  'playing tag',
#  'chasing',
#  'playing frisbee',
#  "the black dot slowly closed in on the grey dot, and which it got close the grey dot 'attacked' it.",
#  'playing tag',
#  'dancing',
#  'moved in a semicircle before striking each other',
#  'they were both bumping into each other, but one seems more aggressive than the other',
#  'being aggressive',
#  'running towards eachother',
#  'running to and from eachother',
#  'fighting',
#  'hiding and, running and bumping each other',
#  'avoid then collide',
#  'this one seems to be fighting again. they are trying to fend off each other.',
#  'playing tag',
#  'playing football',
#  'testing boundaries ',
#  'running and bumping into each other.',
#  'dots where bumping into each other',
#  'running around',
#  'fighting ',
#  'c ircling then coming together repeatedly',
#  'touching bodies',
#  'running from a small distance to come together then move apart again',
#  'playing',
#  'playing tag',
#  'playing around',
#  'react to a whistle or alarm to then rush to a point in the middle of both dots.',
#  'charging at each other',
#  'children may have been playing tag together',
#  'playing football',
#  'on a swing',
#  'running',
#  'walking ',
#  'they are running and chasing each other.',
#  'the black dot seemed to be pursuing the grey dot',
#  'running and colliding',
#  'tag',
#  'small circles to then brake and collide with each other',
#  'playing catch',
#  'attracting',
#  'bullying',
#  'bouncing',
#  'tackling',
#  'boxing',
#  'they are running into each other and bumping off each other playfully.',
#  'dancing',
#  'smashing into each other',
#  'fighting',
#  'calling each other to explore the park',
#  'fighting',
#  'the black dot has the higher ground, knocking into the grey dot.',
#  'trying to avoid each other then chasing',
#  'high fiving',
#  'quickly running at each other',
#  'running',
#  'fighting',
#  'fighting',
#  'running at each other, bouncing',
#  'play fighting',
#  'perhaps playing a game, but most likely running at each other or fighting',
#  'running',
#  'move apart then meet again',
#  'chasing',
#  'playing',
#  'running',
#  'chasing',
#  'jousting',
#  'in this situation two small confrontations occurred',
#  'swings',
#  'fighting',
#  'running',
#  'racing',
#  'playing',
#  'running',
#  'moved in circles before coming together ',
#  'equal leading',
#  'tag',
#  'hitting',
#  'playing tag together',
#  'colliding',
#  'charging each other',
#  "mirroring each other's movements then colliding",
#  'they made small circles and then got closer to collide faster.',
#  'running to and from each other ',
#  'the dots were colliding into each other repeatedly',
#  'exploring the talking',
#  'fighting',
#  'little aggressive',
#  'pushing each other',
#  'playing tag',
#  'walking and running',
#  'running away from each other then running back',
#  'collision (fighting)',
#  'similar to the last one, but to me it seemed like the white dot was seeking out the black one and initiating contact. ',
#  'fighting',
#  'tackling',
#  'clapping hands',
#  'playing',
#  'crashing into each other',
#  'all the two dots came together ',
#  'playing',
#  'running at each other',
#  'running around then seeing each other and saying hi',
#  'playing ',
#  'they were running',
#  'encouraging each other to enjoy the space',
#  'playing a game of it or rugby',
#  'dont know',
#  'rugby, there was a ball fumble halfway through',
#  'playing tag',
#  'running into each other',
#  'circling then coming together',
#  'play fighting',
#  'discussing',
#  'playing some sort of game',
#  'fighting',
#  'the dots seem to move randomly and then attack each other. ',
#  'playing',
#  'they are staying apart and then colliding.',
#  'fighting ',
#  'playing a game',
#  'the dots collided with one another.',
#  'bump and play',
#  'the two were moving around and there were a few moments where they got close to each other ',
#  'clashing',
#  'grey dot aggressively running into black dot',
#  'shoving ',
#  'bumping',
#  'role playing game',
#  'playing chicken (again?)',
#  'playing tag',
#  'wander and smash',
#  'the dots are hitting themselves in an unfriendly manner',
#  'fighting',
#  'fighting',
#  'playing rugby',
#  'moving at the center and clapping together',
#  'touch each other and seperate',
#  'perhaps playing a game, but seems they are running at each other',
#  'hitting one another occasionally ',
#  'arguing',
#  'attacking each other',
#  'they were bumping into each other and rebounding',
#  'playing tag',
#  'dodging touches',
#  'walk around in a circle before rushing to a centre point once told to.',
#  'the dots drifted around slowing, then running together. they did this a couple of times. perhaps passing something between them',
#  'both child were playing tag',
#  'it seems they are colliding to each other? or they are fighting?',
#  'running into each other',
#  'the black dot kept going after the grey dot.',
#  'fighting',
#  'push and pull',
#  'swinging towards each other',
#  'charging to bump into each other.',
#  'playing tag',
#  'flirting',
#  'same game different speed',
#  'swinging into each other',
#  'playing',
#  'running',
#  "looks like dueling, watching each other's moves",
#  'football',
#  'pretending to be bumper cars',
#  'pushing another on a swing',
#  'they are chasing each other.',
#  'going on a swing',
#  'actively hit each other then took a step back ',
#  'walking around',
#  'playing football',
#  'hit and run away.',
#  'they separated slowly and collided with each other very quickly.',
#  'running',
#  'fighting',
#  'fighting',
#  'running quickly towards each other ',
#  'running towards each other',
#  'hit against one another ',
#  'the dots are running into each other and colliding. ',
#  'the dots collided with one another.',
#  'dancing',
#  'running and tagging themselves',
#  'swordfighting',
#  'moving around in a circle and then rushing to a centre point to touch or grab something first before the other did.',
#  'playing solo then coming together',
#  'play fighting',
#  'running and hugging',
#  'at certain times they clashed',
#  'colliding',
#  'fighting',
#  'fighting',
#  'seesaw',
#  'fighting',
#  'they are running and playing tag.',
#  'playing flag football',
#  'fighting each other',
#  'wandering then coming together',
#  'the dots were moving slowly in small motions then quickly coming together. like some sort of dance',
#  'boxing',
#  'running for a while and touching each other afterwards',
#  'crashing ',
#  'bumping into each other ',
#  'running',
#  'clashing',
#  'playing chicken (running at each other to see who bails first)',
#  'tackling',
#  'play fighting',
#  'running and charging each other.',
#  'perhaps playing a game',
#  'fighting or clashing over something',
#  'they are having dispute',
#  'swings',
#  'body slamming',
#  'play fight',
#  'swinging',
#  'playing tag',
#  'soccer',
#  'coming together repeatedely',
#  'playing it',
#  'violently crashing',
#  'playing',
#  'playing around in the park',
#  'tackling each other',
#  'playing on equipment',
#  'trying to find each other',
#  'colliding',
#  'bouncing off each other ',
#  'basketball',
#  'the grey dot seems to be going after the black dot.',
#  'running away and coming together',
#  'seem to be playing tag',
#  'moving around and forcefully hitting',
#  'running around and bumping in to each other',
#  'playing',
#  'the kids were bumping into each other',
#  'jousting',
#  'aggressively charging at each other',
#  'the black dot was coming at the grey dot quickly',
#  'hanging out',
#  'hide and seek',
#  'the dots were moving around and it themselves twice ',
#  'black dot was faster, sort of seeking the white dot to initiate contact. ',
#  'colliding into each other',
#  'hide and go seek',
#  'running around the park and then coming back to each other frequently',
#  'running towards each other',
#  'football?',
#  'the dots were running into each other when they got close',
#  'slowly moved then sped up to strike each other',
#  'they are colliding to each other.',
#  'chasing',
#  'using the same playground equipment',
#  'chasing after something thrown for them',
#  'moving around and meeting at a point',
#  'running into each other',
#  'the dots were playing together',
#  'scavenger hunt',
#  'playing tag',
#  'chasing',
#  'aggressively running into each other',
#  'touching',
#  'running at each other',
#  'fighting',
#  'kickball',
#  'fighting',
#  'running around',
#  'playing football',
#  'there were circling each other and then ran towards each other.',
#  'playing pretend',
#  'running into each other, but it was as if they planned when to',
#  'wrestling',
#  'they were circling around one another and occassionally meeting in middle']

# %%
# ref_words = ['follow','chase','wander','move','independent', 'moveInd']
ref_words = ['play','fight','wander','move','independent','play_fight']

# %%
# Encode the reference phrase and the words to compare

similarity_all_1 = []
similarity_all_2= []
similarity_all_3= []
similarity_all_4 = []
similarity_all_5 = []

for ref_word in ref_words[:-1]:

    # if ref_word == 'play_fight':
    #     continue
    # else:
    reference_embedding = NLPmodel.encode(ref_word)

    data_embeddings = NLPmodel.encode(words_to_compare)

    # Compare and print similarities
    for embedding in data_embeddings:

        similarity = util.pytorch_cos_sim(reference_embedding, embedding) # similarity between ref word and each response
        
        if ref_word in ['play','playing']:
            similarity_all_1.append(similarity.item())

        if ref_word in ['fight','fighting']:
            similarity_all_2.append(similarity.item())
        
        if ref_word in ['wander','wandering']:
            similarity_all_3.append(similarity.item())
        
        if ref_word in ['move','moving']:
            similarity_all_4.append(similarity.item())

        if ref_word in ['independent','independently']:
            similarity_all_5.append(similarity.item())

df['similarity_play'] = similarity_all_1
df['similarity_fight'] = similarity_all_2
df['similarity_wander'] = similarity_all_3
df['similarity_move'] = similarity_all_4
df['similarity_independent'] = similarity_all_5
df['similarity_play_fight'] = df['similarity_play'] - df['similarity_fight']

# %%
df.rename(columns = {'chargeSpeeds':'chargeSpeed'},inplace=True)
df.sort_values(by=['chargeSpeed','subID'],inplace=True)
df
# Out:
#     subID  stimset_rows  chargeSpeed                            responses  \
# 6   24000            22          1.5                              playing
# 6   24001             5          1.5                              dancing
# 5   24003            85          1.5             aimlessly running around
# 3   24004            88          1.5                              bumping
# 6   24005            27          1.5         moving NW and slowly meeting
# ..    ...           ...          ...                                  ...
# 2   24097            84          9.0                            wrestling
# 4   24098            41          9.0  Using the same playground equipment
# 6   24099            86          9.0    They are colliding to each other.
# 1   24100            71          9.0                              playing
# 6   24101            82          9.0                             Jousting
#
#                                    movie  trial_num  similarity_play  \
# 6   81e3fe3f-5a7c-42d3-8ea7-c2bf3831288b          6         0.887281
# 6   b3a507ff-2289-4ad3-8922-1a3d0532e154          6         0.376770
# 5   1b1159fc-de2b-4ae5-a736-d98d8524a366          5         0.326775
# 3   38ad4b16-44e2-4e52-8d02-b23eca73a48d          3         0.252325
# 6   8ed7c0fc-1490-4e35-a000-7f7357a0772a          6         0.173475
# ..                                   ...        ...              ...
# 2   a5228b86-ba0a-42f2-aa38-23b5369f0e56          2         0.246261
# 4   7d40f846-95bc-4c08-b7a1-b4a410852b77          4         0.287940
# 6   6e2932f2-a9d1-4f2a-9599-a872b605c1eb          6         0.252616
# 1   7a2ccf3c-feb4-4b5c-9c03-44c10f774f9a          1         0.887281
# 6   8649b489-429a-4894-9c74-827e94f04566          6         0.298483
#
#     similarity_fight  similarity_wander  similarity_move  \
# 6           0.454840           0.314943         0.369590
# 6           0.333683           0.391984         0.389090
# 5           0.266552           0.378598         0.330485
# 3           0.317343           0.222343         0.293224
# 6           0.173423           0.362493         0.490650
# ..               ...                ...              ...
# 2           0.509682           0.169802         0.299607
# 4           0.052704           0.070623         0.128253
# 6           0.361161           0.033999         0.164491
# 1           0.454840           0.314943         0.369590
# 6           0.403831           0.251309         0.238222
#
#     similarity_independent  similarity_play_fight
# 6                 0.308837               0.432441
# 6                 0.240716               0.043087
# 5                 0.285862               0.060223
# 3                 0.171986              -0.065019
# 6                 0.063473               0.000052
# ..                     ...                    ...
# 2                 0.174845              -0.263420
# 4                 0.088960               0.235236
# 6                 0.111029              -0.108545
# 1                 0.308837               0.432441
# 6                 0.133385              -0.105347
#
# [705 rows x 12 columns]

# %%
rootfile_loc
# Out:
# '../../data/text_responses/playfight/with_cover_story/'

# %%
df.to_csv(f'{rootfile_loc}NLP_analyses/data_with_similarity_scores.csv')

# %% [markdown]
# # Figures

# %%
import matplotlib.pyplot as plt
import seaborn as sns

s=14 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=14) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

color_plots = 'tab:red' # or tab:red

# %%
inds = [[0,0],[0,1],[1,0],[1,1],[1,2],[0,2]]
words_pos_dict = dict(zip(ref_words,inds))
words_pos_dict
# Out:
# {'play': [0, 0],
#  'fight': [0, 1],
#  'wander': [1, 0],
#  'move': [1, 1],
#  'independent': [1, 2],
#  'play_fight': [0, 2]}

# %%
out_loc = '../../results/text_analysis/pf/with_cover_story/'

# %%
param_name = 'chargeSpeed'

# %%
nrows,ncols = 2,3
fig,axs = plt.subplots(nrows = 2, ncols = 3, figsize = (12,6), sharey = False)

for i,word in enumerate(ref_words):
    r,c = words_pos_dict[word]
    ax = axs[r,c]
    sns.regplot(data=df.groupby([param_name]).mean().reset_index(),x = param_name,y = 'similarity_' + word,\
        ax=ax,marker = 'o', color = color_plots)
    ax.set_xticks(np.unique(df[param_name]))
    if word != 'play_fight':
        ax.set_title(f'"{word}" similarity', fontweight = 'bold')
        ax.set_yticks([0.1,0.2,0.3,0.4,.5])
    else:
        ax.set_title(f'"play" similarity -\n"fight" similarity', fontweight = 'bold')
        ax.hlines(0,1.5,9,color = 'grey',ls = ':',alpha=.4)
        ax.set_yticks([-.2,-.1,0,0.1,0.2])
    if c ==0:
        ax.set_ylabel('similarity score')
    else:
        if (r==0) & (c==2):
            ax.set_ylabel('More similar to\nfight <-----> play')
        else:
            ax.set_ylabel('')
    
    if r == 0:
        ax.set_xlabel('')
    
    ax.set_xticks(np.arange(1.5,9.1,1.25),['1.5','2.75','4','5.25','6.5','7.75','9'])
    ax.invert_xaxis()

plt.tight_layout()
plt.savefig(f'{out_loc}word_similarity.png',dpi=300,bbox_inches ='tight')

# %% [markdown]
# ### Stat + plots

# %%
from pymer4.models import Lmer
from pymer4.stats import vif
from scipy.stats import zscore
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
df['chargeSpeed'] = zscore(df['chargeSpeed'])
df
# Out:
#     subID  stimset_rows  chargeSpeed                            responses  \
# 6   24000            22    -1.531702                              playing
# 6   24001             5    -1.531702                              dancing
# 5   24003            85    -1.531702             aimlessly running around
# 3   24004            88    -1.531702                              bumping
# 6   24005            27    -1.531702         moving NW and slowly meeting
# ..    ...           ...          ...                                  ...
# 2   24097            84     1.493088                            wrestling
# 4   24098            41     1.493088  Using the same playground equipment
# 6   24099            86     1.493088    They are colliding to each other.
# 1   24100            71     1.493088                              playing
# 6   24101            82     1.493088                             Jousting
#
#                                    movie  trial_num  similarity_play  \
# 6   81e3fe3f-5a7c-42d3-8ea7-c2bf3831288b          6         0.887281
# 6   b3a507ff-2289-4ad3-8922-1a3d0532e154          6         0.376770
# 5   1b1159fc-de2b-4ae5-a736-d98d8524a366          5         0.326775
# 3   38ad4b16-44e2-4e52-8d02-b23eca73a48d          3         0.252325
# 6   8ed7c0fc-1490-4e35-a000-7f7357a0772a          6         0.173475
# ..                                   ...        ...              ...
# 2   a5228b86-ba0a-42f2-aa38-23b5369f0e56          2         0.246261
# 4   7d40f846-95bc-4c08-b7a1-b4a410852b77          4         0.287940
# 6   6e2932f2-a9d1-4f2a-9599-a872b605c1eb          6         0.252616
# 1   7a2ccf3c-feb4-4b5c-9c03-44c10f774f9a          1         0.887281
# 6   8649b489-429a-4894-9c74-827e94f04566          6         0.298483
#
#     similarity_fight  similarity_wander  similarity_move  \
# 6           0.454840           0.314943         0.369590
# 6           0.333683           0.391984         0.389090
# 5           0.266552           0.378598         0.330485
# 3           0.317343           0.222343         0.293224
# 6           0.173423           0.362493         0.490650
# ..               ...                ...              ...
# 2           0.509682           0.169802         0.299607
# 4           0.052704           0.070623         0.128253
# 6           0.361161           0.033999         0.164491
# 1           0.454840           0.314943         0.369590
# 6           0.403831           0.251309         0.238222
#
#     similarity_independent  similarity_play_fight
# 6                 0.308837               0.432441
# 6                 0.240716               0.043087
# 5                 0.285862               0.060223
# 3                 0.171986              -0.065019
# 6                 0.063473               0.000052
# ..                     ...                    ...
# 2                 0.174845              -0.263420
# 4                 0.088960               0.235236
# 6                 0.111029              -0.108545
# 1                 0.308837               0.432441
# 6                 0.133385              -0.105347
#
# [705 rows x 12 columns]

# %%
ref_words
# Out:
# ['play', 'fight', 'wander', 'move', 'independent', 'play_fight']

# %%
model = Lmer(f'similarity_{ref_words[0]} ~ chargeSpeed +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# boundary (singular) fit: see ?isSingular
#
# Formula: similarity_play~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'movie': 140.0, 'subID': 102.0}
#
# Log-likelihood: 206.444 	 AIC: -412.888
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.000
# subID     (Intercept)  0.011  0.104
# Residual               0.026  0.162
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.360   0.336    0.383  0.012  101.159  30.051  0.000  ***
# chargeSpeed    -0.009  -0.021    0.003  0.006  603.687  -1.446  0.149

# %%
model = Lmer(f'similarity_{ref_words[0]} ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: similarity_play~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 206.444 	 AIC: -412.888
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.011  0.104
# Residual               0.026  0.162
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.360   0.336    0.383  0.012  101.159  30.051  0.000  ***
# chargeSpeed    -0.009  -0.021    0.003  0.006  603.687  -1.446  0.149

# %%
model = Lmer(f'similarity_{ref_words[1]} ~ chargeSpeed +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: similarity_fight~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'movie': 140.0, 'subID': 102.0}
#
# Log-likelihood: 236.083 	 AIC: -472.166
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.011
# subID     (Intercept)  0.008  0.089
# Residual               0.025  0.157
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.326   0.305    0.347  0.011   95.684  30.506    0.0  ***
# chargeSpeed     0.028   0.016    0.040  0.006  100.899   4.643    0.0  ***

# %%
model = Lmer(f'similarity_{ref_words[1]} ~ chargeSpeed +  (1|subID) ', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: similarity_fight~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 236.067 	 AIC: -472.134
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.008  0.089
# Residual               0.025  0.158
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.326   0.305    0.347  0.011  101.434  30.603    0.0  ***
# chargeSpeed     0.028   0.016    0.039  0.006  604.224   4.687    0.0  ***

# %%
model = Lmer(f'similarity_{ref_words[2]} ~ chargeSpeed  +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: similarity_wander~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'movie': 140.0, 'subID': 102.0}
#
# Log-likelihood: 560.114 	 AIC: -1120.228
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.011
# subID     (Intercept)  0.005  0.067
# Residual               0.009  0.097
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.228   0.213    0.243  0.008   98.391  29.764  0.000  ***
# chargeSpeed    -0.009  -0.017   -0.002  0.004  101.556  -2.451  0.016    *

# %%
model = Lmer(f'similarity_{ref_words[2]} ~ chargeSpeed  +  (1|subID) ', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: similarity_wander~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 560.009 	 AIC: -1120.018
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.005  0.067
# Residual               0.009  0.097
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.228   0.213    0.243  0.008  100.776  29.974  0.000  ***
# chargeSpeed    -0.009  -0.016   -0.002  0.004  603.142  -2.501  0.013    *

# %%
model = Lmer(f'similarity_{ref_words[2]} ~ chargeSpeed  +  (1|subID)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: similarity_wander~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 560.009 	 AIC: -1120.018
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.005  0.067
# Residual               0.009  0.097
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.228   0.213    0.243  0.008  100.776  29.974  0.000  ***
# chargeSpeed    -0.009  -0.016   -0.002  0.004  603.142  -2.501  0.013    *

# %%
model = Lmer(f'similarity_{ref_words[3]} ~ chargeSpeed +  (1|subID) + (1|movie) ', data=df) # ff: anglesm rfx: subject ID # + (1|movie)
model.fit()
# Out:
# boundary (singular) fit: see ?isSingular
#
# Formula: similarity_move~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'movie': 140.0, 'subID': 102.0}
#
# Log-likelihood: 740.680 	 AIC: -1481.361
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.000
# subID     (Intercept)  0.003  0.053
# Residual               0.006  0.075
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.275   0.263    0.286  0.006  101.08  46.101  0.000  ***
# chargeSpeed    -0.004  -0.010    0.001  0.003  603.41  -1.488  0.137

# %%
model = Lmer(f'similarity_{ref_words[3]} ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID # + (1|movie)
model.fit()
# Out:
# Formula: similarity_move~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 740.680 	 AIC: -1481.361
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.003  0.053
# Residual               0.006  0.075
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.275   0.263    0.286  0.006  101.08  46.101  0.000  ***
# chargeSpeed    -0.004  -0.010    0.001  0.003  603.41  -1.488  0.137

# %%
model = Lmer(f'similarity_{ref_words[4]} ~ chargeSpeed +  (1|subID) + (1|movie) ', data=df) # ff: anglesm rfx: subject ID # + (1|movie)
model.fit()
# Out:
# Formula: similarity_independent~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'movie': 140.0, 'subID': 102.0}
#
# Log-likelihood: 893.721 	 AIC: -1787.441
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.006
# subID     (Intercept)  0.002  0.049
# Residual               0.003  0.059
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.166   0.155    0.176  0.005   98.339  30.971  0.000  ***
# chargeSpeed    -0.003  -0.007    0.002  0.002  114.848  -1.190  0.236

# %%
model = Lmer(f'similarity_{ref_words[4]} ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID # + (1|movie)
model.fit()
# Out:
# Formula: similarity_independent~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 893.648 	 AIC: -1787.296
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.002  0.049
# Residual               0.004  0.059
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.166   0.155    0.176  0.005  100.961  31.144  0.000  ***
# chargeSpeed    -0.003  -0.007    0.002  0.002  603.004  -1.226  0.221

# %%
model = Lmer(f'similarity_{ref_words[5]} ~ chargeSpeed +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID # + (1|movie)
model.fit()
# Out:
# Formula: similarity_play_fight~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'movie': 140.0, 'subID': 102.0}
#
# Log-likelihood: 93.476 	 AIC: -186.953
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.003  0.051
# subID     (Intercept)  0.005  0.071
# Residual               0.038  0.195
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.032   0.010    0.054  0.011  106.866   2.870  0.005   **
# chargeSpeed    -0.037  -0.053   -0.020  0.009  116.252  -4.278  0.000  ***

# %%
model = Lmer(f'similarity_{ref_words[5]} ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID # + (1|movie)
model.fit()
# Out:
# Formula: similarity_play_fight~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 705	 Groups: {'subID': 102.0}
#
# Log-likelihood: 91.128 	 AIC: -182.256
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.005  0.074
# Residual               0.040  0.201
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.033   0.013    0.054  0.011  101.693   3.176  0.002   **
# chargeSpeed    -0.037  -0.052   -0.022  0.008  605.553  -4.859  0.000  ***

# %% [markdown]
# ## data-driven approach

# %%
# import nltk
# # nltk.download('wordnet')

# from nltk.corpus import wordnet as wn

# # Retrieve all English lemmas in WordNet
# lemmas = wn.all_lemma_names(pos=wn.VERB)#NOUN)

# # Convert lemmas to a list
# english_words = list(lemmas)

# print(english_words[:100]), len(english_words)

# english_words = [i for i in english_words if '-' not in i]
# english_words = [i for i in english_words if '_' not in i]
# english_words_embedding = NLPmodel.encode(english_words)

# print(english_words_embedding.shape)

# df_words = pd.DataFrame({'words':english_words, 'word_len':[len(i) for i in english_words], 'embedding':english_words_embedding.tolist()})
# df_words

# %%
# df_words.shape

# %%
# words_to_compare = df['responses'].to_list()

# %%
# master_verb_list = df_words['words'].values
# master_verb_list = master_verb_list[~np.isin(master_verb_list, ['dot', 'black', 'grey', 'gray','blackball'])]
# master_embeddings = NLPmodel.encode(master_verb_list)#words_to_compare)

# representative_verb = []
# for i,reference_phrase in enumerate(words_to_compare): # participant responsesa
#     reference_embedding = NLPmodel.encode(reference_phrase)
#     all_similarity = []
#     for embedding in master_embeddings: # all english verbs' embeddings
#         similarity = util.pytorch_cos_sim(reference_embedding, embedding)
#         all_similarity.append(similarity.mean().item())
#     all_similarity = np.array(all_similarity)
#     # all_similarity = all_similarity[all_similarity not in ['dot','black','grey','gray']
#     words_to_compare = np.array(words_to_compare)
#     # word = words_to_compare[all_similarity == np.nanmax(all_similarity)]
#     word = master_verb_list[all_similarity == np.nanmax(all_similarity)]
#     representative_verb.append(word[0])
# df['representative_verb'] = representative_verb
# df.head()

# %%
# english_words_embedding = df_words['embedding'].values
# english_words =  df_words['words'].values

# %%
# excluded_words_list = ['dot','dots','grey','gray','black'] #'blacken','blackguard','blackball','blackleg','blacktop','blacklead','collide'] #['dot']
# # excluded_words_list.extend(['grey','gray','black'])
# excluded_words_list

# %%
# # word_embedding per chargeSpeed level - comparison to the whole

# mean_embedding = []
# for cspeed in np.unique(df['chargeSpeed']):
#     print(cspeed*7.5+1.5)
#     df_cspeed = df.loc[df['chargeSpeed']==cspeed,:]
#     words_to_compare = df_cspeed['responses'].to_list()
#     words_to_compare =  [s.lower() for s in words_to_compare]
#     mean_embedding_pf = NLPmodel.encode(words_to_compare)
#     mean_embedding_pf = np.nanmedian(mean_embedding_pf,axis=0) # np.nanmean(all_embeddings_currSpeed,axis=0)
#     # mean_embedding.append(mean_embedding_pf)

#     # for mean_embedding_curr in mean_embedding: # responses
#     mean_embedding_curr = mean_embedding_pf
#     # Compare and print similarities
#     # for word, embedding in zip(words_to_compare, word_embeddings):
#     all_similarity = []
#     for embedding in english_words_embedding: #english words
#         similarity = util.pytorch_cos_sim(mean_embedding_curr, embedding)
#         all_similarity.append(similarity.mean().item())
    
#     all_similarity = np.array(all_similarity)
    
#     # word = english_words[np.where(all_similarity == np.nanmax(all_similarity))[0][0]]
#     # print(f"most representative word: {word}")

#     df_temp = pd.DataFrame({'english_words':english_words, 'all_similarity':all_similarity})
#     df_temp = df_temp[~df_temp['english_words'].isin(excluded_words_list)]
#     df_temp = df_temp.reset_index()
#     df_temp.sort_values(by='all_similarity',inplace=True, ascending=False)
#     print(f"most representative words: {df_temp.iloc[:10,1].values}")
#     # take top 10 words

# %%
# # word_embedding per chargeSpeed level - comparison to the whole

# all_similarity = []
# for i in mean_embedding:
#     # Compare and print similarities
#     # for word, embedding in zip(words_to_compare, word_embeddings):

#     similarity_speed = []
#     for j in mean_embedding:
#         similarity_speed.append(util.pytorch_cos_sim(i, j).mean().item())

#     all_similarity.append(similarity_speed)

# all_similarity = np.array(all_similarity)
    
#     # word = english_words[np.where(all_similarity == np.nanmin(all_similarity))[0][0]]
#     # print(f"most representative word: {word}")
# sns.heatmap(all_similarity, cmap = 'RdBu_r',vmin = -1,vmax =1)

# %%
# # word_embedding per chargeSpeed level - comparison to the whole

# mean_embedding = []
# # for cspeed in np.unique(df['chargeSpeeds']):
# #     df_speed = df.loc[df['chargeSpeeds']==cspeed,:]
# # words_to_compare = df_speed['responses'].to_list()

# words_to_compare = df['responses'].to_list()
# words_to_compare =  [s.lower() for s in words_to_compare]
# all_embeddings = model.encode(words_to_compare)

# all_similarity = []
# for i in all_embeddings:
#     # Compare and print similarities
#     # for word, embedding in zip(words_to_compare, word_embeddings):
#     all_similarity_i = []
#     for j in all_embeddings:
#         similarity = util.pytorch_cos_sim(i, j)
#         all_similarity_i.append(similarity.median().item())
#     all_similarity.append(all_similarity_i)

# all_similarity = np.array(all_similarity)
