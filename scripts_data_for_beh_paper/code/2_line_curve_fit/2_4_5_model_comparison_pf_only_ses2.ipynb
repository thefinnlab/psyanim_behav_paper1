# %% [markdown]
# - model comparison between the sigmoid and linear fits for mean subject-level playfight curves

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from func_fix_curvefit_params import *

# %%
root_folder = '../data/playfight_data/'

# %%
df_linear = pd.read_csv(f'{root_folder}/curve_fit_pf_ses2_linear/all_params_1k_play_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 5    26007.0   0.583599  0.255097 -24.829610   -0.019885  0.453000   0.509008
# 6    26008.0   0.803762  0.155699 -42.858682   -0.854731  0.213643   0.682607
# 24   26037.0   0.001659  0.307259 -34.303468   -9.950441  0.007929   0.578893
# 41   26060.0   0.823969  0.151992 -38.196440   -0.087761  0.318643   0.527964
# 63   26089.0   0.750620  0.178842 -34.875283   -0.010548  0.323929   0.503417
# 70   26096.0   0.203453  0.317590 -29.517473   -0.284030  0.138357   0.539298
# 73   26099.0   0.470037  0.262099 -50.282789   -0.010378  0.058500   0.500607
# 120  26161.0   0.867970  0.117954 -43.276108   -0.474986  0.262714   0.624786
# 122  26163.0   0.348776  0.258420 -41.318617   -1.340051  0.086238   0.615563
# 124  26167.0   0.860705  0.129607 -47.709068   -0.043495  0.185571   0.508071
# 136  26182.0   0.000000  0.305028 -26.694628        -inf  0.000000        NaN
# 175  26233.0   0.218219  0.315461 -34.614399   -0.502132  0.100500   0.550464
# 191  26255.0   0.547377  0.198801 -34.878049   -0.032591  0.205286   0.506690
# 194  26258.0   0.517401  0.226980 -39.015402   -0.769547  0.143833   0.610687
# 197  26261.0   0.953754  0.073058 -43.532981   -0.086617  0.456857   0.539571
# 209  26274.0   0.856206  0.137699 -37.753008   -0.433162  0.370952   0.660683
# 210  26275.0   0.947690  0.085336 -50.970908   -0.055429  0.251714   0.513952
# 219  26285.0   0.374175  0.233202 -42.135603   -0.021884  0.085952   0.501881
# 228  26297.0   0.603597  0.193393 -42.326574   -1.145492  0.135310   0.654996
# 251  26328.0   0.129393  0.277919 -75.845815  -23.685140  0.003857   0.591357
# 254  26333.0   0.873958  0.113684 -49.544327   -1.606969  0.172429   0.777087
# 257  26336.0   0.563570  0.232529 -33.465893   -0.360883  0.234643   0.584679
# 259  26338.0   0.057550  0.318760 -31.247547   -1.308841  0.059786   0.578250
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 5     0.509008   0.037992         0.0         0.0    False
# 6     0.682607   0.103750         0.0         0.0    False
# 24    0.578893   0.413179         0.0         0.0    False
# 41    0.527964   0.153393         0.0         0.0    False
# 63    0.503417   0.172655         0.0         0.0    False
# 70    0.539298   0.322345         0.0         0.0    False
# 73    0.500607   0.440893         0.0         0.0    False
# 120   0.624786   0.112500         0.0         0.0    False
# 122   0.615563   0.298198         0.0         0.0    False
# 124   0.508071   0.306357         0.0         0.0    False
# 136   0.499143   0.500857         1.0         1.0     True
# 175   0.550464   0.349036         0.0         0.0    False
# 191   0.506690   0.288024         0.0         0.0    False
# 194   0.610687   0.245480         0.0         0.0    False
# 197   0.539571   0.003571         0.0         0.0    False
# 209   0.660683  -0.031635         0.0         0.0    False
# 210   0.513952   0.234333         0.0         0.0    False
# 219   0.501881   0.412167         0.0         0.0    False
# 228   0.654996   0.209694         0.0         0.0    False
# 251   0.591357   0.404786         0.0         0.0    False
# 254   0.777087   0.050484         0.0         0.0    False
# 257   0.584679   0.180679         0.0         0.0    False
# 259   0.578250   0.361964         0.0         0.0    False

# %%
df_linear = fix_obj_center(df_linear)
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 46   26067.0   0.284428  0.290743 -54.685573         NaN  0.028595        NaN
# 126  26169.0   0.397730  0.258664 -34.969223         NaN  0.150714        NaN
# 136  26182.0   0.000000  0.305028 -26.694628         NaN  0.000000        NaN
# 145  26193.0   0.856144  0.133840 -27.144130         NaN  0.791238        NaN
# 199  26263.0   0.854329  0.118509 -37.162888         NaN  0.384000        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 46    0.534440   0.494155         1.0         1.0     True
# 126   0.580119   0.570595         1.0         1.0     True
# 136   0.499143   0.500857         1.0         1.0     True
# 145   0.913524   0.877714         1.0         1.0     True
# 199   0.791286   0.592714         1.0         1.0     True

# %%
df_sigmoid = pd.read_csv(f'{root_folder}/curve_fit_pf_ses1/all_params_1k_play.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 13   26013.0   0.153210  0.301533 -12.784271  0.205523   -0.275273  0.587979
# 14   26014.0  -0.271219  0.342287 -11.009483  0.448822         NaN  1.000000
# 39   26044.0   0.424887  0.267987 -14.435421  0.620997         NaN  0.312146
# 55   26060.0   0.078102  0.302751 -12.727843  0.478607         NaN  0.947683
# 67   26075.0   0.877948  0.112498 -26.587468  0.554165         NaN  0.221411
# 76   26085.0   0.999992  0.001460 -87.407501  0.636012        -inf  0.022314
# 87   26096.0   0.106543  0.310545 -12.371956  0.165148         NaN  0.769367
# 108  26118.0   0.568754  0.221490 -17.103320  0.343519   -0.251868  0.293770
# 111  26123.0   0.869203  0.114790 -26.305129  0.571596         NaN  0.209249
# 148  26163.0   0.843791  0.161347 -21.538795  0.774527         NaN  0.077512
# 150  26165.0   0.723191  0.221893 -17.077861  0.137396         NaN  0.034870
# 153  26169.0   0.716633  0.194829 -18.898850  0.457029         NaN  0.228013
# 178  26198.0   0.264526  0.284416 -13.602432  0.519650   -0.208880  0.489002
# 201  26223.0   0.138525  0.315973 -12.129378  0.618609         NaN  0.646466
# 209  26233.0   0.855664  0.127438 -24.841712  0.457531         NaN  0.222138
# 235  26261.0   0.882614  0.129837 -24.580653  0.356555         NaN  0.137600
# 246  26274.0   0.977163  0.063734 -34.542463  0.268184         NaN  0.103128
# 247  26275.0   0.985425  0.049846 -37.983539  0.543772         NaN  0.085471
# 259  26287.0   0.756427  0.143704 -23.159954  0.468207         NaN  0.277783
# 268  26296.0   0.807689  0.165705 -21.165680  0.802261         NaN  0.091038
# 269  26297.0  -0.054295  0.284692 -13.588885  0.370923         NaN  1.000000
# 283  26312.0   0.913164  0.101403 -28.041171  0.631782   -0.040371  0.184447
# 285  26314.0   0.871721  0.118696 -25.836632  0.457628         NaN  0.219586
# 298  26328.0   0.075067  0.300686 -12.823642  1.052003         NaN  0.961087
# 303  26333.0   0.959593  0.077396 -31.823436  0.373242         NaN  0.118705
# 304  26334.0   0.908426  0.111453 -26.718102  0.695630         NaN  0.028610
# 306  26336.0   0.399490  0.260907 -14.810298  0.404978         NaN  0.365703
# 308  26338.0   0.576472  0.222093 -17.065238  0.610539         NaN  0.234049
#
#      bias_xmin     bias_xmax  bias_lower  bias_upper  flipped
# 13    0.517159  4.219079e-01     0.45100    0.389000    False
# 14    0.631381  3.350860e-01     0.57800    0.285000    False
# 39    0.551269  3.066566e-01     0.52500    0.256667    False
# 55    0.753297  2.866642e-01     0.81000    0.345000     True
# 67    0.722358  1.139097e-01     0.70700    0.090000    False
# 76    0.500000  4.117875e-08     0.50000    0.000000    False
# 87    0.641044  2.888417e-01     0.53700    0.230000    False
# 108   0.554875  1.417883e-01     0.44700    0.097778    False
# 111   0.626449  1.921506e-01     0.61300    0.167000    False
# 148   0.501017  1.396005e-01     0.50100    0.120000    False
# 150   0.927000  3.623735e-01     0.92700    0.368000     True
# 153   0.556580  2.785140e-01     0.53200    0.261000    False
# 178   0.487593  5.891418e-01     0.53200    0.631000     True
# 201   0.807347  1.381399e-01     0.76600    0.085000    False
# 209   0.542524  1.968474e-01     0.50600    0.171000    False
# 235   0.796265  2.021029e-03     0.78100    0.000000    False
# 246   0.753313  2.193082e-04     0.73500    0.000000    False
# 247   0.526310  2.948610e-01     0.52600    0.294000    False
# 259   0.585506  1.835008e-01     0.53500    0.142000    False
# 268   0.548019  3.397862e-01     0.54800    0.327000    False
# 269   0.710655  2.628145e-01     0.66625    0.225000    False
# 283   0.501896  2.315509e-01     0.49200    0.194000    False
# 285   0.617385  2.771387e-01     0.60300    0.267000    False
# 298   0.532266  4.627840e-01     0.52700    0.452000    False
# 303   0.633324  1.299035e-02     0.61800    0.011111    False
# 304   0.534000  1.840068e-01     0.53400    0.184000    False
# 306   0.686750  2.239634e-01     0.64900    0.199000    False
# 308   0.934856  2.404306e-01     0.97100    0.256000     True

# %%
df_sigmoid = fix_obj_center(df_sigmoid)
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 55   26060.0   0.078102  0.302751 -12.727843  0.478607         NaN  0.947683
# 150  26165.0   0.723191  0.221893 -17.077861  0.137396         NaN  0.034870
# 173  26193.0   0.921151  0.097332 -28.614746  0.450420         NaN  0.194376
# 175  26195.0  -0.088820  0.322730 -11.833154  0.394690         NaN  1.000000
# 178  26198.0   0.264526  0.284416 -13.602432  0.519650         NaN  0.489002
# 227  26253.0   0.872084  0.153301 -22.254919  0.291435         NaN  0.023282
# 257  26285.0   0.014345  0.349880 -10.702324  0.523027         NaN  1.000000
# 308  26338.0   0.576472  0.222093 -17.065238  0.610539         NaN  0.234049
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 55    0.753297   0.286664       0.810    0.345000     True
# 150   0.927000   0.362374       0.927    0.368000     True
# 173   0.941307   0.910566       0.997    1.000000     True
# 175   0.656477   0.411678       0.755    0.524000     True
# 178   0.487593   0.589142       0.532    0.631000     True
# 227   0.554000   0.664999       0.554    0.665000     True
# 257   0.527065   0.499111       0.568    0.538889     True
# 308   0.934856   0.240431       0.971    0.256000     True

# %%
df_linear = add_new_params(df_linear)
df_linear.loc[df_linear['range']<0,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 46   26067.0   0.284428  0.290743 -54.685573         NaN  0.028595        NaN
# 126  26169.0   0.397730  0.258664 -34.969223         NaN  0.150714        NaN
# 145  26193.0   0.856144  0.133840 -27.144130         NaN  0.791238        NaN
# 199  26263.0   0.854329  0.118509 -37.162888         NaN  0.384000        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 46    0.534440   0.494155         1.0         1.0     True -0.028595  0.519583
# 126   0.580119   0.570595         1.0         1.0     True -0.150714  0.504138
# 145   0.913524   0.877714         1.0         1.0     True -0.791238  0.509996
# 199   0.791286   0.592714         1.0         1.0     True -0.384000  0.571738

# %%
df_linear = df_linear.loc[df_linear['range']>0,:] # remove negative amplitudes
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmoid = add_new_params(df_sigmoid)
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 55   26060.0   0.078102  0.302751 -12.727843  0.478607         NaN  0.947683
# 150  26165.0   0.723191  0.221893 -17.077861  0.137396         NaN  0.034870
# 173  26193.0   0.921151  0.097332 -28.614746  0.450420         NaN  0.194376
# 175  26195.0  -0.088820  0.322730 -11.833154  0.394690         NaN  1.000000
# 178  26198.0   0.264526  0.284416 -13.602432  0.519650         NaN  0.489002
# 227  26253.0   0.872084  0.153301 -22.254919  0.291435         NaN  0.023282
# 257  26285.0   0.014345  0.349880 -10.702324  0.523027         NaN  1.000000
# 308  26338.0   0.576472  0.222093 -17.065238  0.610539         NaN  0.234049
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 55    0.753297   0.286664       0.810    0.345000     True -0.039962  0.724351
# 150   0.927000   0.362374       0.927    0.368000     True -0.289374  0.718954
# 173   0.941307   0.910566       0.997    1.000000     True -0.851873  0.508300
# 175   0.656477   0.411678       0.755    0.524000     True -0.068155  0.614590
# 178   0.487593   0.589142       0.532    0.631000     True -0.076735  0.452844
# 227   0.554000   0.664999       0.554    0.665000     True -0.218999  0.454471
# 257   0.527065   0.499111       0.568    0.538889     True -0.026176  0.513621
# 308   0.934856   0.240431       0.971    0.256000     True -0.175287  0.795428

# %%
df_sigmoid = df_sigmoid.loc[df_sigmoid['range']>0,:] # remove negative amplitudes
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_linear.rename({'obj_center':'PSE'},inplace=True)
df_linear.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_linear.head()
# Out:
#      subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 0  26000.0   0.924233  0.114475 -39.241819    0.124705  0.477381   0.440468
# 1  26001.0   0.810345  0.140828 -30.664804    0.495616  0.521357   0.241607
# 2  26003.0   0.948120  0.087003 -31.126282    0.507930  0.984191   0.000100
# 3  26004.0   0.850246  0.130596 -45.074530    0.202595  0.214714   0.456500
# 4  26005.0   0.978372  0.053982 -40.003157    0.369992  0.870643   0.177869
#
#    bias_xmin  bias_xmax  flipped     range      bias
# 0   0.440468   0.082151    False  0.477381  0.842809
# 1   0.241607   0.237036    False  0.521357  0.504775
# 2   0.000100   0.015709    False  0.984191  0.006326
# 3   0.456500   0.328786    False  0.214714  0.581317
# 4   0.177869   0.000000    False  0.822131  1.000000

# %%
df_sigmoid.rename({'obj_center':'PSE'},inplace=True)
df_sigmoid.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_sigmoid
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 0    26000.0   0.947342  0.086740 -30.227716  0.447547    0.314152  0.156243
# 1    26001.0   0.909476  0.117844 -25.937516  0.686666    0.583813  0.126279
# 2    26002.0   0.951829  0.099103 -28.362317  0.729363    0.684758  0.052594
# 3    26003.0   0.961148  0.076137 -32.053098  0.465610    0.465610  0.138639
# 4    26004.0   0.941723  0.075045 -32.255374  0.553348    0.499196  0.226720
# ..       ...        ...       ...        ...       ...         ...       ...
# 314  26344.0   0.878185  0.136392 -23.891151  0.397590    0.359140  0.153172
# 315  26345.0   0.949162  0.104135 -27.668955  0.687642    0.687160  0.047663
# 316  26346.0   0.910287  0.098605 -28.432913  0.719411    0.602653  0.173938
# 317  26347.0   0.908595  0.100810 -28.123257  0.540522    0.284718  0.180744
# 318  26348.0   0.841177  0.136423 -23.887948  0.561827    0.596415  0.211483
#
#      bias_xmin  bias_xmax  flipped     range      bias
# 0     0.337762   0.053769    False  0.608468  0.862670
# 1     0.377311   0.250293    False  0.372396  0.601193
# 2     0.321001   0.085457    False  0.593543  0.789752
# 3     0.033620   0.020744    False  0.945636  0.618425
# 4     0.272558   0.224223    False  0.503219  0.548648
# ..         ...        ...      ...       ...       ...
# 314   0.172710   0.017078    False  0.810212  0.910015
# 315   0.008001   0.004407    False  0.987592  0.644792
# 316   0.279747   0.161481    False  0.558772  0.634019
# 317   0.461490   0.309041    False  0.229468  0.598924
# 318   0.249562   0.316949    False  0.433489  0.440525
#
# [311 rows x 12 columns]

# %%
rows = (np.isnan(df_linear['aic'])) | (np.isinf(df_linear['aic']))
df_linear.loc[rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = (np.isnan(df_sigmoid['aic'])) | (np.isinf(df_sigmoid['aic']))
df_sigmoid.loc[rows,:] # looks like a reasonable sub, but have to discard bc we need AIC
# Out:
#       subID  r_squared  nrmse  aic    center  obj_center  sigma  bias_xmin  \
# 70  26079.0        1.0    0.0 -inf  0.883856    0.883856    0.0        0.0
#
#     bias_xmax  flipped  range  bias
# 70        0.3    False    0.7   0.0

# %%
rows = ~(np.isnan(df_linear['aic'])) & ~(np.isinf(df_linear['aic']))
print('size, before:', df_linear.shape)
df_linear = df_linear.loc[rows,:]
print('size, after:', df_linear.shape)
# Out:
# size, before: (264, 12)
# size, after: (264, 12)

# %%
rows = ~(np.isnan(df_sigmoid['aic'])) & ~(np.isinf(df_sigmoid['aic']))
print('size, before:', df_sigmoid.shape)
df_sigmoid = df_sigmoid.loc[rows,:]
print('size, after:', df_sigmoid.shape)
# Out:
# size, before: (311, 12)
# size, after: (310, 12)

# %%
np.where(np.isnan(df_sigmoid))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
cols = list(df_linear.columns)
cols_new = [i + '_linear' for i in cols]
df_linear.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_linear
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  \
# 0         26000.0          0.924233      0.114475  -39.241819
# 1         26001.0          0.810345      0.140828  -30.664804
# 2         26003.0          0.948120      0.087003  -31.126282
# 3         26004.0          0.850246      0.130596  -45.074530
# 4         26005.0          0.978372      0.053982  -40.003157
# ..            ...               ...           ...         ...
# 264       26343.0          0.932664      0.080978  -35.254970
# 265       26344.0          0.936623      0.094923  -31.778106
# 266       26346.0          0.937625      0.083382  -39.407191
# 267       26347.0          0.934168      0.085602  -47.646641
# 268       26348.0          0.890589      0.119057  -29.326493
#
#      obj_center_linear  slope_linear  intercept_linear  bias_xmin_linear  \
# 0             0.124705      0.477381          0.440468          0.440468
# 1             0.495616      0.521357          0.241607          0.241607
# 2             0.507930      0.984191          0.000100          0.000100
# 3             0.202595      0.214714          0.456500          0.456500
# 4             0.369992      0.870643          0.177869          0.177869
# ..                 ...           ...               ...               ...
# 264           0.427334      0.676286          0.211000          0.211000
# 265           0.358499      0.895500          0.178964          0.178964
# 266           0.546918      0.523714          0.213571          0.213571
# 267           0.273320      0.282476          0.422794          0.422794
# 268           0.381822      0.791786          0.197679          0.197679
#
#      bias_xmax_linear  flipped_linear  range_linear  bias_linear
# 0            0.082151           False      0.477381     0.842809
# 1            0.237036           False      0.521357     0.504775
# 2            0.015709           False      0.984191     0.006326
# 3            0.328786           False      0.214714     0.581317
# 4            0.000000           False      0.822131     1.000000
# ..                ...             ...           ...          ...
# 264          0.112714           False      0.676286     0.651809
# 265          0.000000           False      0.821036     1.000000
# 266          0.262714           False      0.523714     0.448410
# 267          0.294730           False      0.282476     0.589240
# 268          0.010536           False      0.791786     0.949400
#
# [264 rows x 12 columns]

# %%
cols = list(df_sigmoid.columns)
cols_new = [i + '_sigmoid' for i in cols]
df_sigmoid.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_sigmoid
# Out:
# /Users/f0053cz/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      subID_sigmoid  r_squared_sigmoid  nrmse_sigmoid  aic_sigmoid  \
# 0          26000.0           0.947342       0.086740   -30.227716
# 1          26001.0           0.909476       0.117844   -25.937516
# 2          26002.0           0.951829       0.099103   -28.362317
# 3          26003.0           0.961148       0.076137   -32.053098
# 4          26004.0           0.941723       0.075045   -32.255374
# ..             ...                ...            ...          ...
# 314        26344.0           0.878185       0.136392   -23.891151
# 315        26345.0           0.949162       0.104135   -27.668955
# 316        26346.0           0.910287       0.098605   -28.432913
# 317        26347.0           0.908595       0.100810   -28.123257
# 318        26348.0           0.841177       0.136423   -23.887948
#
#      center_sigmoid  obj_center_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  \
# 0          0.447547            0.314152       0.156243           0.337762
# 1          0.686666            0.583813       0.126279           0.377311
# 2          0.729363            0.684758       0.052594           0.321001
# 3          0.465610            0.465610       0.138639           0.033620
# 4          0.553348            0.499196       0.226720           0.272558
# ..              ...                 ...            ...                ...
# 314        0.397590            0.359140       0.153172           0.172710
# 315        0.687642            0.687160       0.047663           0.008001
# 316        0.719411            0.602653       0.173938           0.279747
# 317        0.540522            0.284718       0.180744           0.461490
# 318        0.561827            0.596415       0.211483           0.249562
#
#      bias_xmax_sigmoid  flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0             0.053769            False       0.608468      0.862670
# 1             0.250293            False       0.372396      0.601193
# 2             0.085457            False       0.593543      0.789752
# 3             0.020744            False       0.945636      0.618425
# 4             0.224223            False       0.503219      0.548648
# ..                 ...              ...            ...           ...
# 314           0.017078            False       0.810212      0.910015
# 315           0.004407            False       0.987592      0.644792
# 316           0.161481            False       0.558772      0.634019
# 317           0.309041            False       0.229468      0.598924
# 318           0.316949            False       0.433489      0.440525
#
# [310 rows x 12 columns]

# %%
df_both =  df_linear.merge(df_sigmoid, left_on = 'subID_linear', right_on = 'subID_sigmoid')
#pd.concat([df_linear.set_index('subID_linear'),df_sigmoid.set_index('subID_sigmoid')]),axis=1)
print(df_both.shape)
# Out:
# (251, 24)

# %%
print(df_both.shape)
rows = (df_both['range_sigmoid']>0) & (df_both['slope_linear']>0)
df_both.loc[rows,:].shape
# Out:
# (251, 24)
# (251, 24)

# %%
df_both.rename(columns={'obj_center_linear':'PSE_linear','obj_center_sigmoid':'PSE_sigmoid'},inplace=True)
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         26000.0          0.924233      0.114475  -39.241819    0.124705
# 1         26001.0          0.810345      0.140828  -30.664804    0.495616
# 2         26003.0          0.948120      0.087003  -31.126282    0.507930
# 3         26004.0          0.850246      0.130596  -45.074530    0.202595
# 4         26005.0          0.978372      0.053982  -40.003157    0.369992
# ..            ...               ...           ...         ...         ...
# 246       26343.0          0.932664      0.080978  -35.254970    0.427334
# 247       26344.0          0.936623      0.094923  -31.778106    0.358499
# 248       26346.0          0.937625      0.083382  -39.407191    0.546918
# 249       26347.0          0.934168      0.085602  -47.646641    0.273320
# 250       26348.0          0.890589      0.119057  -29.326493    0.381822
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.477381          0.440468          0.440468          0.082151
# 1        0.521357          0.241607          0.241607          0.237036
# 2        0.984191          0.000100          0.000100          0.015709
# 3        0.214714          0.456500          0.456500          0.328786
# 4        0.870643          0.177869          0.177869          0.000000
# ..            ...               ...               ...               ...
# 246      0.676286          0.211000          0.211000          0.112714
# 247      0.895500          0.178964          0.178964          0.000000
# 248      0.523714          0.213571          0.213571          0.262714
# 249      0.282476          0.422794          0.422794          0.294730
# 250      0.791786          0.197679          0.197679          0.010536
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.086740   -30.227716        0.447547
# 1             False  ...       0.117844   -25.937516        0.686666
# 2             False  ...       0.076137   -32.053098        0.465610
# 3             False  ...       0.075045   -32.255374        0.553348
# 4             False  ...       0.066314   -33.986936        0.592850
# ..              ...  ...            ...          ...             ...
# 246           False  ...       0.080190   -31.327045        0.629157
# 247           False  ...       0.136392   -23.891151        0.397590
# 248           False  ...       0.098605   -28.432913        0.719411
# 249           False  ...       0.100810   -28.123257        0.540522
# 250           False  ...       0.136423   -23.887948        0.561827
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.314152       0.156243           0.337762           0.053769
# 1       0.583813       0.126279           0.377311           0.250293
# 2       0.465610       0.138639           0.033620           0.020744
# 3       0.499196       0.226720           0.272558           0.224223
# 4       0.610678       0.149196           0.217207           0.273891
# ..           ...            ...                ...                ...
# 246     0.540189       0.109293           0.322838           0.114954
# 247     0.359140       0.153172           0.172710           0.017078
# 248     0.602653       0.173938           0.279747           0.161481
# 249     0.284718       0.180744           0.461490           0.309041
# 250     0.596415       0.211483           0.249562           0.316949
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.608468      0.862670
# 1              False       0.372396      0.601193
# 2              False       0.945636      0.618425
# 3              False       0.503219      0.548648
# 4              False       0.508902      0.442289
# ..               ...            ...           ...
# 246            False       0.562208      0.737423
# 247            False       0.810212      0.910015
# 248            False       0.558772      0.634019
# 249            False       0.229468      0.598924
# 250            False       0.433489      0.440525
#
# [251 rows x 24 columns]

# %%
# rows = (df_both['amplitude_sigmoid']>0) & (df_both['slope_linear']>0)
# df_both = df_both.loc[rows,:]
# print(df_both.shape)
# df_both.head()

# %% [markdown]
# # sanity checks

# %%
def get_p(p):
    if p < .001:
        return "p < .001"
    elif p < .01:
        return f"p={p:.3f}"
    else:
        return f"p={p:.2f}"
        
def explore_correlations(df, param, ax):

    from scipy.stats import pearsonr,spearmanr

    if param == 'slope':
        x = df[param+'_linear']
        y = df['sigma_sigmoid']
    else:
        x = df[param+'_linear']
        y = df[param+'_sigmoid']
    
    rows = (~np.isnan(x)) & (~np.isnan(y)) & (~np.isinf(x)) & (~np.isinf(y))
    x = x[rows]
    y = y[rows]

    sns.scatterplot(x=x, y=y,color='k',alpha=.3,ax=ax)
    r,p = pearsonr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_p={r:.2f} ({get_p(p)})',xy=(0.05,.9),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')


    r,p = spearmanr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_s={r:.2f} ({get_p(p)})',xy=(0.05,.8),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')

# %%
comparisons = ['bias_xmin','bias_xmax','bias','PSE','range','slope','r_squared']

# %%
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         26000.0          0.924233      0.114475  -39.241819    0.124705
# 1         26001.0          0.810345      0.140828  -30.664804    0.495616
# 2         26003.0          0.948120      0.087003  -31.126282    0.507930
# 3         26004.0          0.850246      0.130596  -45.074530    0.202595
# 4         26005.0          0.978372      0.053982  -40.003157    0.369992
# ..            ...               ...           ...         ...         ...
# 246       26343.0          0.932664      0.080978  -35.254970    0.427334
# 247       26344.0          0.936623      0.094923  -31.778106    0.358499
# 248       26346.0          0.937625      0.083382  -39.407191    0.546918
# 249       26347.0          0.934168      0.085602  -47.646641    0.273320
# 250       26348.0          0.890589      0.119057  -29.326493    0.381822
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.477381          0.440468          0.440468          0.082151
# 1        0.521357          0.241607          0.241607          0.237036
# 2        0.984191          0.000100          0.000100          0.015709
# 3        0.214714          0.456500          0.456500          0.328786
# 4        0.870643          0.177869          0.177869          0.000000
# ..            ...               ...               ...               ...
# 246      0.676286          0.211000          0.211000          0.112714
# 247      0.895500          0.178964          0.178964          0.000000
# 248      0.523714          0.213571          0.213571          0.262714
# 249      0.282476          0.422794          0.422794          0.294730
# 250      0.791786          0.197679          0.197679          0.010536
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.086740   -30.227716        0.447547
# 1             False  ...       0.117844   -25.937516        0.686666
# 2             False  ...       0.076137   -32.053098        0.465610
# 3             False  ...       0.075045   -32.255374        0.553348
# 4             False  ...       0.066314   -33.986936        0.592850
# ..              ...  ...            ...          ...             ...
# 246           False  ...       0.080190   -31.327045        0.629157
# 247           False  ...       0.136392   -23.891151        0.397590
# 248           False  ...       0.098605   -28.432913        0.719411
# 249           False  ...       0.100810   -28.123257        0.540522
# 250           False  ...       0.136423   -23.887948        0.561827
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.314152       0.156243           0.337762           0.053769
# 1       0.583813       0.126279           0.377311           0.250293
# 2       0.465610       0.138639           0.033620           0.020744
# 3       0.499196       0.226720           0.272558           0.224223
# 4       0.610678       0.149196           0.217207           0.273891
# ..           ...            ...                ...                ...
# 246     0.540189       0.109293           0.322838           0.114954
# 247     0.359140       0.153172           0.172710           0.017078
# 248     0.602653       0.173938           0.279747           0.161481
# 249     0.284718       0.180744           0.461490           0.309041
# 250     0.596415       0.211483           0.249562           0.316949
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.608468      0.862670
# 1              False       0.372396      0.601193
# 2              False       0.945636      0.618425
# 3              False       0.503219      0.548648
# 4              False       0.508902      0.442289
# ..               ...            ...           ...
# 246            False       0.562208      0.737423
# 247            False       0.810212      0.910015
# 248            False       0.558772      0.634019
# 249            False       0.229468      0.598924
# 250            False       0.433489      0.440525
#
# [251 rows x 24 columns]

# %%
nrows = 3
ncols = 3
fig,axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (10,10))
for i,param in enumerate(comparisons):
    r = int(np.floor(i/ncols))
    c = i%ncols
    ax = axs[r,c]
    explore_correlations(df_both, param, ax)
    ax.set_title(param,fontweight='bold')
    if param == 'slope':
        ax.set_title ('slope vs. inv. sigma',fontweight='bold')

df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

ax = axs[2,1]
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-100,0)

ax = axs[2,2]
ax.axis('off')

plt.suptitle('Linear (X) vs. sigmoid(Y) fits (pf sess1)', fontweight='bold', fontsize=16)
plt.tight_layout()
# plt.savefig('../results/playfight/linear_vs_sigmoid_ses2.png',dpi=300,bbox_inches='tight')

# %%
df_both.to_csv('../data/playfight_data/curvefits_linear_sigmoid_params_ses2.csv')

# %%
from scipy import stats

# %%
s=16 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

# %%
df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

fig,ax = plt.subplots(figsize=(4,4),nrows=1,ncols=1)
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-100,0)
plt.savefig('../results/playfight/AIC_linear_vs_sigmoid_ses2.png')

# %%
stats.ttest_rel(df_both['aic_sigmoid'],df_both['aic_linear'])
# Out:
# Ttest_relResult(statistic=13.248928287417588, pvalue=1.042572241830733e-30)

# %%
df_both['aic_sigmoid'].mean(),df_both['aic_linear'].mean(), df_both['aic_sigmoid'].std(),df_both['aic_linear'].std()
# Out:
# (-29.227208785525068, -37.62291301856578, 6.457097179985464, 7.062631157514021)

# %%
df_both['aic_diff'] = df_both['aic_sigmoid'] - df_both['aic_linear']
# len(np.where(df_both['aic_diff']>0)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<0)[0])
len(np.where(df_both['aic_diff']>5)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-5)[0])
# Out:
# (165, 0, 17)

# %%
len(np.where(df_both['aic_diff']>10)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-10)[0])
# Out:
# (99, 0, 6)
