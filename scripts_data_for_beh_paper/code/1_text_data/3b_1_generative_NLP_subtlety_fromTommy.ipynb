# %% [markdown]
# # data-driven approach

# %%
# !pip install sentence-transformers
from sentence_transformers import SentenceTransformer, util
# Initialize the model
NLPmodel = SentenceTransformer('./sentence-transformers_all-MiniLM-L6-v2') # SentenceTransformer('all-MiniLM-L6-v2')

# %%
import pandas as pd
import numpy as np
from nlp_utils import *

# %%
sentences = ['This is how it looks.','let me see']

# %%
import os, sys
import numpy as np
import pandas as pd
import regex as re
import torch

def load_mlm_model(model_name, cache_dir=None):
	'''
	Use a model from the sentence-transformers library to get
	sentence embeddings. Models used are trained on a next-sentence
	prediction task and evaluate the likelihood of S2 following S1.
	'''
	# set the path of where to download models
	# this NEEDS to be run before loading from transformers
	if cache_dir:
		os.environ['TRANSFORMERS_CACHE'] = cache_dir

	from transformers import AutoTokenizer, AutoModel

	# Load model from HuggingFace Hub
	tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
	model = AutoModel.from_pretrained(model_name)
	
	model.eval()

	return tokenizer, model

import re

def subwords_to_words(sentence, tokenizer):
	
	word_token_pairs = []
	
	# split the sentence on spaces + punctuation (excluding apostrophes and hyphens within words)
	regex_split_pattern = r'(\w|\.\w|\:\w|\'\w|\'\w|\-\w|\S)+'

	# regex_split_pattern = r"[\w]+[''.-:]?[\w]*"

	for m in re.finditer(regex_split_pattern, sentence):
		word = m.group(0)
		tokens = tokenizer.encode(word, add_special_tokens=False)
		char_idxs = (m.start(), m.end()-1)
		
		word_token_pairs.append((word, tokens, char_idxs))
	
	return word_token_pairs

def extract_word_embeddings(sentences, tokenizer, model):#, word_indices=None):
	'''
	Given a list of sentences, pass them through the tokenizer/model. Then pair
	sub-word tokens into the words of the actual sentence and extract the true
	word embeddings. 
	
	If wanted, can return only certain indices (specified by word_indices)
	
	Currently not robust to different length strings MBMB
	'''
	
	if isinstance(sentences, str):
		sentences = [sentences]
	
	if not sentences:
		return []
	
	# get the full sentence tokenized
	encoded_inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
	# print('encoded_inputs',encoded_inputs)
	
	# get the embeddings
	with torch.no_grad():
		model_output = model(**encoded_inputs, output_hidden_states=True)
	
	print("len(model_output['hidden_states']",len(model_output['hidden_states']))#7
	all_embeddings = []
	
	# bring together the current sentence, its tokens, and its embeddings
	for i, sent in enumerate(sentences):
		# now pair subwords into words for the current sentence
		subword_word_pairs = subwords_to_words(sent, tokenizer)
		print(sent, subword_word_pairs)
		
		embeddings = []
		
		# for the current set of word subword pairs, get the embeddings
		for (word, tokens, char_span) in subword_word_pairs:
			
			# given the character to token mapping in the sentence, 
			# find the first and last token indices
			start_token = encoded_inputs.char_to_token(batch_or_char_index=i, char_index=char_span[0])
			end_token = encoded_inputs.char_to_token(batch_or_char_index=i, char_index=char_span[-1])
			
			# extract the embedding for the given word
			word_embed = torch.stack([layer[i, start_token:end_token+1, :].sum(0) for layer in model_output['hidden_states']])
			print(word_embed.shape)
			embeddings.append(word_embed)
		
		print(len(embeddings))
		# stack the embeddings together
		embeddings = torch.stack(embeddings)
		print(len(embeddings))
		
		# make sure the mapping happened correctly
		if len(sent.split()) != embeddings.shape[0]:
			print (subword_word_pairs)
			print (len(subword_word_pairs))
			print (embeddings.shape)
			print (len(sent.split()))

		assert (len(sent.split()) == embeddings.shape[0])
		
		print(len(embeddings))
		all_embeddings.append(embeddings)
	
	# all_embeddings = torch.stack(all_embeddings)
	
	# if word_indices:
	# 	return all_embeddings[:, word_indices, :]
	# else:
	# 	return all_embeddings

	return all_embeddings

# %%
tokenizer, model = load_mlm_model('./sentence-transformers_all-MiniLM-L6-v2')
all_embeddings = extract_word_embeddings(sentences, tokenizer, model)
# Out:
# len(model_output['hidden_states'] 7
# This is how it looks. [('This', [2023], (0, 3)), ('is', [2003], (5, 6)), ('how', [2129], (8, 10)), ('it', [2009], (12, 13)), ('looks.', [3504, 1012], (15, 20))]
# torch.Size([7, 384])
# torch.Size([7, 384])
# torch.Size([7, 384])
# torch.Size([7, 384])
# torch.Size([7, 384])
# 5
# 5
# 5
# let me see [('let', [2292], (0, 2)), ('me', [2033], (4, 5)), ('see', [2156], (7, 9))]
# torch.Size([7, 384])
# torch.Size([7, 384])
# torch.Size([7, 384])
# 3
# 3
# 3

# %%
all_embeddings[0].shape
# Out:
# torch.Size([5, 7, 384])

# %%
all_embeddings[1].shape
# Out:
# torch.Size([3, 7, 384])

# %%
# run if needed!!
# df with all verbs and their embeddings

# import nltk
# # nltk.download('wordnet')

# from nltk.corpus import wordnet as wn

# # Retrieve all English lemmas in WordNet
# lemmas = wn.all_lemma_names(pos=wn.VERB)#NOUN)

# # Convert lemmas to a list
# english_words = list(lemmas)

# print(english_words[:100]), len(english_words)

# english_words = [i for i in english_words if '-' not in i]
# english_words = [i for i in english_words if '_' not in i]
# english_words_embedding = NLPmodel.encode(english_words)

# print(english_words_embedding.shape)

# df_words = pd.DataFrame({'words':english_words, 'word_len':[len(i) for i in english_words], 'embedding':english_words_embedding.tolist()})
# df_words

# %%
# df_words.to_csv('../../data/text_responses/text_responses_all_verbs.csv')

# %%
df_words = pd.read_csv('../../data/text_responses/text_responses_all_verbs.csv',index_col=[0])
df_words.head()
# Out:
#         words  word_len                                          embedding
# 0      absent         6  [0.019467102363705635, 0.05805996060371399, -0...
# 1    abstract         8  [-0.07030732184648514, 0.08017940074205399, 0....
# 2         ace         3  [-0.12659801542758942, 0.01382419653236866, -0...
# 3   acuminate         9  [-0.06811799108982086, 0.09903689473867416, -0...
# 4  adulterate        10  [0.03436809778213501, 0.04313870146870613, -0....

# %%
english_words = df_words['words'].values
english_words_embedding = df_words['embedding'].values

# %%
param_name = 'subtlety'
expt_type = 'subtlety/without_cover_story/'
rootfile_loc = f'../../data/text_responses/{expt_type}'

# %%
df = pd.read_csv(f'{rootfile_loc}/data_triallevel_sorted.csv',index_col=[0])
df.head()
# Out:
#    subID  stimset_rows  subtlety  \
# 0  15000             0         0
# 6  15001             1         0
# 0  15002             2         0
# 2  15003             3         0
# 3  15004             6         0
#
#                                            responses  \
# 0                       grey dot following black dot
# 6  A grey dot appeared to chase or follow a black...
# 0  the black dot seemed to be running away from t...
# 2               Black dot was following the grey dot
# 3    Black moved from right to left chasing the grey
#
#                                   movie  trial_num
# 0  07cdb9d7-6577-428d-9498-8a7243527554          0
# 6  53613c0d-b07e-4b22-b6ec-56dda26edc8f          6
# 0  19c65966-3d88-4851-afe4-ae34c498748c          0
# 2  c188e383-94d7-475e-9da5-6d1f0a1184bb          2
# 3  49e5ac90-6e7f-4243-9552-8c4c10545895          3

# %%
words_to_compare = df['responses'].to_list()
words_to_compare = [s.lower() for s in words_to_compare]
words_to_compare
# Out:
# ['grey dot following black dot',
#  'a grey dot appeared to chase or follow a black dot right and then up.',
#  'the black dot seemed to be running away from the gray one',
#  'black dot was following the grey dot',
#  'black moved from right to left chasing the grey',
#  'black dot was being chased by the grey one',
#  'it seemed like the grey dot was trying to chase the black dot',
#  'lighter dot is being pressured by dark one',
#  'grey sot following black dot',
#  'the black dot was following the grey dot in a beeline.',
#  'black dot being chased by white dot',
#  'again the black dot moved toward the grey dot which moved to get away from the black dot',
#  'the grey dot approached the black dot and both curved in a downwards sweep to the bottom of the box',
#  'the grey dot was chasing the black dot',
#  'the grey dot was moving closer to the black dot, as they reached a distance, the dot did not move any closer but mimicked the moves of the other one ',
#  'black chasseing dray dot',
#  'the white dot is chasing after the black dot',
#  'the gray dot and the black dot approach each other so that the gray dot can lead the black dot. after they meet, the gray dot leads the black dot to the top right of the box.',
#  'the grey dot was after the black dot and moving towards the right side of the screen',
#  'the grey dot started off moving on its own then moved down to the bottom left, the black dot followed it',
#  'black moving in one direct to the left, gret circling before moving in the same direction as black',
#  'the black dot was following the grey dot',
#  'the dark dot was evading and the light dot was chasing',
#  'the black dot moved to the left of the screen. the gray dot moved to the left, upwards and in a circle.',
#  'the dots approached each other and then the black dot chased the gray dot',
#  'the black dot followed the grey dot',
#  'the grey dot moved a bit in a specific area, then the black dot moved directly towards the grey dot and kept following it persistently.',
#  'the grey dot bee-lined to the black dot and then followed it. black dot moved away, but slowly in no rush.',
#  "grey dot is chasing the black dot. the black dot gets it's back to the wall and continues to back away.",
#  "the grey dot made a consistant motion towards the black dot. the black dot appears to have been moving in a circle before 'seeing' the black dot and moving away from it to the right",
#  'flowing around',
#  'moving to right hand side',
#  'the lighter dot seemed to be chasing/following the darker dot',
#  'they grey dot was chasing the black dot which was frantically trying to get away',
#  'both dots moving towards the top left of the box',
#  'they both moved left, then the grey dot moved right for a short time but before making contact with the other moved down',
#  'the grey one was following the black one',
#  'black following light grey to bottom left',
#  'the black dot is backing the grey one into a corner',
#  'the grey dot appeared to be chasing the black dot, and the black dot was making a constant effort to move further away from it',
#  'the black one cornered the grey one',
#  'black dot was chasing the grey dot',
#  'drifting to the right and then up.',
#  'grey tracking black dot directly',
#  'black following grey up to the top right and beyond like takingoff',
#  'grey dot was chasing black dot but could only go a single speed. the black dot was faster and could escape',
#  'they were moving more quickly to left of screen',
#  'black dot was following/tailing the grey dot',
#  'the black dot was chasing the grey dot. the grey was moving quickly and wavering around, the black was moving slowly and steadily in a smooth line.',
#  'both fell towards the bottom right corner. black started in the middle and fell less distance. grey started a little right of middle but from much higher.',
#  'the black dot was chasing the grey dot',
#  'the black dot started going in circles and was the followed by the grey dot',
#  'it looked like the grey dot was trying to tag the black dot',
#  'the black dot appeared to be following the grey dot.',
#  'the dark dot was chasing the light dot, the light dot saw the dark dot a short while in',
#  'dots moving upwards- one following the other dot',
#  'they both moved toward the upper left side ',
#  'the black dot was following the grey dot into the corner ',
#  'the black dot began to follow the grey dot',
#  'the =dark dot nearly hit the light then turned',
#  'black dot following grey dot',
#  'a black dot seemed to follow a grey dot from center right to lower left.',
#  'the black dot was following the gray dot',
#  'grey dot was following the black dot',
#  'black moved from left to right chasing the grey',
#  'the black dot is chasing the grey one',
#  'black dot moved toward the grey and the grey was trying to get away from it so moved downwards',
#  'dancing',
#  'grey dot chasing black dot',
#  'the grey dot was making a beeline towards the black dot and the black dot was moving away from it.',
#  'black dot following white dot',
#  'the black dot moved toward the grey dot and after closing a certain distance the grey dot moved away from the black',
#  'the grey dot approached the black dot and both moved towards the top right corner',
#  'the grey dot seems to be chasing the black dot',
#  'the grey dot was following the black dot at a consistent distance between the two.  ',
#  'gray dot chaseing black dot',
#  'the white dot is trying to get close to the black dot',
#  'it seems as if the black dot was approaching the gray dot, and the gray dot was moving away from it, though not urgently.',
#  'black dot moving after the grey dot towards the left side corner of the screen',
#  'the dots went to the left and it seemed as if the darker dot was chasing the other',
#  'both dots were moving in the same path',
#  'black dot chasing grey dot',
#  'the light dot appeared to be chasing the dark dot',
#  'both dots moved down to the right. the gray dot went in a more squiggly and not straight pattern though.',
#  'black dot seemed to chase the gray dot',
#  'the dots approached eachother before the black dot backed off and they moved towards the top right corner',
#  'the two dots moved closer to each other, then the grey dot started following the direction that the black dot was moving to',
#  'the black dot looked like it wanted to get away, but the grey dot bee-lined for it and kept trying to get close.',
#  'black dot is chasing the grey dot again in this one. except this time instead of the chase leading to the left, they went to the right.',
#  'the grey dot appeared to be making a consistent motion towards the black dot as is mimiced its motion traveling towards it. the black dot did a circular motion and then began moving away from the grey dot to the right before traveling upwards on the right side of the box',
#  'black was following white',
#  'both moving to upper left corner',
#  'dark dot moved towards light dot then light followed the dark a short distance',
#  'the black dot was chasing the grey dot',
#  'both dots moving into the centre and then moving out to the left together',
#  'they moved right then down; the grey dot seemed to make moves to avoid contact with the black dot',
#  'now the black one followed the grey one!',
#  'light grey following black to top left',
#  'the black dot is approaching the grey dot ',
#  'the black dot appeared to be chasing the grey dot which seemed to be actively moving away purposefully',
#  'the black one followed the grey one to the edge',
#  'black dot was following the grey dot',
#  'moving from right to left with the grey dot moving with the black dot staying just in front.',
#  'black following grey dot',
#  'like two little birds flying together',
#  'grey dot chasing black dot but they became locked on a horizontal axis at the same distance',
#  'they were moving to the bottom right of screen',
#  'grey dot was following/tailing the black dot',
#  'black was moving towards grey, grey was swaying back and forth and moving away from black',
#  'black made  a short move to the top left corner then traced along the top of the box back right. grey started more central and did the same. since grey had further to travel it was behind black and seemed to follow black along the top of the box.',
#  'they initially moved together, then black chased grey and grey moved away',
#  'the grey dot was floating and chasing the black dot around the screen',
#  'the black dot was chasing the grey dot around the screen',
#  'the dots both moved in an anti clockwise direction, but again they did not touch each other.',
#  'the dark dot was chasing the light dot',
#  'dots moved towards the left and then began to drop downwards towards the left',
#  'they were moving toward the left side',
#  'the dots came together then the grey dot followed the black dot ',
#  'the black dot started following the grey and the grey moved in zig zags to try and avoid it',
#  'the light dot was chasing the dark dot',
#  'black dot following grey dot',
#  "a grey dot appeared to move away from a black dot, slowed and allowed for the black dot to catch up before continuing on it's path.",
#  'the gray dot was following the black dot from a distance',
#  'black dot was following the grey dot',
#  'black moved diagnonally grey in circles',
#  'the grey dot discvered the black one and now it is running after it',
#  'both went toward each other then the black dot started to move right so the grey followed.',
#  'chasing ',
#  'grey follwoing black',
#  'the white dot was following the black dot which was moving away from it.',
#  'black dot chased yje white one, white one moved away',
#  'the grey dot moved toward the black, the black seemed to be moving to its own pattern at first but started moving away from the grey after it closed a certain distance',
#  'both the black and grey dot seemed to be drawn towards the top right corner',
#  'the black dot was chasing the grey dot',
#  'the dots moved closer together , but then gaining distance back as they moved upwards on the screen, following each other closely with a near coalition ',
#  'black dot chasing gray dot gray moving toward corner',
#  'the black dot is chasing the white dot',
#  'the dots are moving toward the top of the screen. the gray dot is following the black dot.',
#  'grey dot after black dot and moving toward the right hand upper corner of the screen',
#  'the lighter dot chased the black dot into the upper right hand corner of the box',
#  'grey had smooth movement compared to black as had no idea where to move to next',
#  'black dot still chasing grey dot',
#  'i think the light dot was chasing the dark dot',
#  'the gray dot moved down to the left. the black dot went in a bit of a circle before going down to the left.',
#  'gray dot seemed to chase the black dot',
#  'the grey dot followed the black dot slowly upwards towards the top left corner',
#  'this time the black dot was following the grey dot',
#  'the dots were moving towards each other, but when they got close the grey dot tried to move away while the black dot followed.',
#  'the black dot was sort of chasing the grey dot. the black dot was actively approaching the grey one and the grey one would sort of back off.',
#  "the black dot appeared to be moving to the top right corner of the box before 'spotting' the grey dot and following it to the top of the box. the grey dot apeared to be moving to the top center of the box before 'seeing' the grey dot and going to the top right and circling around to the top centre",
#  'white was following black',
#  'black dot following grey dot',
#  'dark dot moved towards light dot after light dot started to make circular movement',
#  'looked like the black dot was chasing the grey dot again',
#  'hovering around, with the black dot slowly hovering closer to the grey dot',
#  "they both moved left; the black dot seemed to 'bounce' off of the left side of the field",
#  'the grey one is slowly following the black one again',
#  'travelling to the top right',
#  'the grey dot is approaching the black dot, backing it into a corner  (or against a wall)',
#  'the grey dot appeared to be actively chasing the black dot. the black dot seemed to be purposefully moving away and trying to distance itself',
#  'when they came close, the grey one followed the black one',
#  'grey dot was following the black dot',
#  'moving to top right hand corner.',
#  'black dot was heading towards grey dot',
#  'black is following grey',
#  'black dot is chasing the grey dot',
#  'they were moving to the top right of screen',
#  'black dot was following and tailing the grey one',
#  'grey was chasing black dot, black was getting stuck in a corner.',
#  'grey was going in a zig zag pattern from bottom to top on the left side. black was going in a similar pattern from middle to top left.',
#  "the grey dot was 'chasing' the black dot",
#  'the black dot followed the grey dot into the top left corner',
#  'the black dot was running away from the grey dot',
#  'the dots were both fairly close to each other and were both moving around.',
#  'the light dot was chasing the dark dot',
#  'moving to the left and moving downwards slowly',
#  'they both dots were moving from middle to the upward part',
#  'grey dot was following/pushing the black dot into the corner',
#  'the black dot started chasing the grey dot',
#  'the dark dot was closing in on the light dot',
#  'grey dot following black dot',
#  'a black dot appeared to trace the path of the grey dot from left to right.',
#  'they looked like they were going to collide, but they both went to the left with some distance between them',
#  'dots looked like they were in sync at first, then they became closer together',
#  'bothmoved randomly',
#  'the grey dot is spying on the black one, the grey dot does not feel confident',
#  'they slowly floated toward each other but seemed hesitant to touch and kept going seperate',
#  'playing a game together',
#  'black dot followng grey dot',
#  'they seemed to be keeping an equal distance from each other.',
#  'white dot moving away from black dot. but balck dot not chaseing white.',
#  'both dots moved semi randomly but toward the end the grey dot moved toward the black',
#  'the black dot approaches the grey dot to the left, then they start to move towards the left wavering',
#  'both dots seems to be playing together',
#  'the dot first moved closer to each other, then one was following the other one while gaining distance on the other one',
#  'black dot mving up and down and foward gray moving toward right side',
#  'the black dot is trying to get close to the white dot',
#  'the dots were moving toward the top left corner of the screen.',
#  'both dots at the center of the screen',
#  'the dots were moving towards each other then away then together again',
#  'grey went in an upwards trajectory smoothly, black was snaked across the screen',
#  'grey dot is chasing the black dot',
#  'the dots were moving on the screen not touching each other',
#  'the gray dot was moving to the left. the black one moved right then left.',
#  'it felt like the grey dot was chasing the black dot to the bottom right of the screen',
#  'the dots approached eachother before the grey dot backed off and the black dot followed',
#  'the grey dot moved immediately away from the black dot. the black dot seemed to be moving closer to the grey dot but slowly and not aggressively.',
#  "the grey dot didn't do much, but the black dot bee-lined for it and meet up with it.",
#  'black dot is backing off. the grey dot is approaching, but slowly. sort of in a calculating way?',
#  "the grey dot moved up and down to the right in a consistant motion of moving downwards before nearly hitting the black dot. the black dot did a circular motion before beginning to move upward with it's path seeming to be about to cross with the grey dot",
#  'black was following white',
#  'moving towards the left hand side',
#  'both dots moving up and down but darker dot was following the lighter dot',
#  'again it looked like one was chasing the other but the grey dot seemed to not be able to get to the black dot',
#  'both dots moving to the right side of the box, with the grey dot moving towards the black dot',
#  'they were moving with fluctuations in a generally up-left motion',
#  'they came to each other and then the grey one followed the black one',
#  'black trying to follow light grey',
#  'the grey dot is rising with the black dot rising shortly behind',
#  'the grey dot appeared to be actively moving away from the black dot, at one point it turned and headed toward the black dot but only seemingly as it approached the edge of the screen/border. it then resumed moving away',
#  'the grey one was following the black one cautiously',
#  'grey dot was trying to get pas the black dot.',
#  'slowly drifting right whilst moving up and down.',
#  'grey dot was following black dot. both moving downwards.',
#  'towards end they were mimicking each other',
#  'grey dot was chasing the black dot but the black dot kept a set distance away',
#  'they were moving slightly together and then apart, ending closer together',
#  'dots were hovering towards the bottom left of the screen almost in sync',
#  'gray was chasing black dot, black was trying to evade when it became aware of grey.',
#  'grey was going in a small movement pattern from right to left. black started doing similar towards grey from left to right, but then turned as if running from gray.',
#  'grey was chasing black, but blacks movement seemed slightly more erratic',
#  'the black dot was chasing the grey dot',
#  'the black dot was chasing the grey dot from a distance',
#  'the dots started of far apart and then both moved towards each other but they did not touch each other.',
#  'the light dot was chasing the dark dot. the dark dot saw the light dot a short time in',
#  'light grey dot moved towards the right, dark dot moved up and down across screen',
#  'they moved from middle to the bottom part',
#  'the grey dot was moving in the same way of the black dot but not getting close to each other',
#  'the grey dot started trying to catch up with the black dot',
#  'the dark dot was zig zagging.',
#  'moving towards the left',
#  'a grey dot moved in circles while the black dot appeared to bounce around.',
#  'the dots were on their own separate paths but looked like they were about to collide',
#  'both had completely random movements',
#  'black dot is moving on the left, grey on the right',
#  'black dot was minding its business, the grey dot was trying to spy on the black one',
#  'grey dot was slowly floating towards the black on again and the black one was moving to the left',
#  'light dot is unaware of black dot',
#  'floating to the right top corner',
#  'the grey dot seemed to be following the black dot from a distance.',
#  'moving like incets on water or small cells',
#  'the black dot was moving closer to the grey dot whilst the grey dot moved randomly and then moved away from the black dot',
#  'the black dot moved in an erratic way to the right where as the grey dot wavered about the right side of the box',
#  'both dots were playing',
#  'moving around but slightly closer and closer with each move towards each other while going downward ',
#  'black dot moving left gray dot moving right',
#  'the dots a moving up and down on different sides of the screen',
#  'i mostly saw what the black dot was doing, and i think it was writing or drawing: its movements seemed precise.',
#  'both dots moving to thr bottom of the screen',
#  'the grey dot did small movements, the black dot did big ones',
#  'circular motions before moving direction',
#  'moving around the screen',
#  'the dots were moving on the screen',
#  'the black dot moved up and down. the gray dot went in a little bit of a circle and then down.',
#  'the dots approached each other but the gray dot retreated',
#  'both dots moved inwards and slightly down',
#  'the grey dot was moving at a slow pace, the black dot was moving faster and seemed to be gradually moving closer to the grey dot',
#  'the dots were doing their own thing, but when grey dot got too close to black dot it started to move away from black dot.',
#  'it was like a wary fight between the two dots. it looked as if the black one was on defense while the grey one was looking for an opening to attack.',
#  'the grey dot bounced slightly as it moved down to the left before moving up, the black dot moved to the left somewhat bouncing as it went',
#  'moving near each other',
#  'moving in zig zag',
#  'darker dot seemed to be moving faster with wider/longer paces across the screen',
#  'they almost seemed to circle until the grey dot advanced toward the black dot then ran away',
#  'both dots moving towards the left slowly and not fully',
#  'they moved upward and closer to each other though never made contact',
#  'the black one is stalking the grey one.',
#  'moving towards each other then away again',
#  'both dots are descending with a bit of distance between them',
#  'the darker dot appeared to be attempting to move closer to the grey dot, however the grey dot did not appear to be consciously moving toward it or away from it.',
#  'when they came close the black one moved away',
#  'grey dot was watching the black dot',
#  'moving slightly to the left but mostly around the middle.',
#  'movements not related, black heading towards grey slightly',
#  'both doing their own thing but repel each other when they get close',
#  'the black dot appeared to still want to chase they grey dot but the grey dot was watching for it',
#  'they were drifting to top right of screen',
#  'dots were hovering in sync almost ',
#  'grey dot was following a back and forth jagged pattern, black dot was moving around slowly and smoothly in curved paths',
#  'i paid a lot of attention to gray on the left. both appear to be making patterns, maybe a letter or number at times? since i was focusing on grey it seems it drew a lowercase letter q. unsure what black drew. ',
#  "initially they went towards each other, but ultimately black 'ran away'",
#  'both dots were floating towards each other. the grey dot was moving faster than the black dot.',
#  'the grey dot was following the black dot without getting to close',
#  'the dots both moved towards each other but they did not touch each other.',
#  'the dark dot was chasing the light dot',
#  'dark dot went up and down, grey dot moved in circular motion',
#  'the black dot moved up the white dot was moving around the middle',
#  'black dot was copying the grey dot without getting close',
#  'the grey dot was writing something and the black dot was just moving around',
#  'they were chasing each other.',
#  'moving upwards random shapes',
#  'a grey dot moved erratically from right to left, a black dot moved erratically from left to right.',
#  'the gray dot was going in a circle while the black dot was going up and down until they started going toward each other',
#  'grey dot was moving similarly to a snake. black dot was the same but at a slower pace',
#  'black was zigzagging. grey was moving in circles',
#  'each dot has its own agenda, they are not aware of each other',
#  'one stayed in the middle while the other decided to go towards the bottom of the box',
#  'both individually lost',
#  'rolling around',
#  'they were moving in circles far away from each other.',
#  'one bouced off the wall',
#  'to begin with moving to the bottom left then going in different directions, seemed to be repelled from each other a little at the end',
#  'both dots stayed cenrally however the black dot slowly approached the grey dot',
#  'they were playful',
#  'they looked like they were drawn closer to each other , the grey one pulling closer to the black one but it looked as if a force was bouncing the grey one off the black dot ',
#  'gray following black black moving away from gray',
#  'the dots are moving away from each other',
#  'the two dots seem to each be taking a side of the same picture to draw.',
#  'the two dot where moving close to each other  but avioding collision',
#  'the black dot bounced off the side, the grey dot was going around in a small square in the middle',
#  'black was doing longer movement whilst grey was snake like and quite jittery',
#  'big gap between moving dots',
#  'the dots were moving on the screen independently from each other',
#  'the gray dot went in clockwise circles. the black dot went up and down repeatedly, but generally was moving up.',
#  'the dots moved along the screen pretty much independent of one another',
#  'the dots slightly circled the centre',
#  'the two dots seemed to be moving randomly and sepparatetly to each other within their own areas. they each had a different speed and pace.',
#  'the dots moved around their zones, but wandered into each other after some time.',
#  "now the grey one is sort of chasing the black one. once again it looks like some wary defense is coming from the black dot as it stands on guard trying to anticipate the grey dot's moves.",
#  'the gray dot did a circle and then went down and up in a right hook shape, the black dot moved a little to the left and right bouncing slightly up and down as it was moving. the grey dot was on the left side and the black dot was on the right side.',
#  'getting closer to each other',
#  'grey dot staying in same area black dot more free',
#  'both dots making seperate random movements',
#  'the grey dot was moving towards the black dot but getting lost on the way',
#  'both dots moving downwards slowly, with the grey dot hovering closer towards the black dot',
#  'the grey dot moved toward the bottom-right corner and then moved in a small circle, while the black dot made seemingly random movements and remained in largely the same area of the field',
#  "the grey one was moving fast and the black one couldn't make up it's mind.",
#  'the light grey was repelling the black',
#  'the grey dot is hovering around while the black dot is descending',
#  'both dots appeared to be moving randomly, with no pattern or obvious trajectory and without recognition of each other',
#  'black one moving rigidly, grey one floating',
#  'black dot was trying to get round grey dot',
#  'getting closer together whilst rotating anti clockwise',
#  'dots were not related to eachothers movements',
#  'black and grey are unrelated and black is moving down',
#  'the black dot appeared to be stalknig the grey dot from a distance before losing interest',
#  'they were moving slightly to left of screen',
#  'dots were moving almost in sync, ',
#  'black dot was following a predetermined path (spelling something about) grey was moving around randomly',
#  'grey drew a pattern on the left side of the box while black did similar on the right. both were going down as they made their pattern. greys was a bit more dynamic, with some circling and quick up/downs at one point.',
#  "they appeared to be 'doing their own thing' and not be impacted by each other until they got very close, then avoiding action was taken",
#  'the dots were both making circles and floating around the centre of the screen',
#  'it looked like the black dot could not decide whether to chase or run away from the grey dot',
#  'the dots were far apart from each other at first, then moved closer together to each other but they did not touch each other.',
#  'the dots movements were seemingly unrelated. the dark dot appeared confused',
#  'moving quickly left to right. dots didnt really move from where started',
#  'the black dot was moving toward the upper left side while the white was in the middle',
#  'both dots were staying a certain distance away from each other but moving the same way ',
#  'the grey dot was moving in the bottom right section of the square and the black was moving in the top left section',
#  'they were aimlessly going in different directions',
#  'moving largely in line up and down',
#  'a grey dot and black dot appeared to move around the screen without any certain direction.',
#  'they were both going in somewhat circular movements somewhat far from each other',
#  'both dots going around in random circles',
#  'grey moved in circles black from top to bottom',
#  'both dots meet by accident, they are not interested in each other',
#  'both just seemed to float in the middle and then one moved upward and one down',
#  'moving on their own',
#  'moving away from each other',
#  'they were staying an equal distance apart from each other while moving in a similar pattern.',
#  'just moving in circles',
#  'moving in a sort of circular way to begin with, joined together and then went in opposite directions',
#  'box black and gray dots approached and then seem to tbe repelled away from one another',
#  'they were playing ',
#  'the grey dot was moving at the top of the page and the black one was mimicking its moved but at the equal distance it started with ',
#  'black dot going towards right corner gray dot moving toward black',
#  'the dots seems to want to attack each other but on one wants to make the first move',
#  'the dots were moving in curvy lines - perhaps drawing or writing? ',
#  'both dots are fa apart from each other',
#  'the dots were floating, they began to go in small circles upwards then floated downwards',
#  'grey stayed in one position circling whilst black was moving irregular',
#  'randomly moving dots keeping a distance',
#  'the dots were moving on the screen, light dot made a circle',
#  'the black dot moved up to the top of the screen and went in small circles once it reached the top. the gray dot moved in circles on the lefthand side of the screen.',
#  'the dots moved on the screen, black dot kept to the left side and gray dot to the right',
#  'both dots moved in the circular motion away from eachother',
#  'the two dots were moving around at a medium distance to each other, sometimes the grey dot was moving towards the black to and at other times the black dot was moving towards the grey. each time a dot was trying to move close the other was moving away.',
#  'the dots stayed in their own zones and circled around some, no movement towards each other.',
#  'the dots were sort of wiggling(?) towards one another before going up and keeping a distance between them.',
#  'the grey dot made a somewhat figure of eight motion around the left side of the box and the black dot move in a sort of hooked shape nearing the grey dot in the center of the box',
#  'moving together',
#  'no pattern this time',
#  'dots were moving independantly almost in their own individual circles',
#  'the dots were floating almost simultaneously following the same path but the black one wanted to catch the grey one. it was like they were playing tag',
#  'both dots hovering parallel to each other in the central plane of the box',
#  'the grey dot moved around in the central-left area of the field while the black dot moved slowly down the right side',
#  "it looks like they're dancing",
#  'light grey moving toward black, black making small circles toward top right',
#  'the grey dot is almost going around in circles, the black dot not so',
#  'both dots appear to have been moving independently with no regard for what the other was doing. ',
#  'both floating in their own spaces',
#  'grey dot was watching the black dot',
#  'quite apart. black dot was drifting top right. left dot was moving bottom left.',
#  'moving independently ',
#  'both going in circles at different times',
#  'both dots were interested in each other but did not want to actually make contact',
#  'they were moving in small curves slightly to left',
#  'grey dot was following the black dot from a distance',
#  'black dot was travelling diagonally sw to ne, grey dot was moving around jerkly in a small area',
#  'black is going in a small circular pattern along the horizontal center line but on the left half of the box. grey was doing the similar pattern in the middle top of the box.',
#  'they were independently drawing small circles and moving, but not impacted by each other',
#  'the black dot was moving in circles near the bottom right corner while the grey was doing the same near the top left corner.',
#  'the two dots were trying to get away from each other without going to far from each other',
#  'this time the dots moved around but they were further apart from each other and they did not touch each other.',
#  'the dots movements were similar but seemingly unrelated',
#  'going around in a circle- opposing ends one top and towards bottom of screen',
#  'they were moving randomly',
#  'the dots touched then went away from each other',
#  'they were mirroring each other and moving at the same time',
#  'they were making circles']

# %%
excluded_words_list = ['dot','dots','grey','gray','black']

# %%
# word_embedding per chargeSpeed level - comparison to the whole verbs list
mean_embedding = []
for subt in np.unique(df['subtlety']):
    print('subt:', subt)
    df_subt = df.loc[df['subtlety']==subt,:]
    words_to_compare = df_subt['responses'].to_list()
    words_to_compare =  [s.lower() for s in words_to_compare]
    mean_embedding_curr = NLPmodel.encode(words_to_compare)
    mean_embedding_curr = np.nanmedian(mean_embedding_curr,axis=0) 

    similarity_with_each_word = []
    for embedding in english_words_embedding: #english words
        similarity = util.pytorch_cos_sim(mean_embedding_curr, eval(embedding))
        similarity_with_each_word.append(similarity.mean().item())
    
    similarity_with_each_word = np.array(similarity_with_each_word)

    df_temp = pd.DataFrame({'english_words':english_words, 'similarity_with_each_word':similarity_with_each_word})
    df_temp = df_temp[~df_temp['english_words'].isin(excluded_words_list)]
    df_temp = df_temp.reset_index()
    df_temp.sort_values(by='similarity_with_each_word',inplace=True, ascending=False)
    print(f"most representative words: {df_temp.iloc[:10,1].values}")
    # take top 10 words
# Out:
# subt: 0
# most representative words: ['blackball' 'blackleg' 'blacktop' 'focus' 'gaze' 'dusk' 'circle'
#  'encircle' 'clatter' 'motion']
# subt: 30
# most representative words: ['blackball' 'blackleg' 'gaze' 'clatter' 'focus' 'motion' 'circle' 'dusk'
#  'misalign' 'blacktop']
# subt: 60
# most representative words: ['blackball' 'blackleg' 'focus' 'gaze' 'blacktop' 'clatter' 'dusk' 'sight'
#  'foreground' 'circle']
# subt: 90
# most representative words: ['misalign' 'motion' 'clatter' 'focus' 'blackball' 'gaze' 'foreground'
#  'flicker' 'shift' 'circle']
# subt: 120
# most representative words: ['motion' 'misalign' 'clatter' 'focus' 'circle' 'shift' 'gaze' 'flicker'
#  'encircle' 'foreground']
# subt: 150
# most representative words: ['clatter' 'motion' 'misalign' 'circle' 'circularise' 'scatter' 'encircle'
#  'disorganize' 'circularize' 'smatter']
# subt: 180
# most representative words: ['clatter' 'motion' 'circle' 'circularize' 'circularise' 'misalign'
#  'encircle' 'scatter' 'smatter' 'move']
