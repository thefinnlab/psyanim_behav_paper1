# %% [markdown]
# - model comparison between the sigmoid and linear fits for mean subject-level playfight curves

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from func_fix_curvefit_params import *

# %%
root_folder = '../data/subtlety_playfight_data/'

# %%
df_linear = pd.read_csv(f'{root_folder}/curve_fit_subt_linear/all_params_1k_subt_mixed_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 20   30030.0   0.598494  0.203708 -30.587623   -0.188966  0.309643   0.558512
# 91   30116.0   0.662985  0.218796 -24.780629   -0.025199  0.538571   0.513571
# 108  30139.0   0.779543  0.166502 -30.802550   -0.015589  0.469643   0.507321
# 120  30153.0   0.348392  0.257026 -27.616765   -0.782451  0.229286   0.679405
# 121  30156.0   0.917034  0.115540 -39.945566   -0.144077  0.432143   0.562262
# 155  30201.0   0.807998  0.193014 -31.064216   -0.087121  0.502857   0.543810
# 184  30235.0   0.774431  0.166350 -37.659147   -0.514274  0.283571   0.645833
# 193  30246.0   0.703125  0.232067 -26.154297   -0.033333  0.535714   0.517857
# 210  30273.0   0.844404  0.144448 -36.695427   -0.135995  0.381929   0.551940
# 216  30282.0   0.819333  0.168378 -36.322218   -0.047809  0.358571   0.517143
# 230  30297.0   0.718586  0.192663 -35.376846   -0.404880  0.287857   0.616548
# 243  30312.0   0.867262  0.155150 -38.039202   -0.246717  0.380714   0.593929
# 272  30342.0   0.687273  0.222043 -28.615239   -0.112211  0.432857   0.548571
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 20    0.558512   0.131845         0.0         0.0    False
# 91    0.513571  -0.052143         0.0         0.0    False
# 108   0.507321   0.023036         0.0         0.0    False
# 120   0.679405   0.091310         0.0         0.0    False
# 121   0.562262   0.005595         0.0         0.0    False
# 155   0.543810  -0.046667         0.0         0.0    False
# 184   0.645833   0.070595         0.0         0.0    False
# 193   0.517857  -0.053571         0.0         0.0    False
# 210   0.551940   0.066131         0.0         0.0    False
# 216   0.517143   0.124286         0.0         0.0    False
# 230   0.616548   0.095595         0.0         0.0    False
# 243   0.593929   0.025357         0.0         0.0    False
# 272   0.548571   0.018571         0.0         0.0    False

# %%
df_linear = fix_obj_center(df_linear)
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped]
# Index: []

# %%
df_sigmoid = pd.read_csv(f'{root_folder}/curve_fit_subt/all_params_1k_subt_mixed.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 120  30153.0   0.493481  0.234090 -16.328702  0.196101         NaN  0.202573
# 121  30156.0   0.994711  0.029179 -45.480259  0.477303         NaN  0.096263
# 155  30201.0   0.992987  0.041195 -40.652173  0.418479         NaN  0.042199
# 184  30235.0   0.861362  0.130437 -24.516068  0.397311         NaN  0.110271
# 193  30246.0   0.925000  0.125988 -25.001943  0.491683        -inf  0.011999
# 210  30273.0   0.920315  0.103373 -27.771785  0.339515         NaN  0.130679
# 230  30297.0   0.701670  0.198372 -18.646576  0.586961         NaN  0.223000
# 243  30312.0   0.995885  0.027600 -46.259324  0.464891         NaN  0.068823
# 272  30342.0   0.811791  0.172931 -20.568092  0.435110         NaN  0.036179
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 120   0.635276   0.077545    0.523333    0.070000    False
# 121   0.585949   0.043303    0.583333    0.041667    False
# 155   0.561688   0.015000    0.561667    0.015000    False
# 184   0.616466   0.086292    0.608333    0.085000    False
# 193   0.500000   0.000000    0.500000    0.000000    False
# 210   0.529537   0.120733    0.503333    0.118333    False
# 230   0.645913   0.105600    0.625000    0.063333    False
# 243   0.613706   0.066801    0.613333    0.066667    False
# 272   0.526669   0.035000    0.526667    0.035000    False

# %%
df_sigmoid = fix_obj_center(df_sigmoid)
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped]
# Index: []

# %%
df_linear = add_new_params(df_linear)
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_linear = df_linear.loc[df_linear['range']>0,:] # remove negative amplitudes
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmoid = add_new_params(df_sigmoid)
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmoid = df_sigmoid.loc[df_sigmoid['range']>0,:] # remove negative amplitudes
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_linear.rename({'obj_center':'PSE'},inplace=True)
df_linear.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_linear.head()
# Out:
#      subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 0  30002.0   0.907661  0.122847 -26.573543    0.519615  0.962059   0.000100
# 1  30004.0   0.844820  0.158292 -24.584680    0.265723  0.908571   0.258571
# 2  30005.0   0.926674  0.103903 -31.915645    0.308072  0.820000   0.247381
# 3  30006.0   0.879632  0.148145 -22.827526    0.485476  1.000000   0.014524
# 4  30008.0   0.875484  0.122334 -31.125586    0.332598  0.647143   0.284762
#
#    bias_xmin  bias_xmax  flipped     range      bias
# 0   0.000100   0.037841    False  0.962059  0.002636
# 1   0.258571   0.000000    False  0.741429  1.000000
# 2   0.247381   0.000000    False  0.752619  1.000000
# 3   0.014524   0.000000    False  0.985476  1.000000
# 4   0.284762   0.068095    False  0.647143  0.807018

# %%
df_sigmoid.rename({'obj_center':'PSE'},inplace=True)
df_sigmoid.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_sigmoid
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 0    30002.0   0.978946  0.059585 -35.485036  0.546183    0.552951  0.103360
# 1    30004.0   0.994784  0.031310 -44.493407  0.311200    0.276896  0.076866
# 2    30005.0   0.985636  0.048320 -38.418617  0.380063    0.320583  0.115353
# 3    30006.0   0.983710  0.057399 -36.008190  0.465887    0.464823  0.079221
# 4    30008.0   0.900792  0.110236 -26.871886  0.385415    0.325118  0.172585
# ..       ...        ...       ...        ...       ...         ...       ...
# 274  30344.0   0.982096  0.049413 -38.105636  0.436226    0.361233  0.135840
# 275  30345.0   0.900182  0.135227 -24.011227  0.480709    0.475067  0.013915
# 276  30346.0   0.995720  0.031059 -44.606204  0.426850    0.426850  0.045409
# 277  30348.0   0.405749  0.219546 -17.226706  0.604790    0.729328  0.392303
# 278  30352.0   0.872976  0.124697 -25.146107  0.394443    0.392464  0.153343
#
#      bias_xmin  bias_xmax  flipped     range      bias
# 0     0.031291   0.067887    False  0.900821  0.315504
# 1     0.194061   0.000105    False  0.805834  0.999458
# 2     0.249789   0.040080    False  0.710131  0.861730
# 3     0.009433   0.001171    False  0.989396  0.889572
# 4     0.289378   0.128370    False  0.582252  0.692710
# ..         ...        ...      ...       ...       ...
# 274   0.273528   0.070757    False  0.655715  0.794480
# 275   0.166667   0.000000    False  0.833333  1.000000
# 276   0.000083   0.000003    False  0.999914  0.961644
# 277   0.355133   0.444629    False  0.200238  0.444049
# 278   0.279987   0.249770    False  0.470243  0.528520
#
# [279 rows x 12 columns]

# %%
rows = (np.isnan(df_linear['aic'])) | (np.isinf(df_linear['aic']))
df_linear.loc[rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = (np.isnan(df_sigmoid['aic'])) | (np.isinf(df_sigmoid['aic']))
df_sigmoid.loc[rows,:] # looks like a reasonable sub, but have to discard bc we need AIC
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = ~(np.isnan(df_linear['aic'])) & ~(np.isinf(df_linear['aic']))
print('size, before:', df_linear.shape)
df_linear = df_linear.loc[rows,:]
print('size, after:', df_linear.shape)
# Out:
# size, before: (279, 12)
# size, after: (279, 12)

# %%
rows = ~(np.isnan(df_sigmoid['aic'])) & ~(np.isinf(df_sigmoid['aic']))
print('size, before:', df_sigmoid.shape)
df_sigmoid = df_sigmoid.loc[rows,:]
print('size, after:', df_sigmoid.shape)
# Out:
# size, before: (279, 12)
# size, after: (279, 12)

# %%
np.where(np.isnan(df_sigmoid))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
cols = list(df_linear.columns)
cols_new = [i + '_linear' for i in cols]
df_linear.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_linear
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  \
# 0         30002.0          0.907661      0.122847  -26.573543
# 1         30004.0          0.844820      0.158292  -24.584680
# 2         30005.0          0.926674      0.103903  -31.915645
# 3         30006.0          0.879632      0.148145  -22.827526
# 4         30008.0          0.875484      0.122334  -31.125586
# ..            ...               ...           ...         ...
# 274       30344.0          0.948166      0.083946  -35.813612
# 275       30345.0          0.687504      0.218920  -19.819179
# 276       30346.0          0.796950      0.202055  -18.389020
# 277       30348.0          0.371888      0.224337  -31.227598
# 278       30352.0          0.754557      0.167684  -30.244465
#
#      obj_center_linear  slope_linear  intercept_linear  bias_xmin_linear  \
# 0             0.519615      0.962059          0.000100          0.000100
# 1             0.265723      0.908571          0.258571          0.258571
# 2             0.308072      0.820000          0.247381          0.247381
# 3             0.485476      1.000000          0.014524          0.014524
# 4             0.332598      0.647143          0.284762          0.284762
# ..                 ...           ...               ...               ...
# 274           0.323051      0.746786          0.258750          0.258750
# 275           0.297331      0.811786          0.258631          0.258631
# 276           0.446667      1.000000          0.053333          0.053333
# 277           0.714559      0.186429          0.366786          0.366786
# 278           0.434169      0.455714          0.302143          0.302143
#
#      bias_xmax_linear  flipped_linear  range_linear  bias_linear
# 0            0.037841           False      0.962059     0.002636
# 1            0.000000           False      0.741429     1.000000
# 2            0.000000           False      0.752619     1.000000
# 3            0.000000           False      0.985476     1.000000
# 4            0.068095           False      0.647143     0.807018
# ..                ...             ...           ...          ...
# 274          0.000000           False      0.741250     1.000000
# 275          0.000000           False      0.741369     1.000000
# 276          0.000000           False      0.946667     1.000000
# 277          0.446786           False      0.186429     0.450834
# 278          0.242143           False      0.455714     0.555118
#
# [279 rows x 12 columns]

# %%
cols = list(df_sigmoid.columns)
cols_new = [i + '_sigmoid' for i in cols]
df_sigmoid.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_sigmoid
# Out:
#      subID_sigmoid  r_squared_sigmoid  nrmse_sigmoid  aic_sigmoid  \
# 0          30002.0           0.978946       0.059585   -35.485036
# 1          30004.0           0.994784       0.031310   -44.493407
# 2          30005.0           0.985636       0.048320   -38.418617
# 3          30006.0           0.983710       0.057399   -36.008190
# 4          30008.0           0.900792       0.110236   -26.871886
# ..             ...                ...            ...          ...
# 274        30344.0           0.982096       0.049413   -38.105636
# 275        30345.0           0.900182       0.135227   -24.011227
# 276        30346.0           0.995720       0.031059   -44.606204
# 277        30348.0           0.405749       0.219546   -17.226706
# 278        30352.0           0.872976       0.124697   -25.146107
#
#      center_sigmoid  obj_center_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  \
# 0          0.546183            0.552951       0.103360           0.031291
# 1          0.311200            0.276896       0.076866           0.194061
# 2          0.380063            0.320583       0.115353           0.249789
# 3          0.465887            0.464823       0.079221           0.009433
# 4          0.385415            0.325118       0.172585           0.289378
# ..              ...                 ...            ...                ...
# 274        0.436226            0.361233       0.135840           0.273528
# 275        0.480709            0.475067       0.013915           0.166667
# 276        0.426850            0.426850       0.045409           0.000083
# 277        0.604790            0.729328       0.392303           0.355133
# 278        0.394443            0.392464       0.153343           0.279987
#
#      bias_xmax_sigmoid  flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0             0.067887            False       0.900821      0.315504
# 1             0.000105            False       0.805834      0.999458
# 2             0.040080            False       0.710131      0.861730
# 3             0.001171            False       0.989396      0.889572
# 4             0.128370            False       0.582252      0.692710
# ..                 ...              ...            ...           ...
# 274           0.070757            False       0.655715      0.794480
# 275           0.000000            False       0.833333      1.000000
# 276           0.000003            False       0.999914      0.961644
# 277           0.444629            False       0.200238      0.444049
# 278           0.249770            False       0.470243      0.528520
#
# [279 rows x 12 columns]

# %%
df_both =  df_linear.merge(df_sigmoid, left_on = 'subID_linear', right_on = 'subID_sigmoid')
#pd.concat([df_linear.set_index('subID_linear'),df_sigmoid.set_index('subID_sigmoid')]),axis=1)
print(df_both.shape)
# Out:
# (279, 24)

# %%
print(df_both.shape)
rows = (df_both['range_sigmoid']>0) & (df_both['slope_linear']>0)
df_both.loc[rows,:].shape
# Out:
# (279, 24)
# (279, 24)

# %%
df_both.rename(columns={'obj_center_linear':'PSE_linear','obj_center_sigmoid':'PSE_sigmoid'},inplace=True)
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         30002.0          0.907661      0.122847  -26.573543    0.519615
# 1         30004.0          0.844820      0.158292  -24.584680    0.265723
# 2         30005.0          0.926674      0.103903  -31.915645    0.308072
# 3         30006.0          0.879632      0.148145  -22.827526    0.485476
# 4         30008.0          0.875484      0.122334  -31.125586    0.332598
# ..            ...               ...           ...         ...         ...
# 274       30344.0          0.948166      0.083946  -35.813612    0.323051
# 275       30345.0          0.687504      0.218920  -19.819179    0.297331
# 276       30346.0          0.796950      0.202055  -18.389020    0.446667
# 277       30348.0          0.371888      0.224337  -31.227598    0.714559
# 278       30352.0          0.754557      0.167684  -30.244465    0.434169
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.962059          0.000100          0.000100          0.037841
# 1        0.908571          0.258571          0.258571          0.000000
# 2        0.820000          0.247381          0.247381          0.000000
# 3        1.000000          0.014524          0.014524          0.000000
# 4        0.647143          0.284762          0.284762          0.068095
# ..            ...               ...               ...               ...
# 274      0.746786          0.258750          0.258750          0.000000
# 275      0.811786          0.258631          0.258631          0.000000
# 276      1.000000          0.053333          0.053333          0.000000
# 277      0.186429          0.366786          0.366786          0.446786
# 278      0.455714          0.302143          0.302143          0.242143
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.059585   -35.485036        0.546183
# 1             False  ...       0.031310   -44.493407        0.311200
# 2             False  ...       0.048320   -38.418617        0.380063
# 3             False  ...       0.057399   -36.008190        0.465887
# 4             False  ...       0.110236   -26.871886        0.385415
# ..              ...  ...            ...          ...             ...
# 274           False  ...       0.049413   -38.105636        0.436226
# 275           False  ...       0.135227   -24.011227        0.480709
# 276           False  ...       0.031059   -44.606204        0.426850
# 277           False  ...       0.219546   -17.226706        0.604790
# 278           False  ...       0.124697   -25.146107        0.394443
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.552951       0.103360           0.031291           0.067887
# 1       0.276896       0.076866           0.194061           0.000105
# 2       0.320583       0.115353           0.249789           0.040080
# 3       0.464823       0.079221           0.009433           0.001171
# 4       0.325118       0.172585           0.289378           0.128370
# ..           ...            ...                ...                ...
# 274     0.361233       0.135840           0.273528           0.070757
# 275     0.475067       0.013915           0.166667           0.000000
# 276     0.426850       0.045409           0.000083           0.000003
# 277     0.729328       0.392303           0.355133           0.444629
# 278     0.392464       0.153343           0.279987           0.249770
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.900821      0.315504
# 1              False       0.805834      0.999458
# 2              False       0.710131      0.861730
# 3              False       0.989396      0.889572
# 4              False       0.582252      0.692710
# ..               ...            ...           ...
# 274            False       0.655715      0.794480
# 275            False       0.833333      1.000000
# 276            False       0.999914      0.961644
# 277            False       0.200238      0.444049
# 278            False       0.470243      0.528520
#
# [279 rows x 24 columns]

# %%
# rows = (df_both['amplitude_sigmoid']>0) & (df_both['slope_linear']>0)
# df_both = df_both.loc[rows,:]
# print(df_both.shape)
# df_both.head()

# %% [markdown]
# # sanity checks

# %%
def get_p(p):
    if p < .001:
        return "p < .001"
    elif p < .01:
        return f"p={p:.3f}"
    else:
        return f"p={p:.2f}"
        
def explore_correlations(df, param, ax):

    from scipy.stats import pearsonr,spearmanr

    if param == 'slope':
        x = df[param+'_linear']
        y = df['sigma_sigmoid']
    else:
        x = df[param+'_linear']
        y = df[param+'_sigmoid']
    
    rows = (~np.isnan(x)) & (~np.isnan(y)) & (~np.isinf(x)) & (~np.isinf(y))
    x = x[rows]
    y = y[rows]

    sns.scatterplot(x=x, y=y,color='k',alpha=.3,ax=ax)
    r,p = pearsonr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_p={r:.2f} ({get_p(p)})',xy=(0.05,.9),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')


    r,p = spearmanr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_s={r:.2f} ({get_p(p)})',xy=(0.05,.8),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')

# %%
comparisons = ['bias_xmin','bias_xmax','bias','PSE','range','slope','r_squared']

# %%
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         30002.0          0.907661      0.122847  -26.573543    0.519615
# 1         30004.0          0.844820      0.158292  -24.584680    0.265723
# 2         30005.0          0.926674      0.103903  -31.915645    0.308072
# 3         30006.0          0.879632      0.148145  -22.827526    0.485476
# 4         30008.0          0.875484      0.122334  -31.125586    0.332598
# ..            ...               ...           ...         ...         ...
# 274       30344.0          0.948166      0.083946  -35.813612    0.323051
# 275       30345.0          0.687504      0.218920  -19.819179    0.297331
# 276       30346.0          0.796950      0.202055  -18.389020    0.446667
# 277       30348.0          0.371888      0.224337  -31.227598    0.714559
# 278       30352.0          0.754557      0.167684  -30.244465    0.434169
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.962059          0.000100          0.000100          0.037841
# 1        0.908571          0.258571          0.258571          0.000000
# 2        0.820000          0.247381          0.247381          0.000000
# 3        1.000000          0.014524          0.014524          0.000000
# 4        0.647143          0.284762          0.284762          0.068095
# ..            ...               ...               ...               ...
# 274      0.746786          0.258750          0.258750          0.000000
# 275      0.811786          0.258631          0.258631          0.000000
# 276      1.000000          0.053333          0.053333          0.000000
# 277      0.186429          0.366786          0.366786          0.446786
# 278      0.455714          0.302143          0.302143          0.242143
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.059585   -35.485036        0.546183
# 1             False  ...       0.031310   -44.493407        0.311200
# 2             False  ...       0.048320   -38.418617        0.380063
# 3             False  ...       0.057399   -36.008190        0.465887
# 4             False  ...       0.110236   -26.871886        0.385415
# ..              ...  ...            ...          ...             ...
# 274           False  ...       0.049413   -38.105636        0.436226
# 275           False  ...       0.135227   -24.011227        0.480709
# 276           False  ...       0.031059   -44.606204        0.426850
# 277           False  ...       0.219546   -17.226706        0.604790
# 278           False  ...       0.124697   -25.146107        0.394443
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.552951       0.103360           0.031291           0.067887
# 1       0.276896       0.076866           0.194061           0.000105
# 2       0.320583       0.115353           0.249789           0.040080
# 3       0.464823       0.079221           0.009433           0.001171
# 4       0.325118       0.172585           0.289378           0.128370
# ..           ...            ...                ...                ...
# 274     0.361233       0.135840           0.273528           0.070757
# 275     0.475067       0.013915           0.166667           0.000000
# 276     0.426850       0.045409           0.000083           0.000003
# 277     0.729328       0.392303           0.355133           0.444629
# 278     0.392464       0.153343           0.279987           0.249770
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.900821      0.315504
# 1              False       0.805834      0.999458
# 2              False       0.710131      0.861730
# 3              False       0.989396      0.889572
# 4              False       0.582252      0.692710
# ..               ...            ...           ...
# 274            False       0.655715      0.794480
# 275            False       0.833333      1.000000
# 276            False       0.999914      0.961644
# 277            False       0.200238      0.444049
# 278            False       0.470243      0.528520
#
# [279 rows x 24 columns]

# %%
nrows = 3
ncols = 3
fig,axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (10,10))
for i,param in enumerate(comparisons):
    r = int(np.floor(i/ncols))
    c = i%ncols
    ax = axs[r,c]
    explore_correlations(df_both, param, ax)
    ax.set_title(param,fontweight='bold')
    if param == 'slope':
        ax.set_title ('slope vs. inv. sigma',fontweight='bold')

df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

ax = axs[2,1]
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-100,0)

ax = axs[2,2]
ax.axis('off')

plt.suptitle('Linear (X) vs. sigmoid(Y) fits (pf sess1)', fontweight='bold', fontsize=16)
plt.tight_layout()
# plt.savefig('../results/subtlety_playfight_mixed/linear_vs_sigmoid_mixedbatch.png',dpi=300,bbox_inches='tight')

# %%
df_both.to_csv('../data/subtlety_playfight_data/curvefits_subt_linear_sigmoid_params_mixedbatch.csv')

# %%
from scipy import stats

# %%
s=16 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

# %%
df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

fig,ax = plt.subplots(figsize=(4,4),nrows=1,ncols=1)
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-200,0)
plt.savefig('../results/subtlety_playfight_mixed/AIC_subt_linear_vs_sigmoid.png')

# %%
stats.ttest_rel(df_both['aic_sigmoid'],df_both['aic_linear'])
# Out:
# Ttest_relResult(statistic=-10.991713568050894, pvalue=1.4122819661184662e-23)

# %%
df_both['aic_sigmoid'].mean(),df_both['aic_linear'].mean(), df_both['aic_sigmoid'].std(),df_both['aic_linear'].std()
# Out:
# (-36.652264665546724, -28.8148005701867, 10.088567290444367, 5.490450741178328)

# %%
df_both['aic_diff'] = df_both['aic_sigmoid'] - df_both['aic_linear']
# len(np.where(df_both['aic_diff']>0)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<0)[0])
len(np.where(df_both['aic_diff']>5)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-5)[0])
# Out:
# (34, 0, 158)

# %%
len(np.where(df_both['aic_diff']>10)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-10)[0])
# Out:
# (9, 0, 104)
