# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
path_to_add = os.path.abspath('../')
print('path_to_add:',path_to_add)
sys.path.append(path_to_add)
from func_fix_curvefit_params import *
from general_utility_functions import *
# Out:
# path_to_add: /Users/f0053cz/Dartmouth College Dropbox/Rekha Sreekumar Varrier/postdoc_Dartmouth/psyanim_behav_paper/version2/scripts_data_for_beh_paper/code

# %%
root_folder = '../../data/playfight_data/'

# %%
curvefit_ses1 = pd.read_csv(f'{root_folder}/curve_fit_pf_ses1_linear/all_params_1k_play_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(curvefit_ses1['obj_center'])) | \
      (np.isinf(curvefit_ses1['obj_center'])) | \
    (curvefit_ses1['obj_center']<0)
curvefit_ses1.loc[bad_rows,:]# has bad subs
# Out:
#        subID     r_squared     nrmse        aic  obj_center     slope  \
# 13   26013.0  1.446321e-01  0.302901 -38.377043   -0.298088  0.059786
# 14   26014.0  1.110223e-16  0.303568 -40.518924        -inf  0.000000
# 39   26044.0  4.185987e-01  0.267964 -35.740912   -0.331015  0.148929
# 67   26075.0  8.876873e-01  0.107887 -49.497133   -1.128770  0.184714
# 87   26096.0  1.186676e-01  0.308373 -32.864250   -1.760486  0.079095
# 108  26118.0  6.104091e-01  0.210471 -28.835251   -0.119196  0.359786
# 111  26123.0  8.546758e-01  0.120805 -46.787886   -0.584185  0.193357
# 148  26163.0  5.557648e-01  0.216688 -30.993227   -0.003370  0.275571
# 153  26169.0  7.542010e-01  0.181101 -41.972309   -0.208243  0.197000
# 175  26195.0 -2.220446e-16  0.309204 -30.304180         inf  0.000000
# 178  26198.0  2.821719e-01  0.280972 -39.169052   -0.096462  0.086143
# 201  26223.0  1.413701e-01  0.315443 -38.806200   -5.345193  0.057214
# 209  26233.0  8.894991e-01  0.110775 -42.625005   -0.098911  0.304548
# 235  26261.0  8.333432e-01  0.154608 -43.397602   -1.329560  0.227143
# 241  26269.0  7.306614e-01  0.210368 -27.223951   -0.135319  0.531167
# 246  26274.0  8.368666e-01  0.141974 -41.921882   -1.104359  0.255643
# 247  26275.0  8.711468e-01  0.147580 -46.794556   -0.023268  0.207214
# 259  26287.0  7.575584e-01  0.142867 -39.063244   -0.347052  0.244714
# 268  26296.0  5.071970e-01  0.227558 -45.837099   -0.529703  0.086571
# 269  26297.0  3.809776e-03  0.276735 -45.047567  -39.631439  0.005583
# 285  26314.0  9.019037e-01  0.103671 -56.294614   -0.910112  0.122595
# 298  26328.0  8.629261e-02  0.298836 -66.995296   -5.475301  0.005786
# 303  26333.0  9.013999e-01  0.118162 -39.785718   -0.347788  0.397524
# 305  26335.0  1.032762e-04  0.313363 -38.166630  -10.261943  0.001500
# 306  26336.0  4.127911e-01  0.257820 -41.351132   -1.850725  0.098571
#
#      intercept  bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 13    0.517821   0.517821   0.422393         0.0         0.0    False
# 14    0.647714   0.647714   0.352286         0.0         0.0    False
# 39    0.549298   0.549298   0.301774         0.0         0.0    False
# 67    0.708500   0.708500   0.106786         0.0         0.0    False
# 87    0.639246   0.639246   0.281659         0.0         0.0    False
# 108   0.542885   0.542885   0.097329         0.0         0.0    False
# 111   0.612956   0.612956   0.193687         0.0         0.0    False
# 148   0.500929   0.500929   0.223500         0.0         0.0    False
# 153   0.541024   0.541024   0.261976         0.0         0.0    False
# 175        NaN   0.620556   0.379444         1.0         1.0     True
# 178        NaN   0.491690   0.594452         1.0         1.0     True
# 201   0.805821   0.805821   0.136964         0.0         0.0    False
# 209   0.530123   0.530123   0.165329         0.0         0.0    False
# 235   0.802000   0.802000  -0.029143         0.0         0.0    False
# 241   0.571877   0.571877  -0.103044         0.0         0.0    False
# 246   0.782321   0.782321  -0.037964         0.0         0.0    False
# 247   0.504821   0.504821   0.287964         0.0         0.0    False
# 259   0.584929   0.584929   0.170357         0.0         0.0    False
# 268   0.545857   0.545857   0.367571         0.0         0.0    False
# 269   0.721276   0.721276   0.273141         0.0         0.0    False
# 285   0.611575   0.611575   0.265829         0.0         0.0    False
# 298   0.531679   0.531679   0.462536         0.0         0.0    False
# 303   0.638254   0.638254  -0.035778         0.0         0.0    False
# 305   0.515393   0.515393   0.483107         0.0         0.0    False
# 306   0.682429   0.682429   0.219000         0.0         0.0    False

# %%
curvefit_ses1 = fix_obj_center(curvefit_ses1)
bad_rows = (np.isnan(curvefit_ses1['obj_center'])) | \
      (np.isinf(curvefit_ses1['obj_center'])) | \
    (curvefit_ses1['obj_center']<0)
curvefit_ses1.loc[bad_rows,:] # bad subs bc of obj_center removed. rest will be removed with neg amplitudes
# Out:
#        subID     r_squared     nrmse        aic  obj_center     slope  \
# 55   26060.0  7.984686e-02  0.302446 -38.842548         NaN  0.041429
# 150  26165.0  3.891542e-01  0.232675 -33.504478         NaN  0.164357
# 173  26193.0  9.444549e-01  0.081346 -31.168611         NaN  1.000000
# 175  26195.0 -2.220446e-16  0.309204 -30.304180         NaN  0.000000
# 178  26198.0  2.821719e-01  0.280972 -39.169052         NaN  0.086143
# 227  26253.0  5.391453e-01  0.254507 -36.419557         NaN  0.180857
# 257  26285.0  2.157118e-02  0.348544 -42.059395         NaN  0.016595
# 308  26338.0  5.491162e-01  0.228676 -37.415560         NaN  0.171857
#
#      intercept  bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 55         NaN   0.754571   0.286857         1.0         1.0     True
# 150        NaN   0.908607   0.255750         1.0         1.0     True
# 173        NaN   1.028000   0.972000         1.0         1.0     True
# 175        NaN   0.620556   0.379444         1.0         1.0     True
# 178        NaN   0.491690   0.594452         1.0         1.0     True
# 227        NaN   0.561286   0.619571         1.0         1.0     True
# 257        NaN   0.521615   0.494980         1.0         1.0     True
# 308        NaN   0.928500   0.243357         1.0         1.0     True

# %%
curvefit_ses2 =  pd.read_csv(f'{root_folder}/curve_fit_pf_ses2_linear/all_params_1k_play_linear.csv')
bad_rows = (np.isnan(curvefit_ses2['obj_center'])) | \
      (np.isinf(curvefit_ses2['obj_center'])) | \
    (curvefit_ses2['obj_center']<0)
curvefit_ses2.loc[bad_rows,:] # has bad rows
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 5    26007.0   0.583599  0.255097 -24.829610   -0.019885  0.453000   0.509008
# 6    26008.0   0.803762  0.155699 -42.858682   -0.854731  0.213643   0.682607
# 24   26037.0   0.001659  0.307259 -34.303468   -9.950441  0.007929   0.578893
# 41   26060.0   0.823969  0.151992 -38.196440   -0.087761  0.318643   0.527964
# 63   26089.0   0.750620  0.178842 -34.875283   -0.010548  0.323929   0.503417
# 70   26096.0   0.203453  0.317590 -29.517473   -0.284030  0.138357   0.539298
# 73   26099.0   0.470037  0.262099 -50.282789   -0.010378  0.058500   0.500607
# 120  26161.0   0.867970  0.117954 -43.276108   -0.474986  0.262714   0.624786
# 122  26163.0   0.348776  0.258420 -41.318617   -1.340051  0.086238   0.615563
# 124  26167.0   0.860705  0.129607 -47.709068   -0.043495  0.185571   0.508071
# 136  26182.0   0.000000  0.305028 -26.694628        -inf  0.000000        NaN
# 175  26233.0   0.218219  0.315461 -34.614399   -0.502132  0.100500   0.550464
# 191  26255.0   0.547377  0.198801 -34.878049   -0.032591  0.205286   0.506690
# 194  26258.0   0.517401  0.226980 -39.015402   -0.769547  0.143833   0.610687
# 197  26261.0   0.953754  0.073058 -43.532981   -0.086617  0.456857   0.539571
# 209  26274.0   0.856206  0.137699 -37.753008   -0.433162  0.370952   0.660683
# 210  26275.0   0.947690  0.085336 -50.970908   -0.055429  0.251714   0.513952
# 219  26285.0   0.374175  0.233202 -42.135603   -0.021884  0.085952   0.501881
# 228  26297.0   0.603597  0.193393 -42.326574   -1.145492  0.135310   0.654996
# 251  26328.0   0.129393  0.277919 -75.845815  -23.685140  0.003857   0.591357
# 254  26333.0   0.873958  0.113684 -49.544327   -1.606969  0.172429   0.777087
# 257  26336.0   0.563570  0.232529 -33.465893   -0.360883  0.234643   0.584679
# 259  26338.0   0.057550  0.318760 -31.247547   -1.308841  0.059786   0.578250
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 5     0.509008   0.037992         0.0         0.0    False
# 6     0.682607   0.103750         0.0         0.0    False
# 24    0.578893   0.413179         0.0         0.0    False
# 41    0.527964   0.153393         0.0         0.0    False
# 63    0.503417   0.172655         0.0         0.0    False
# 70    0.539298   0.322345         0.0         0.0    False
# 73    0.500607   0.440893         0.0         0.0    False
# 120   0.624786   0.112500         0.0         0.0    False
# 122   0.615563   0.298198         0.0         0.0    False
# 124   0.508071   0.306357         0.0         0.0    False
# 136   0.499143   0.500857         1.0         1.0     True
# 175   0.550464   0.349036         0.0         0.0    False
# 191   0.506690   0.288024         0.0         0.0    False
# 194   0.610687   0.245480         0.0         0.0    False
# 197   0.539571   0.003571         0.0         0.0    False
# 209   0.660683  -0.031635         0.0         0.0    False
# 210   0.513952   0.234333         0.0         0.0    False
# 219   0.501881   0.412167         0.0         0.0    False
# 228   0.654996   0.209694         0.0         0.0    False
# 251   0.591357   0.404786         0.0         0.0    False
# 254   0.777087   0.050484         0.0         0.0    False
# 257   0.584679   0.180679         0.0         0.0    False
# 259   0.578250   0.361964         0.0         0.0    False

# %%
curvefit_ses2.loc[curvefit_ses2['bias_xmax']<0,:].shape # has rows with neg bias_xmax
# Out:
# (20, 12)

# %%
curvefit_ses2 = fix_obj_center(curvefit_ses2)
bad_rows = (np.isnan(curvefit_ses2['obj_center'])) | \
      (np.isinf(curvefit_ses2['obj_center'])) | \
    (curvefit_ses2['obj_center']<0)
curvefit_ses2.loc[bad_rows,:] # bad subs bc of obj_center removed
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 46   26067.0   0.284428  0.290743 -54.685573         NaN  0.028595        NaN
# 126  26169.0   0.397730  0.258664 -34.969223         NaN  0.150714        NaN
# 136  26182.0   0.000000  0.305028 -26.694628         NaN  0.000000        NaN
# 145  26193.0   0.856144  0.133840 -27.144130         NaN  0.791238        NaN
# 199  26263.0   0.854329  0.118509 -37.162888         NaN  0.384000        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 46    0.534440   0.494155         1.0         1.0     True
# 126   0.580119   0.570595         1.0         1.0     True
# 136   0.499143   0.500857         1.0         1.0     True
# 145   0.913524   0.877714         1.0         1.0     True
# 199   0.791286   0.592714         1.0         1.0     True

# %%
curvefit_ses1 = add_new_params(curvefit_ses1)
curvefit_ses1.loc[curvefit_ses1['range']<0,:] # has neg range rows
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 55   26060.0   0.079847  0.302446 -38.842548         NaN  0.041429        NaN
# 150  26165.0   0.389154  0.232675 -33.504478         NaN  0.164357        NaN
# 173  26193.0   0.944455  0.081346 -31.168611         NaN  1.000000        NaN
# 178  26198.0   0.282172  0.280972 -39.169052         NaN  0.086143        NaN
# 227  26253.0   0.539145  0.254507 -36.419557         NaN  0.180857        NaN
# 257  26285.0   0.021571  0.348544 -42.059395         NaN  0.016595        NaN
# 308  26338.0   0.549116  0.228676 -37.415560         NaN  0.171857        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 55    0.754571   0.286857         1.0         1.0     True -0.041429  0.724554
# 150   0.908607   0.255750         1.0         1.0     True -0.164357  0.780351
# 173   1.028000   0.972000         1.0         1.0     True -1.000000  0.514000
# 178   0.491690   0.594452         1.0         1.0     True -0.086143  0.452694
# 227   0.561286   0.619571         1.0         1.0     True -0.180857  0.475321
# 257   0.521615   0.494980         1.0         1.0     True -0.016595  0.513100
# 308   0.928500   0.243357         1.0         1.0     True -0.171857  0.792332

# %%
curvefit_ses1 = curvefit_ses1.loc[curvefit_ses1['range']>0,:] # remove negative amplitudes
curvefit_ses1.loc[curvefit_ses1['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(curvefit_ses1['obj_center'])) | \
      (np.isinf(curvefit_ses1['obj_center'])) | \
    (curvefit_ses1['obj_center']<0)
curvefit_ses1.loc[bad_rows,:]# all bad subs removed
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
curvefit_ses1.loc[curvefit_ses1['bias_xmax']<0,:].shape # neg bias rows removed
# Out:
# (0, 14)

# %%
curvefit_ses2 = add_new_params(curvefit_ses2)
curvefit_ses2.loc[curvefit_ses2['range']<0,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 46   26067.0   0.284428  0.290743 -54.685573         NaN  0.028595        NaN
# 126  26169.0   0.397730  0.258664 -34.969223         NaN  0.150714        NaN
# 145  26193.0   0.856144  0.133840 -27.144130         NaN  0.791238        NaN
# 199  26263.0   0.854329  0.118509 -37.162888         NaN  0.384000        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 46    0.534440   0.494155         1.0         1.0     True -0.028595  0.519583
# 126   0.580119   0.570595         1.0         1.0     True -0.150714  0.504138
# 145   0.913524   0.877714         1.0         1.0     True -0.791238  0.509996
# 199   0.791286   0.592714         1.0         1.0     True -0.384000  0.571738

# %%
curvefit_ses2 = curvefit_ses2.loc[curvefit_ses2['range']>0,:] # remove negative amplitudes
curvefit_ses2.loc[curvefit_ses2['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(curvefit_ses2['obj_center'])) | \
      (np.isinf(curvefit_ses2['obj_center'])) | \
    (curvefit_ses2['obj_center']<0)
curvefit_ses2.loc[bad_rows,:]# all bad subs removed
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
curvefit_ses2.loc[curvefit_ses2['bias_xmax']<0,:].shape # neg bias rows removed
# Out:
# (0, 14)

# %%
curvefit_ses1.rename(columns={'obj_center':'PSE'},inplace=True)
curvefit_ses2.rename(columns={'obj_center':'PSE'},inplace=True)
# Out:
# /Users/f0053cz/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# def return_minmax(df,param):
#     # print min nax values of entered params to sanity check curve fit params, most should be within 0 and 1
#     print(f'{param}: min={df[param].describe()["min"]:.2f}, max={df[param].describe()["max"]:.2f}')

# %%
return_minmax(curvefit_ses1,'PSE')
return_minmax(curvefit_ses1,'range')
return_minmax(curvefit_ses1,'bias')

return_minmax(curvefit_ses2,'PSE')
return_minmax(curvefit_ses2,'range')
return_minmax(curvefit_ses2,'bias')
# Out:
# PSE: min=0.00, max=1.00
# range: min=0.00, max=1.00
# bias: min=0.00, max=1.00
# PSE: min=0.00, max=1.00
# range: min=0.00, max=1.00
# bias: min=0.00, max=1.00

# %%
cmap = 'BrBG'#'RdBu_r'

# %%
cols = ['PSE','slope','bias']

# %%
fig,axs = plt.subplots(nrows=1,ncols = 2, figsize=(6,3))

ax = axs[0]
sns.heatmap(curvefit_ses1.loc[:,cols].corr(),vmin=-1,vmax=1,annot=True,cbar=False,cmap=cmap,ax=ax, fmt = '.2f',annot_kws={"size": 12})
ax.set_title('playfight session 1',fontweight='bold')

ax = axs[1]
sns.heatmap(curvefit_ses2.loc[:,cols].corr(),vmin=-1,vmax=1,annot=True,cbar=False,cmap=cmap,ax=ax, fmt = '.2f',annot_kws={"size": 12})
ax.set_title('playfight session 2',fontweight='bold')
ax.set_yticks([])

plt.tight_layout()
plt.savefig('../../results/playfight/curvefit_covar_allcols_playfight.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # merge them and plot ICC

# %%
from general_utility_functions import *
from scipy import stats

# %%
bothsess = curvefit_ses1.loc[:,['subID']+cols].merge(curvefit_ses2.loc[:,['subID']+cols],how='inner',on='subID',suffixes = ['_ses1','_ses2'])
bothsess
# Out:
#        subID  PSE_ses1  slope_ses1  bias_ses1  PSE_ses2  slope_ses2  bias_ses2
# 0    26000.0  0.290396    0.709500   1.000000  0.124705    0.477381   0.842809
# 1    26001.0  0.405999    0.386857   0.559309  0.495616    0.521357   0.504775
# 2    26003.0  0.485000    1.000000   1.000000  0.507930    0.984191   0.006326
# 3    26004.0  0.473363    0.579214   0.536666  0.202595    0.214714   0.581317
# 4    26005.0  0.579699    0.570000   0.394352  0.369992    0.870643   1.000000
# ..       ...       ...         ...        ...       ...         ...        ...
# 247  26343.0  0.398139    0.625500   0.670132  0.427334    0.676286   0.651809
# 248  26344.0  0.376172    0.967929   1.000000  0.358499    0.895500   1.000000
# 249  26346.0  0.488752    0.609643   0.517566  0.546918    0.523714   0.448410
# 250  26347.0  0.175750    0.235905   0.600108  0.273320    0.282476   0.589240
# 251  26348.0  0.582796    0.502286   0.416443  0.381822    0.791786   0.949400
#
# [252 rows x 7 columns]

# %%
bothsess[['PSE_ses1','PSE_ses2']].describe()
# Out:
#          PSE_ses1    PSE_ses2
# count  252.000000  252.000000
# mean     0.379041    0.374073
# std      0.179439    0.178565
# min      0.000000    0.000000
# 25%      0.304314    0.285872
# 50%      0.401765    0.398329
# 75%      0.489411    0.484889
# max      1.000000    1.000000

# %%
np.where(np.isnan(bothsess))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
fig, axs = plt.subplots(nrows=1, ncols=len(cols), figsize=(3*len(cols),3))  # Adjusting subplot size to make plots square
for i, item in enumerate(cols):
    ax = axs[i] #axs[i]
    sns.scatterplot(data=bothsess, x=item + '_ses1', y=item + '_ses2', ax=ax, color = 'tab:red',alpha=0.5, marker = '.')
    # ax.set_aspect('equal')  # Ensures same scale on x and y axes
    # Adding a diagonal line from the minimum to maximum values
    limits = [min(ax.get_xlim()[0], ax.get_ylim()[0]), max(ax.get_xlim()[1], ax.get_ylim()[1])]
    ax.plot(limits, limits, 'k--', zorder=0, alpha = .2)  # 'k--' specifies a black dotted line
    ax.set_xlim(limits)
    ax.set_ylim(limits)
    ticks = np.arange(limits[0],limits[1]*1.01,(limits[1]-limits[0])/3)
    ticks = [np.round(i,1) for i in ticks]
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    x,y =  bothsess[item + '_ses1'],bothsess[item + '_ses2']
    rows = ~(np.isnan(x)) & ~(np.isnan(y)) & ~(np.isinf(x)) & ~(np.isinf(y))
    x = x[rows]
    y = y[rows]
    r_p,p_p = stats.pearsonr(x,y)
    r_s,p_s = stats.spearmanr(x,y)
    ax.annotate(f'r={r_p:.2f}\n({get_p(p_p)})', xy = (.05,.75),xycoords='axes fraction')
    ax.set_title(item, fontweight='bold') #item,fontweight='bold')
    
    # ax.set_title(meaningful_names[item], fontweight='bold') #item,fontweight='bold')
    ax.set_xlabel('test')
    ax.set_ylabel('retest')

plt.tight_layout()
plt.savefig('../../results/playfight/ICC_playfight.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# # supp rows

# %%
curvefit_ses1_extra = curvefit_ses1.drop(columns=['bias_lower','bias_upper']).rename(columns={'bias_xmin':'lb','bias_xmax':'ub'})
curvefit_ses2_extra = curvefit_ses2.drop(columns=['bias_lower','bias_upper']).rename(columns={'bias_xmin':'lb','bias_xmax':'ub'})

# %%
curvefit_ses1_extra.columns
# Out:
# Index(['subID', 'r_squared', 'nrmse', 'aic', 'PSE', 'slope', 'intercept', 'lb',
#        'ub', 'flipped', 'range', 'bias'],
#       dtype='object')

# %%
supp_cols = ['range','lb','ub','aic']

# %%
bothsess_extra = curvefit_ses1_extra.loc[:,['subID']+supp_cols].merge(curvefit_ses2_extra.loc[:,['subID']+supp_cols],how='inner',on='subID',suffixes = ['_ses1','_ses2'])
bothsess_extra
# Out:
#        subID  range_ses1   lb_ses1   ub_ses1   aic_ses1  range_ses2   lb_ses2  \
# 0    26000.0    0.706036  0.293964  0.000000 -35.492508    0.477381  0.440468
# 1    26001.0    0.386857  0.342937  0.270206 -35.444795    0.521357  0.241607
# 2    26003.0    0.985000  0.015000  0.000000 -26.826571    0.984191  0.000100
# 3    26004.0    0.579214  0.225821  0.194964 -43.866039    0.214714  0.456500
# 4    26005.0    0.570000  0.169571  0.260429 -38.116158    0.822131  0.177869
# ..       ...         ...       ...       ...        ...         ...       ...
# 247  26343.0    0.625500  0.250964  0.123536 -32.029021    0.676286  0.211000
# 248  26344.0    0.864107  0.135893  0.000000 -25.061996    0.821036  0.178964
# 249  26346.0    0.609643  0.202036  0.188321 -30.751435    0.523714  0.213571
# 250  26347.0    0.235905  0.458540  0.305556 -43.857648    0.282476  0.422794
# 251  26348.0    0.502286  0.207270  0.290444 -34.010792    0.791786  0.197679
#
#       ub_ses2   aic_ses2
# 0    0.082151 -39.241819
# 1    0.237036 -30.664804
# 2    0.015709 -31.126282
# 3    0.328786 -45.074530
# 4    0.000000 -40.003157
# ..        ...        ...
# 247  0.112714 -35.254970
# 248  0.000000 -31.778106
# 249  0.262714 -39.407191
# 250  0.294730 -47.646641
# 251  0.010536 -29.326493
#
# [252 rows x 9 columns]

# %%
fig, axs = plt.subplots(nrows=1, ncols=len(supp_cols), figsize=(3*len(supp_cols),3))  # Adjusting subplot size to make plots square
for i, item in enumerate(supp_cols):
    ax = axs[i] #axs[i]
    sns.scatterplot(data=bothsess_extra, x=item + '_ses1', y=item + '_ses2', ax=ax, color = 'tab:red',alpha=0.5, marker = '.')
    # ax.set_aspect('equal')  # Ensures same scale on x and y axes
    # Adding a diagonal line from the minimum to maximum values
    limits = [min(ax.get_xlim()[0], ax.get_ylim()[0]), max(ax.get_xlim()[1], ax.get_ylim()[1])]
    ax.plot(limits, limits, 'k--', zorder=0, alpha = .2)  # 'k--' specifies a black dotted line
    ax.set_xlim(limits)
    ax.set_ylim(limits)
    ticks = np.arange(limits[0],limits[1]*1.01,(limits[1]-limits[0])/3)
    ticks = [np.round(i,1) for i in ticks]
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    x,y =  bothsess_extra[item + '_ses1'],bothsess_extra[item + '_ses2']
    rows = ~(np.isnan(x)) & ~(np.isnan(y)) & ~(np.isinf(x)) & ~(np.isinf(y))
    x = x[rows]
    y = y[rows]
    r_p,p_p = stats.pearsonr(x,y)
    r_s,p_s = stats.spearmanr(x,y)
    ax.annotate(f'r={r_p:.2f}\n({get_p(p_p)})', xy = (.05,.75),xycoords='axes fraction')
    ax.set_title(item, fontweight='bold') #item,fontweight='bold')
    
    # ax.set_title(meaningful_names[item], fontweight='bold') #item,fontweight='bold')
    ax.set_xlabel('test')
    ax.set_ylabel('retest')

plt.tight_layout()
plt.savefig('../../results/playfight/ICC_playfight_extra.png',dpi=300,bbox_inches='tight')
