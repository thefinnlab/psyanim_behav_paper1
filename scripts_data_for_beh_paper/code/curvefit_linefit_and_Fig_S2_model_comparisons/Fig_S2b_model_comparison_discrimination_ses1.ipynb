# %% [markdown]
# - model comparison between the sigmoid and linear fits for mean subject-level playfight curves

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
path_to_add = os.path.abspath('../')
sys.path.append(path_to_add)
from func_fix_curvefit_params import *

# %%
root_folder = '../../data/playfight_data/'

# %%
df_linear = pd.read_csv(f'{root_folder}/curve_fit_aggressiveness_ses1_linear/all_params_1k_fight_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
# df_linear = pd.read_csv(f'{root_folder}/curve_fit_pf_ses1_linear/all_params_1k_play_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID     r_squared     nrmse        aic  obj_center     slope  \
# 14   26014.0  0.000000e+00  0.303568 -40.518924         inf  0.000000
# 55   26060.0  7.984686e-02  0.302446 -38.842548   -5.144827  0.041429
# 70   26079.0  3.750000e-01  0.276642 -18.983900   -0.388889  0.450000
# 150  26165.0  3.891542e-01  0.232675 -33.504478   -1.486093  0.164357
# 175  26195.0 -2.220446e-16  0.309204 -30.304180        -inf  0.000000
# 257  26285.0  2.157118e-02  0.348544 -42.059395   -0.302487  0.016595
# 308  26338.0  5.491162e-01  0.228676 -37.415560   -1.493350  0.171857
#
#      intercept  bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 14    0.352286   0.352286   0.647714         0.0         0.0    False
# 55         NaN   0.286857   0.754571         1.0         1.0     True
# 70    0.675000   0.675000  -0.125000         0.0         0.0    False
# 150        NaN   0.255750   0.908607         1.0         1.0     True
# 175        NaN   0.379444   0.620556         1.0         1.0     True
# 257        NaN   0.494980   0.521615         1.0         1.0     True
# 308        NaN   0.243357   0.928500         1.0         1.0     True

# %%
df_linear = fix_obj_center(df_linear)
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID     r_squared     nrmse        aic  obj_center     slope  \
# 55   26060.0  7.984686e-02  0.302446 -38.842548         NaN  0.041429
# 150  26165.0  3.891542e-01  0.232675 -33.504478         NaN  0.164357
# 173  26193.0  9.428737e-01  0.083005 -30.885994         NaN  0.962103
# 175  26195.0 -2.220446e-16  0.309204 -30.304180         NaN  0.000000
# 178  26198.0  2.821719e-01  0.280972 -39.169052         NaN  0.086143
# 227  26253.0  5.391453e-01  0.254507 -36.419557         NaN  0.180857
# 257  26285.0  2.157118e-02  0.348544 -42.059395         NaN  0.016595
# 308  26338.0  5.491162e-01  0.228676 -37.415560         NaN  0.171857
#
#      intercept  bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 55         NaN   0.286857   0.754571         1.0         1.0     True
# 150        NaN   0.255750   0.908607         1.0         1.0     True
# 173        NaN   0.962203   0.999900         1.0         1.0     True
# 175        NaN   0.379444   0.620556         1.0         1.0     True
# 178        NaN   0.594452   0.491690         1.0         1.0     True
# 227        NaN   0.619571   0.561286         1.0         1.0     True
# 257        NaN   0.494980   0.521615         1.0         1.0     True
# 308        NaN   0.243357   0.928500         1.0         1.0     True

# %%
df_sigmoid = pd.read_csv(f'{root_folder}/curve_fit_aggressiveness_ses1_sigmoid/all_params_1k_play.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
df_sigmoid.head()
# Out:
#      subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 0  26000.0   0.947342  0.086740 -30.227716  0.552453    0.685848  0.156243
# 1  26001.0   0.909476  0.117844 -25.937516  0.313334    0.416187  0.126279
# 2  26002.0   0.951829  0.099103 -28.362317  0.270637    0.315242  0.052594
# 3  26003.0   0.961148  0.076137 -32.053098  0.534390    0.534390  0.138639
# 4  26004.0   0.941723  0.075045 -32.255374  0.446652    0.500804  0.226720
#
#    bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 0   0.053769   0.337762       0.035    0.302000    False
# 1   0.250293   0.377311       0.219    0.375556    False
# 2   0.085457   0.321001       0.082    0.321000    False
# 3   0.020744   0.033620       0.000    0.000000    False
# 4   0.224223   0.272558       0.147    0.222000    False

# %%
df_sigmoid = pd.read_csv(f'{root_folder}/curve_fit_aggressiveness_ses1_sigmoid/all_params_1k_play.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
# 209  1.968473e-01   0.542524    0.171000     0.50600    False
# 235  2.021029e-03   0.796265    0.000000     0.78100    False
# 246  2.193082e-04   0.753313    0.000000     0.73500    False
# 247  2.948610e-01   0.526310    0.294000     0.52600    False
# 257  4.991108e-01   0.527065    0.538889     0.56800     True
# 259  1.835008e-01   0.585506    0.142000     0.53500    False
# 268  3.397862e-01   0.548019    0.327000     0.54800    False
# 269  2.628145e-01   0.710655    0.225000     0.66625    False
# 285  2.771387e-01   0.617385    0.267000     0.60300    False
# 298  4.624994e-01   0.532190    0.452000     0.52700    False
# 303  1.299035e-02   0.633324    0.011111     0.61800    False
# 304  1.840068e-01   0.534000    0.184000     0.53400    False
# 306  2.239634e-01   0.686750    0.199000     0.64900    False
# 308  2.404306e-01   0.934856    0.256000     0.97100     True

# %%
df_sigmoid = fix_obj_center(df_sigmoid)
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 55   26060.0   0.078102  0.302751 -12.727843  0.521393         NaN  0.947683
# 150  26165.0   0.723191  0.221893 -17.077861  0.862604         NaN  0.034870
# 173  26193.0   0.921151  0.097332 -28.614746  0.549580         NaN  0.194376
# 175  26195.0  -0.088820  0.322730 -11.833154  0.605310         NaN  1.000000
# 178  26198.0   0.264526  0.284416 -13.602432  0.480350         NaN  0.489002
# 227  26253.0   0.872084  0.153301 -22.254919  0.708564         NaN  0.023282
# 257  26285.0   0.014345  0.349880 -10.702324  0.476973         NaN  1.000000
# 308  26338.0   0.576472  0.222093 -17.065238  0.389461         NaN  0.234049
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 55    0.286664   0.753297    0.345000       0.810     True
# 150   0.362374   0.927000    0.368000       0.927     True
# 173   0.910566   0.941307    1.000000       0.997     True
# 175   0.411678   0.656477    0.524000       0.755     True
# 178   0.589142   0.487593    0.631000       0.532     True
# 227   0.664999   0.554000    0.665000       0.554     True
# 257   0.499111   0.527065    0.538889       0.568     True
# 308   0.240431   0.934856    0.256000       0.971     True

# %%
df_linear = add_new_params(df_linear)
df_linear.loc[df_linear['range']<0,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 55   26060.0   0.079847  0.302446 -38.842548         NaN  0.041429        NaN
# 150  26165.0   0.389154  0.232675 -33.504478         NaN  0.164357        NaN
# 173  26193.0   0.942874  0.083005 -30.885994         NaN  0.962103        NaN
# 178  26198.0   0.282172  0.280972 -39.169052         NaN  0.086143        NaN
# 227  26253.0   0.539145  0.254507 -36.419557         NaN  0.180857        NaN
# 257  26285.0   0.021571  0.348544 -42.059395         NaN  0.016595        NaN
# 308  26338.0   0.549116  0.228676 -37.415560         NaN  0.171857        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 55    0.286857   0.754571         1.0         1.0     True -0.041429  0.275446
# 150   0.255750   0.908607         1.0         1.0     True -0.164357  0.219649
# 173   0.962203   0.999900         1.0         1.0     True -0.962103  0.490394
# 178   0.594452   0.491690         1.0         1.0     True -0.086143  0.547306
# 227   0.619571   0.561286         1.0         1.0     True -0.180857  0.524679
# 257   0.494980   0.521615         1.0         1.0     True -0.016595  0.486900
# 308   0.243357   0.928500         1.0         1.0     True -0.171857  0.207668

# %%
df_linear = df_linear.loc[df_linear['range']>0,:] # remove negative amplitudes
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmo
# 318  26348.0   0.841177  0.136423 -23.887948  0.438173    0.403585  0.211483
#
#      bias_xmin  bias_xmax  flipped     range      bias
# 0     0.053769   0.337762    False  0.608468  0.137330
# 1     0.250293   0.377311    False  0.372396  0.398807
# 2     0.085457   0.321001    False  0.593543  0.210248
# 3     0.020744   0.033620    False  0.945636  0.381575
# 4     0.224223   0.272558    False  0.503219  0.451352
# ..         ...        ...      ...       ...       ...
# 314   0.017078   0.172710    False  0.810212  0.089985
# 315   0.004407   0.008001    False  0.987592  0.355208
# 316   0.161481   0.279747    False  0.558772  0.365981
# 317   0.309041   0.461490    False  0.229468  0.401076
# 318   0.316949   0.249562    False  0.433489  0.559475
#
# [311 rows x 12 columns]

# %%
rows = (np.isnan(df_linear['aic'])) | (np.isinf(df_linear['aic']))
df_linear.loc[rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = (np.isnan(df_sigmoid['aic'])) | (np.isinf(df_sigmoid['aic']))
df_sigmoid.loc[rows,:] # looks like a reasonable sub, but have to discard bc we need AIC
# Out:
#       subID  r_squared  nrmse  aic  center  obj_center  sigma  bias_xmin  \
# 70  26079.0        1.0    0.0 -inf  0.0001      0.0001    0.0        0.3
#
#     bias_xmax  flipped  range  bias
# 70        0.0    False    0.7   1.0

# %%
rows = ~(np.isnan(df_linear['aic'])) & ~(np.isinf(df_linear['aic']))
print('size, before:', df_linear.shape)
df_linear = df_linear.loc[rows,:]
print('size, after:', df_linear.shape)
# Out:
# size, before: (310, 12)
# size, after: (310, 12)

# %%
rows = ~(np.isnan(df_sigmoid['aic'])) & ~(np.isinf(df_sigmoid['aic']))
print('size, before:', df_sigmoid.shape)
df_sigmoid = df_sigmoid.loc[rows,:]
print('size, after:', df_sigmoid.shape)
# Out:
# size, before: (311, 12)
# size, after: (310, 12)

# %%
np.where(np.isnan(df_sigmoid))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
cols = list(df_linear.columns)
cols_new = [i + '_linear' for i in cols]
df_linear.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_linear
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  \
# 0         26000.0          0.940328      0.089873  -35.484797
# 1         26001.0          0.823224      0.147384  -35.444795
# 2         26002.0          0.799844      0.174349  -27.675491
# 3         26003.0          0.915302      0.111619  -26.697277
# 4         26004.0          0.972040      0.051894  -43.866039
# ..            ...               ...           ...         ...
# 314       26344.0          0.849478      0.155297  -23.720998
# 315       26345.0          0.803122      0.179504  -20.200661
# 316       26346.0          0.855388      0.122336  -30.751435
# 317       26347.0          0.852070      0.125535  -43.857648
# 318       26348.0          0.864797      0.125619  -34.010792
#
#      obj_center_linear  slope_linear  intercept_linear  bias_xmin_linear  \
# 0             0.709516      0.704565          0.000100          0.000100
# 1             0.594001      0.386857          0.270206          0.270206
# 2             0.550578      0.624214          0.156321          0.156321
# 3             0.499900      1.000000          0.000100          0.000100
# 4             0.526637      0.579214          0.194964          0.194964
# ..                 ...           ...               ...               ...
# 314           0.606647      0.824037          0.000100          0.000100
# 315           0.391841      1.000000          0.108159          0.108159
# 316           0.511248      0.609643          0.188321          0.188321
# 317           0.824250      0.235905          0.305556          0.305556
# 318           0.417204      0.502286          0.290444          0.290444
#
#      bias_xmax_linear  flipped_linear  range_linear  bias_linear
# 0            0.295335           False      0.704565     0.000338
# 1            0.342937           False      0.386857     0.440691
# 2            0.219464           False      0.624214     0.415986
# 3            0.000000           False      0.999900     1.000000
# 4            0.225821           False      0.579214     0.463334
# ..                ...             ...           ...          ...
# 314          0.175863           False      0.824037     0.000568
# 315          0.000000           False      0.891841     1.000000
# 316          0.202036           False      0.609643     0.482434
# 317          0.458540           False      0.235905     0.399892
# 318          0.207270           False      0.502286     0.583557
#
# [310 rows x 12 columns]

# %%
cols = list(df_sigmoid.columns)
cols_new = [i + '_sigmoid' for i in cols]
df_sigmoid.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_sigmoid
# Out:
# /Users/f0053cz/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      subID_sigmoid  r_squared_sigmoid  nrmse_sigmoid  aic_sigmoid  \
# 0          26000.0           0.947342       0.086740   -30.227716
# 1          26001.0           0.909476       0.117844   -25.937516
# 2          26002.0           0.951829       0.099103   -28.362317
# 3          26003.0           0.961148       0.076137   -32.053098
# 4          26004.0           0.941723       0.075045   -32.255374
# ..             ...                ...            ...          ...
# 314        26344.0           0.878185       0.136392   -23.891151
# 315        26345.0           0.949162       0.104135   -27.668955
# 316        26346.0           0.910287       0.098605   -28.432913
# 317        26347.0           0.908595       0.100810   -28.123257
# 318        26348.0           0.841177       0.136423   -23.887948
#
#      center_sigmoid  obj_center_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  \
# 0          0.552453            0.685848       0.156243           0.053769
# 1          0.313334            0.416187       0.126279           0.250293
# 2          0.270637            0.315242       0.052594           0.085457
# 3          0.534390            0.534390       0.138639           0.020744
# 4          0.446652            0.500804       0.226720           0.224223
# ..              ...                 ...            ...                ...
# 314        0.602410            0.640860       0.153172           0.017078
# 315        0.312358            0.312840       0.047663           0.004407
# 316        0.280589            0.397347       0.173938           0.161481
# 317        0.459478            0.715282       0.180744           0.309041
# 318        0.438173            0.403585       0.211483           0.316949
#
#      bias_xmax_sigmoid  flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0             0.337762            False       0.608468      0.137330
# 1             0.377311            False       0.372396      0.398807
# 2             0.321001            False       0.593543      0.210248
# 3             0.033620            False       0.945636      0.381575
# 4             0.272558            False       0.503219      0.451352
# ..                 ...              ...            ...           ...
# 314           0.172710            False       0.810212      0.089985
# 315           0.008001            False       0.987592      0.355208
# 316           0.279747            False       0.558772      0.365981
# 317           0.461490            False       0.229468      0.401076
# 318           0.249562            False       0.433489      0.559475
#
# [310 rows x 12 columns]

# %%
df_both =  df_linear.merge(df_sigmoid, left_on = 'subID_linear', right_on = 'subID_sigmoid')
#pd.concat([df_linear.set_index('subID_linear'),df_sigmoid.set_index('subID_sigmoid')]),axis=1)
print(df_both.shape)
# Out:
# (309, 24)

# %%
print(df_both.shape)
rows = (df_both['range_sigmoid']>0) & (df_both['slope_linear']>0)
df_both.loc[rows,:].shape
# Out:
# (309, 24)
# (309, 24)

# %%
df_both.rename(columns={'obj_center_linear':'PSE_linear','obj_center_sigmoid':'PSE_sigmoid'},inplace=True)
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         26000.0          0.940328      0.089873  -35.484797    0.709516
# 1         26001.0          0.823224      0.147384  -35.444795    0.594001
# 2         26002.0          0.799844      0.174349  -27.675491    0.550578
# 3         26003.0          0.915302      0.111619  -26.697277    0.499900
# 4         26004.0          0.972040      0.051894  -43.866039    0.526637
# ..            ...               ...           ...         ...         ...
# 304       26344.0          0.849478      0.155297  -23.720998    0.606647
# 305       26345.0          0.803122      0.179504  -20.200661    0.391841
# 306       26346.0          0.855388      0.122336  -30.751435    0.511248
# 307       26347.0          0.852070      0.125535  -43.857648    0.824250
# 308       26348.0          0.864797      0.125619  -34.010792    0.417204
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.704565          0.000100          0.000100          0.295335
# 1        0.386857          0.270206          0.270206          0.342937
# 2        0.624214          0.156321          0.156321          0.219464
# 3        1.000000          0.000100          0.000100          0.000000
# 4        0.579214          0.194964          0.194964          0.225821
# ..            ...               ...               ...               ...
# 304      0.824037          0.000100          0.000100          0.175863
# 305      1.000000          0.108159          0.108159          0.000000
# 306      0.609643          0.188321          0.188321          0.202036
# 307      0.235905          0.305556          0.305556          0.458540
# 308      0.502286          0.290444          0.290444          0.207270
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.086740   -30.227716        0.552453
# 1             False  ...       0.117844   -25.937516        0.313334
# 2             False  ...       0.099103   -28.362317        0.270637
# 3             False  ...       0.076137   -32.053098        0.534390
# 4             False  ...       0.075045   -32.255374        0.446652
# ..              ...  ...            ...          ...             ...
# 304           False  ...       0.136392   -23.891151        0.602410
# 305           False  ...       0.104135   -27.668955        0.312358
# 306           False  ...       0.098605   -28.432913        0.280589
# 307           False  ...       0.100810   -28.123257        0.459478
# 308           False  ...       0.136423   -23.887948        0.438173
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.685848       0.156243           0.053769           0.337762
# 1       0.416187       0.126279           0.250293           0.377311
# 2       0.315242       0.052594           0.085457           0.321001
# 3       0.534390       0.138639           0.020744           0.033620
# 4       0.500804       0.226720           0.224223           0.272558
# ..           ...            ...                ...                ...
# 304     0.640860       0.153172           0.017078           0.172710
# 305     0.312840       0.047663           0.004407           0.008001
# 306     0.397347       0.173938           0.161481           0.279747
# 307     0.715282       0.180744           0.309041           0.461490
# 308     0.403585       0.211483           0.316949           0.249562
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.608468      0.137330
# 1              False       0.372396      0.398807
# 2              False       0.593543      0.210248
# 3              False       0.945636      0.381575
# 4              False       0.503219      0.451352
# ..               ...            ...           ...
# 304            False       0.810212      0.089985
# 305            False       0.987592      0.355208
# 306            False       0.558772      0.365981
# 307            False       0.229468      0.401076
# 308            False       0.433489      0.559475
#
# [309 rows x 24 columns]

# %%
# rows = (df_both['amplitude_sigmoid']>0) & (df_both['slope_linear']>0)
# df_both = df_both.loc[rows,:]
# print(df_both.shape)
# df_both.head()

# %% [markdown]
# # sanity checks

# %%
def get_p(p):
    if p < .001:
        return "p < .001"
    elif p < .01:
        return f"p={p:.3f}"
    else:
        return f"p={p:.2f}"
        
def explore_correlations(df, param, ax):

    from scipy.stats import pearsonr,spearmanr

    if param == 'slope':
        x = df[param+'_linear']
        y = df['sigma_sigmoid']
    else:
        x = df[param+'_linear']
        y = df[param+'_sigmoid']
    
    rows = (~np.isnan(x)) & (~np.isnan(y)) & (~np.isinf(x)) & (~np.isinf(y))
    x = x[rows]
    y = y[rows]

    sns.scatterplot(x=x, y=y,color='k',alpha=.3,ax=ax)
    r,p = pearsonr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_p={r:.2f} ({get_p(p)})',xy=(0.05,.9),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')


    r,p = spearmanr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_s={r:.2f} ({get_p(p)})',xy=(0.05,.8),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')

# %%
comparisons = ['bias_xmin','bias_xmax','bias','PSE','range','slope','r_squared']

# %%
# nrows = 3
# ncols = 3
# fig,axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (10,10))
# for i,param in enumerate(comparisons):
#     r = int(np.floor(i/ncols))
#     c = i%ncols
#     ax = axs[r,c]
#     explore_correlations(df_both, param, ax)
#     ax.set_title(param,fontweight='bold')
#     if param == 'slope':
#         ax.set_title ('slope vs. inv. sigma',fontweight='bold')

# df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
# df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

# ax = axs[2,1]
# sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
# ax.set_xlabel('')
# for i in df_both.index:
#     ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
# ax.set_title('AIC',fontweight='bold')
# ax.set_ylim(-100,0)

# ax = axs[2,2]
# ax.axis('off')

# plt.suptitle('Linear (X) vs. sigmoid(Y) fits (pf sess1)', fontweight='bold', fontsize=16)
# plt.tight_layout()
# # plt.savefig('../../results/playfight/linear_vs_sigmoid_ses1.png',dpi=300,bbox_inches='tight')

# %%
df_both.to_csv('../../data/playfight_data/curvefits_linear_sigmoid_params_ses1.csv')

# %%
from scipy import stats

# %%
s=16 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

# %%
t,p = stats.ttest_rel(df_both['aic_sigmoid'],df_both['aic_linear'])
t,p
# Out:
# (13.354222486476814, 2.096420394043633e-32)

# %%
(df_both['aic_sigmoid']-df_both['aic_linear']).mean()
# Out:
# 7.2071297490087645

# %%
df_both['aic_sigmoid'].mean(),df_both['aic_linear'].mean(), df_both['aic_sigmoid'].std(),df_both['aic_linear'].std()
# Out:
# (-29.31633320232952, -36.5234629513383, 7.251856781588657, 6.767813461390009)

# %%
df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

fig,ax = plt.subplots(figsize=(4,4),nrows=1,ncols=1)
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='tab:red',alpha = .05)
if p < .05:
    ax.hlines(-10,0,1,color = 'k',linewidth=.5)
    if p<.001:
        txt = '***'
    elif p < .01:
        txt = '**'
    else:
        txt = '*'
    ax.text(0.5,-12,txt,color = 'k',ha='center')
ax.set_title('Session 1',fontweight='bold')
ax.set_ylim(-100,0)
ax.set_xticklabels(['linear','sigmoid'])
ax.set_ylabel('AIC')
plt.savefig('../../results/playfight/AIC_linear_vs_sigmoid_ses1.png',bbox_inches='tight',dpi=300)

# %%
# Out:
# Ttest_relResult(statistic=13.459850284395195, pvalue=8.530643756703199e-33)

# %%
# Out:
# (-29.31633320232952, -36.5234629513383, 7.251856781588657, 6.767813461390009)

# %%
df_both['aic_diff'] = df_both['aic_sigmoid'] - df_both['aic_linear']
# len(np.where(df_both['aic_diff']>0)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<0)[0])
len(np.where(df_both['aic_diff']>5)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-5)[0])
# Out:
# (196, 0, 20)

# %%
len(np.where(df_both['aic_diff']>10)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-10)[0])
# Out:
# (109, 0, 10)
