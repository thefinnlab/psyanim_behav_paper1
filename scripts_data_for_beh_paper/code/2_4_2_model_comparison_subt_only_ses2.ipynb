# %% [markdown]
# - model comparison between the sigmoid and linear fits for mean subject-level playfight curves

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from func_fix_curvefit_params import *

# %%
root_folder = '../data/subtlety_data/'

# %%
df_linear = pd.read_csv(f'{root_folder}/curve_fit_subt_ses2_linear/all_params_1k_subt_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#      subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 10    15.0   0.581768  0.193472 -35.169290   -0.461981  0.215633   0.599619
# 26    41.0   0.898478  0.118566 -45.686505   -0.552192  0.256607   0.641696
# 91   146.0   0.895318  0.115993 -41.262540   -0.128820  0.346006   0.544573
# 107  170.0   0.781894  0.176745 -34.468890   -0.385509  0.363929   0.640298
# 124  193.0   0.650810  0.186413 -47.126228   -1.841737  0.106250   0.695685
# 133  206.0   0.716634  0.200030 -30.702844   -0.332001  0.400016   0.632806
# 141  217.0   0.595374  0.225252 -26.548264   -0.398652  0.410536   0.663661
# 153  229.0   0.763139  0.172857 -42.836553   -1.321320  0.189784   0.750765
# 178  263.0   0.602077  0.223993 -24.471948   -0.046351  0.482857   0.522381
# 187  276.0   0.884994  0.137086 -34.804887   -0.076415  0.520552   0.539778
# 202  303.0   0.916385  0.109212 -40.610248   -0.125762  0.410357   0.551607
# 216  324.0   0.818040  0.163955 -32.084589   -0.178985  0.483214   0.586488
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 10    0.599619   0.184748         0.0         0.0    False
# 26    0.641696   0.101696         0.0         0.0    False
# 91    0.544573   0.109421         0.0         0.0    False
# 107   0.640298  -0.004226         0.0         0.0    False
# 124   0.695685   0.198065         0.0         0.0    False
# 133   0.632806  -0.032822         0.0         0.0    False
# 141   0.663661  -0.074196         0.0         0.0    False
# 153   0.750765   0.059452         0.0         0.0    False
# 178   0.522381  -0.005238         0.0         0.0    False
# 187   0.539778  -0.060330         0.0         0.0    False
# 202   0.551607   0.038036         0.0         0.0    False
# 216   0.586488  -0.069702         0.0         0.0    False

# %%
df_linear = fix_obj_center(df_linear)
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped]
# Index: []

# %%
df_sigmoid = pd.read_csv(f'{root_folder}/curve_fit_subt_ses2/all_params_1k_subt.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#      subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 10    15.0   0.594764  0.190694 -19.199227  0.313610         NaN  0.271394
# 26    41.0   0.936395  0.094287 -29.059708  0.430071         NaN  0.143945
# 91   146.0   0.963045  0.070438 -33.142256  0.543616         NaN  0.136717
# 107  170.0   0.945719  0.088534 -29.941214  0.329023         NaN  0.064599
# 124  193.0   0.870836  0.120979 -25.569905  0.220287         NaN  0.137616
# 133  206.0   0.940303  0.091834 -29.428751  0.324354         NaN  0.052660
# 153  229.0   0.873489  0.128357 -24.741149  0.357200         NaN  0.112038
# 187  276.0   0.981602  0.055024 -36.599857  0.398508         NaN  0.098273
# 202  303.0   0.963546  0.074767 -32.307370  0.367953         NaN  0.130412
# 216  324.0   0.962729  0.077298 -31.841311  0.315902         NaN  0.067468
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 10    0.582935   0.200760    0.507500    0.177500    False
# 26    0.644136   0.129539    0.632500    0.125000    False
# 91    0.561260   0.116657    0.555000    0.105000    False
# 107   0.587211   0.052511    0.585000    0.052500    False
# 124   0.676697   0.207980    0.653333    0.207500    False
# 133   0.561717   0.020001    0.560833    0.020000    False
# 153   0.722521   0.082322    0.714444    0.081667    False
# 187   0.542320   0.010167    0.534545    0.009167    False
# 202   0.554586   0.091282    0.533333    0.088333    False
# 216   0.537583   0.003352    0.533333    0.003333    False

# %%
df_sigmoid = fix_obj_center(df_sigmoid)
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped]
# Index: []

# %%
df_linear = add_new_params(df_linear)
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_linear = df_linear.loc[df_linear['range']>0,:] # remove negative amplitudes
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmoid = add_new_params(df_sigmoid)
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmoid = df_sigmoid.loc[df_sigmoid['range']>0,:] # remove negative amplitudes
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_linear.rename({'obj_center':'PSE'},inplace=True)
df_linear.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_linear.head()
# Out:
#    subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 0    2.0   0.953096  0.082835 -34.622905    0.371640  0.856964   0.181518
# 1    4.0   0.944858  0.087002 -40.933013    0.309283  0.501412   0.344922
# 2    5.0   0.933279  0.106481 -37.608336    0.280955  0.574464   0.338601
# 3    6.0   0.956291  0.078839 -46.611156    0.256554  0.377679   0.403105
# 4    7.0   0.906807  0.125423 -31.222079    0.371201  0.756071   0.219345
#
#    bias_xmin  bias_xmax  flipped     range      bias
# 0   0.181518   0.000000    False  0.818482  1.000000
# 1   0.344922   0.153666    False  0.501412  0.691797
# 2   0.338601   0.086935    False  0.574464  0.795706
# 3   0.403105   0.219216    False  0.377679  0.647744
# 4   0.219345   0.024583    False  0.756071  0.899219

# %%
df_sigmoid.rename({'obj_center':'PSE'},inplace=True)
df_sigmoid.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_sigmoid
# Out:
#      subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 0      2.0   0.982275  0.053215 -37.067887  0.437272    0.379686  0.132783
# 1      4.0   0.982178  0.049461 -38.092011  0.493091    0.375676  0.138347
# 2      5.0   0.999750  0.006915 -65.636911  0.492211    0.385977  0.093328
# 3      6.0   0.988793  0.041230 -40.640351  0.475595    0.326023  0.130284
# 4      7.0   0.984765  0.056519 -36.224397  0.492990    0.433843  0.083456
# ..     ...        ...       ...        ...       ...         ...       ...
# 223  338.0   0.988393  0.042582 -40.188473  0.434195    0.440575  0.101662
# 224  340.0   0.992838  0.035600 -42.695711  0.411307    0.389330  0.088312
# 225  342.0   0.947681  0.072888 -32.663609  0.538108    0.344159  0.217861
# 226  343.0   0.998014  0.021021 -50.071118  0.377460    0.377460  0.054893
# 227  344.0   0.993762  0.033605 -43.503280  0.442641    0.391301  0.089461
#
#      bias_xmin  bias_xmax  flipped     range      bias
# 0     0.226559   0.046721    False  0.726720  0.829038
# 1     0.373690   0.186597    False  0.439713  0.666962
# 2     0.385784   0.137909    False  0.476307  0.736661
# 3     0.426422   0.246824    False  0.326753  0.633382
# 4     0.289247   0.069811    False  0.640942  0.805572
# ..         ...        ...      ...       ...       ...
# 223   0.166650   0.180866    False  0.652485  0.479546
# 224   0.168112   0.065985    False  0.765904  0.718131
# 225   0.414595   0.258785    False  0.326620  0.615692
# 226   0.001031   0.000012    False  0.998957  0.988611
# 227   0.223843   0.001536    False  0.774621  0.993184
#
# [228 rows x 12 columns]

# %%
rows = (np.isnan(df_linear['aic'])) | (np.isinf(df_linear['aic']))
df_linear.loc[rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = (np.isnan(df_sigmoid['aic'])) | (np.isinf(df_sigmoid['aic']))
df_sigmoid.loc[rows,:] # looks like a reasonable sub, but have to discard bc we need AIC
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = ~(np.isnan(df_linear['aic'])) & ~(np.isinf(df_linear['aic']))
print('size, before:', df_linear.shape)
df_linear = df_linear.loc[rows,:]
print('size, after:', df_linear.shape)
# Out:
# size, before: (228, 12)
# size, after: (228, 12)

# %%
rows = ~(np.isnan(df_sigmoid['aic'])) & ~(np.isinf(df_sigmoid['aic']))
print('size, before:', df_sigmoid.shape)
df_sigmoid = df_sigmoid.loc[rows,:]
print('size, after:', df_sigmoid.shape)
# Out:
# size, before: (228, 12)
# size, after: (228, 12)

# %%
np.where(np.isnan(df_sigmoid))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
cols = list(df_linear.columns)
cols_new = [i + '_linear' for i in cols]
df_linear.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_linear
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  \
# 0             2.0          0.953096      0.082835  -34.622905
# 1             4.0          0.944858      0.087002  -40.933013
# 2             5.0          0.933279      0.106481  -37.608336
# 3             6.0          0.956291      0.078839  -46.611156
# 4             7.0          0.906807      0.125423  -31.222079
# ..            ...               ...           ...         ...
# 223         338.0          0.895467      0.126678  -30.654617
# 224         340.0          0.904786      0.126556  -28.522493
# 225         342.0          0.979091      0.046028  -51.897979
# 226         343.0          0.822184      0.182083  -19.846131
# 227         344.0          0.911445      0.126490  -28.394864
#
#      obj_center_linear  slope_linear  intercept_linear  bias_xmin_linear  \
# 0             0.371640      0.856964          0.181518          0.181518
# 1             0.309283      0.501412          0.344922          0.344922
# 2             0.280955      0.574464          0.338601          0.338601
# 3             0.256554      0.377679          0.403105          0.403105
# 4             0.371201      0.756071          0.219345          0.219345
# ..                 ...           ...               ...               ...
# 223           0.468737      0.738750          0.153720          0.153720
# 224           0.389108      0.906071          0.147440          0.147440
# 225           0.312667      0.378750          0.381577          0.381577
# 226           0.387392      1.000000          0.112608          0.112608
# 227           0.343748      0.951607          0.172887          0.172887
#
#      bias_xmax_linear  flipped_linear  range_linear  bias_linear
# 0            0.000000           False      0.818482     1.000000
# 1            0.153666           False      0.501412     0.691797
# 2            0.086935           False      0.574464     0.795706
# 3            0.219216           False      0.377679     0.647744
# 4            0.024583           False      0.756071     0.899219
# ..                ...             ...           ...          ...
# 223          0.107530           False      0.738750     0.588403
# 224          0.000000           False      0.852560     1.000000
# 225          0.239673           False      0.378750     0.614209
# 226          0.000000           False      0.887392     1.000000
# 227          0.000000           False      0.827113     1.000000
#
# [228 rows x 12 columns]

# %%
cols = list(df_sigmoid.columns)
cols_new = [i + '_sigmoid' for i in cols]
df_sigmoid.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_sigmoid
# Out:
#      subID_sigmoid  r_squared_sigmoid  nrmse_sigmoid  aic_sigmoid  \
# 0              2.0           0.982275       0.053215   -37.067887
# 1              4.0           0.982178       0.049461   -38.092011
# 2              5.0           0.999750       0.006915   -65.636911
# 3              6.0           0.988793       0.041230   -40.640351
# 4              7.0           0.984765       0.056519   -36.224397
# ..             ...                ...            ...          ...
# 223          338.0           0.988393       0.042582   -40.188473
# 224          340.0           0.992838       0.035600   -42.695711
# 225          342.0           0.947681       0.072888   -32.663609
# 226          343.0           0.998014       0.021021   -50.071118
# 227          344.0           0.993762       0.033605   -43.503280
#
#      center_sigmoid  obj_center_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  \
# 0          0.437272            0.379686       0.132783           0.226559
# 1          0.493091            0.375676       0.138347           0.373690
# 2          0.492211            0.385977       0.093328           0.385784
# 3          0.475595            0.326023       0.130284           0.426422
# 4          0.492990            0.433843       0.083456           0.289247
# ..              ...                 ...            ...                ...
# 223        0.434195            0.440575       0.101662           0.166650
# 224        0.411307            0.389330       0.088312           0.168112
# 225        0.538108            0.344159       0.217861           0.414595
# 226        0.377460            0.377460       0.054893           0.001031
# 227        0.442641            0.391301       0.089461           0.223843
#
#      bias_xmax_sigmoid  flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0             0.046721            False       0.726720      0.829038
# 1             0.186597            False       0.439713      0.666962
# 2             0.137909            False       0.476307      0.736661
# 3             0.246824            False       0.326753      0.633382
# 4             0.069811            False       0.640942      0.805572
# ..                 ...              ...            ...           ...
# 223           0.180866            False       0.652485      0.479546
# 224           0.065985            False       0.765904      0.718131
# 225           0.258785            False       0.326620      0.615692
# 226           0.000012            False       0.998957      0.988611
# 227           0.001536            False       0.774621      0.993184
#
# [228 rows x 12 columns]

# %%
df_both =  df_linear.merge(df_sigmoid, left_on = 'subID_linear', right_on = 'subID_sigmoid')
#pd.concat([df_linear.set_index('subID_linear'),df_sigmoid.set_index('subID_sigmoid')]),axis=1)
print(df_both.shape)
# Out:
# (228, 24)

# %%
print(df_both.shape)
rows = (df_both['range_sigmoid']>0) & (df_both['slope_linear']>0)
df_both.loc[rows,:].shape
# Out:
# (228, 24)
# (228, 24)

# %%
df_both.rename(columns={'obj_center_linear':'PSE_linear','obj_center_sigmoid':'PSE_sigmoid'},inplace=True)
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0             2.0          0.953096      0.082835  -34.622905    0.371640
# 1             4.0          0.944858      0.087002  -40.933013    0.309283
# 2             5.0          0.933279      0.106481  -37.608336    0.280955
# 3             6.0          0.956291      0.078839  -46.611156    0.256554
# 4             7.0          0.906807      0.125423  -31.222079    0.371201
# ..            ...               ...           ...         ...         ...
# 223         338.0          0.895467      0.126678  -30.654617    0.468737
# 224         340.0          0.904786      0.126556  -28.522493    0.389108
# 225         342.0          0.979091      0.046028  -51.897979    0.312667
# 226         343.0          0.822184      0.182083  -19.846131    0.387392
# 227         344.0          0.911445      0.126490  -28.394864    0.343748
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.856964          0.181518          0.181518          0.000000
# 1        0.501412          0.344922          0.344922          0.153666
# 2        0.574464          0.338601          0.338601          0.086935
# 3        0.377679          0.403105          0.403105          0.219216
# 4        0.756071          0.219345          0.219345          0.024583
# ..            ...               ...               ...               ...
# 223      0.738750          0.153720          0.153720          0.107530
# 224      0.906071          0.147440          0.147440          0.000000
# 225      0.378750          0.381577          0.381577          0.239673
# 226      1.000000          0.112608          0.112608          0.000000
# 227      0.951607          0.172887          0.172887          0.000000
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.053215   -37.067887        0.437272
# 1             False  ...       0.049461   -38.092011        0.493091
# 2             False  ...       0.006915   -65.636911        0.492211
# 3             False  ...       0.041230   -40.640351        0.475595
# 4             False  ...       0.056519   -36.224397        0.492990
# ..              ...  ...            ...          ...             ...
# 223           False  ...       0.042582   -40.188473        0.434195
# 224           False  ...       0.035600   -42.695711        0.411307
# 225           False  ...       0.072888   -32.663609        0.538108
# 226           False  ...       0.021021   -50.071118        0.377460
# 227           False  ...       0.033605   -43.503280        0.442641
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.379686       0.132783           0.226559           0.046721
# 1       0.375676       0.138347           0.373690           0.186597
# 2       0.385977       0.093328           0.385784           0.137909
# 3       0.326023       0.130284           0.426422           0.246824
# 4       0.433843       0.083456           0.289247           0.069811
# ..           ...            ...                ...                ...
# 223     0.440575       0.101662           0.166650           0.180866
# 224     0.389330       0.088312           0.168112           0.065985
# 225     0.344159       0.217861           0.414595           0.258785
# 226     0.377460       0.054893           0.001031           0.000012
# 227     0.391301       0.089461           0.223843           0.001536
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.726720      0.829038
# 1              False       0.439713      0.666962
# 2              False       0.476307      0.736661
# 3              False       0.326753      0.633382
# 4              False       0.640942      0.805572
# ..               ...            ...           ...
# 223            False       0.652485      0.479546
# 224            False       0.765904      0.718131
# 225            False       0.326620      0.615692
# 226            False       0.998957      0.988611
# 227            False       0.774621      0.993184
#
# [228 rows x 24 columns]

# %%
# rows = (df_both['amplitude_sigmoid']>0) & (df_both['slope_linear']>0)
# df_both = df_both.loc[rows,:]
# print(df_both.shape)
# df_both.head()

# %% [markdown]
# # sanity checks

# %%
def get_p(p):
    if p < .001:
        return "p < .001"
    elif p < .01:
        return f"p={p:.3f}"
    else:
        return f"p={p:.2f}"
        
def explore_correlations(df, param, ax):

    from scipy.stats import pearsonr,spearmanr

    if param == 'slope':
        x = df[param+'_linear']
        y = df['sigma_sigmoid']
    else:
        x = df[param+'_linear']
        y = df[param+'_sigmoid']
    
    rows = (~np.isnan(x)) & (~np.isnan(y)) & (~np.isinf(x)) & (~np.isinf(y))
    x = x[rows]
    y = y[rows]

    sns.scatterplot(x=x, y=y,color='k',alpha=.3,ax=ax)
    r,p = pearsonr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_p={r:.2f} ({get_p(p)})',xy=(0.05,.9),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')


    r,p = spearmanr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_s={r:.2f} ({get_p(p)})',xy=(0.05,.8),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')

# %%
comparisons = ['bias_xmin','bias_xmax','bias','PSE','range','slope','r_squared']

# %%
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0             2.0          0.953096      0.082835  -34.622905    0.371640
# 1             4.0          0.944858      0.087002  -40.933013    0.309283
# 2             5.0          0.933279      0.106481  -37.608336    0.280955
# 3             6.0          0.956291      0.078839  -46.611156    0.256554
# 4             7.0          0.906807      0.125423  -31.222079    0.371201
# ..            ...               ...           ...         ...         ...
# 223         338.0          0.895467      0.126678  -30.654617    0.468737
# 224         340.0          0.904786      0.126556  -28.522493    0.389108
# 225         342.0          0.979091      0.046028  -51.897979    0.312667
# 226         343.0          0.822184      0.182083  -19.846131    0.387392
# 227         344.0          0.911445      0.126490  -28.394864    0.343748
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.856964          0.181518          0.181518          0.000000
# 1        0.501412          0.344922          0.344922          0.153666
# 2        0.574464          0.338601          0.338601          0.086935
# 3        0.377679          0.403105          0.403105          0.219216
# 4        0.756071          0.219345          0.219345          0.024583
# ..            ...               ...               ...               ...
# 223      0.738750          0.153720          0.153720          0.107530
# 224      0.906071          0.147440          0.147440          0.000000
# 225      0.378750          0.381577          0.381577          0.239673
# 226      1.000000          0.112608          0.112608          0.000000
# 227      0.951607          0.172887          0.172887          0.000000
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.053215   -37.067887        0.437272
# 1             False  ...       0.049461   -38.092011        0.493091
# 2             False  ...       0.006915   -65.636911        0.492211
# 3             False  ...       0.041230   -40.640351        0.475595
# 4             False  ...       0.056519   -36.224397        0.492990
# ..              ...  ...            ...          ...             ...
# 223           False  ...       0.042582   -40.188473        0.434195
# 224           False  ...       0.035600   -42.695711        0.411307
# 225           False  ...       0.072888   -32.663609        0.538108
# 226           False  ...       0.021021   -50.071118        0.377460
# 227           False  ...       0.033605   -43.503280        0.442641
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.379686       0.132783           0.226559           0.046721
# 1       0.375676       0.138347           0.373690           0.186597
# 2       0.385977       0.093328           0.385784           0.137909
# 3       0.326023       0.130284           0.426422           0.246824
# 4       0.433843       0.083456           0.289247           0.069811
# ..           ...            ...                ...                ...
# 223     0.440575       0.101662           0.166650           0.180866
# 224     0.389330       0.088312           0.168112           0.065985
# 225     0.344159       0.217861           0.414595           0.258785
# 226     0.377460       0.054893           0.001031           0.000012
# 227     0.391301       0.089461           0.223843           0.001536
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.726720      0.829038
# 1              False       0.439713      0.666962
# 2              False       0.476307      0.736661
# 3              False       0.326753      0.633382
# 4              False       0.640942      0.805572
# ..               ...            ...           ...
# 223            False       0.652485      0.479546
# 224            False       0.765904      0.718131
# 225            False       0.326620      0.615692
# 226            False       0.998957      0.988611
# 227            False       0.774621      0.993184
#
# [228 rows x 24 columns]

# %%
nrows = 3
ncols = 3
fig,axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (10,10))
for i,param in enumerate(comparisons):
    r = int(np.floor(i/ncols))
    c = i%ncols
    ax = axs[r,c]
    explore_correlations(df_both, param, ax)
    ax.set_title(param,fontweight='bold')
    if param == 'slope':
        ax.set_title ('slope vs. inv. sigma',fontweight='bold')

df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

ax = axs[2,1]
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-100,0)

ax = axs[2,2]
ax.axis('off')

plt.suptitle('Linear (X) vs. sigmoid(Y) fits (pf sess1)', fontweight='bold', fontsize=16)
plt.tight_layout()
# plt.savefig('../results/subtlety/linear_vs_sigmoid_ses2.png',dpi=300,bbox_inches='tight')

# %%
df_both.to_csv('../data/subtlety_data/curvefits_subt_linear_sigmoid_params_ses2.csv')

# %%
from scipy import stats

# %%
s=16 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

# %%
df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

fig,ax = plt.subplots(figsize=(4,4),nrows=1,ncols=1)
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-200,0)
plt.savefig('../results/subtlety/AIC_linear_vs_sigmoid_ses2.png')

# %%
stats.ttest_rel(df_both['aic_sigmoid'],df_both['aic_linear'])
# Out:
# Ttest_relResult(statistic=-11.580443782850255, pvalue=1.1289928803644015e-24)

# %%
df_both['aic_sigmoid'].mean(),df_both['aic_linear'].mean(), df_both['aic_sigmoid'].std(),df_both['aic_linear'].std()
# Out:
# (-40.037997936921315, -30.41819281055999, 9.603894516873266, 5.763330629980338)

# %%
df_both['aic_diff'] = df_both['aic_sigmoid'] - df_both['aic_linear']
# len(np.where(df_both['aic_diff']>0)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<0)[0])
len(np.where(df_both['aic_diff']>5)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-5)[0])
# Out:
# (19, 0, 145)

# %%
len(np.where(df_both['aic_diff']>10)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-10)[0])
# Out:
# (8, 0, 101)

# %%
df_both.shape
# Out:
# (228, 25)
