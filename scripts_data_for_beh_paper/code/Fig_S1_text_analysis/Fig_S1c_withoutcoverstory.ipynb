# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
param_name = 'chargeSpeed'
expt_type = 'playfight/without_cover_story/sentiment_analyses/'
rootfile_loc = f'../../data/text_responses/{expt_type}'

# %%
df = pd.read_csv(f'{rootfile_loc}/data_with_sentiment_scores.csv', index_col=[0])
df = df.reset_index()
df
# Out:
#      index  subID  stimset_rows  chargeSpeed  stim_dur  \
# 0        5  28024            65          1.5      7962
# 1        3  28022            59          1.5      8002
# 2        3  28083            46          1.5      8083
# 3        1  28050            98          1.5      8648
# 4        1  28070            26          1.5      8284
# ..     ...    ...           ...          ...       ...
# 716      4  28056             4          9.0      8167
# 717      6  28022            59          9.0      8031
# 718      5  28058            13          9.0      9886
# 719      3  28085            51          9.0      8101
# 720      0  28101            65          9.0      8018
#
#                                              responses  \
# 0                now they slowly met and touched twice
# 1                     The dots meet each other warmly.
# 2                             both meeting each other
# 3                                slowly came together
# 4    The dots moved to the left and down and collid...
# ..                                                 ...
# 716              The white dot attacked the black dot.
# 717  The dots looked like enemy of each other and f...
# 718                   the two dots seem to be fighting
# 719                                 Hitting each other
# 720               the dot fighting, hitting each other
#
#                                     movie  trial_num  neg_score  neu_score  \
# 0    1b1159fc-de2b-4ae5-a736-d98d8524a366          5   0.003994   0.731555
# 1    1a8cf3c1-690b-449c-bb36-fd3b251837c1          3   0.004204   0.169153
# 2    50919f52-6a9c-4824-b24f-2f1aebd58e1b          3   0.005532   0.861102
# 3    8ed7c0fc-1490-4e35-a000-7f7357a0772a          1   0.006125   0.355109
# 4    29e7c94f-a6bf-4f1d-8ea1-46efbdb6a836          1   0.006636   0.873458
# ..                                    ...        ...        ...        ...
# 716  abb20336-74c4-448b-a5f7-252c765a55f4          4   0.482806   0.497981
# 717  5b2465b2-47b6-4cc7-b06f-c362ff7454f8          6   0.493080   0.482383
# 718  6a57f963-5846-4eaa-a5d2-0e658499a4a9          5   0.500883   0.477192
# 719  9301277e-6b35-4aa7-bd52-4f56ae0f029b          3   0.543805   0.415098
# 720  5b2465b2-47b6-4cc7-b06f-c362ff7454f8          0   0.609392   0.355545
#
#      pos_score   pos-neg   pos-neu   neg-neu   neu-neg
# 0     0.264451  0.260457 -0.467103 -0.727561  0.727561
# 1     0.826644  0.822440  0.657491 -0.164949  0.164949
# 2     0.133366  0.127834 -0.727736 -0.855570  0.855570
# 3     0.638766  0.632641  0.283657 -0.348984  0.348984
# 4     0.119906  0.113270 -0.753552 -0.866822  0.866822
# ..         ...       ...       ...       ...       ...
# 716   0.019213 -0.463593 -0.478769 -0.015176  0.015176
# 717   0.024537 -0.468543 -0.457846  0.010698 -0.010698
# 718   0.021925 -0.478958 -0.455267  0.023691 -0.023691
# 719   0.041097 -0.502707 -0.374001  0.128706 -0.128706
# 720   0.035063 -0.574328 -0.320482  0.253847 -0.253847
#
# [721 rows x 15 columns]

# %%
sum_sentiments = (df['pos_score'] + df['neg_score'] + df['neu_score'])
sum_sentiments.describe()
# Out:
# count    7.210000e+02
# mean     1.000000e+00
# std      7.042515e-08
# min      9.999998e-01
# 25%      9.999999e-01
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# dtype: float64

# %%
import matplotlib.pyplot as plt
s=16 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

# %%
param_name = 'chargeSpeed'

# %%
results_dir = '../../results/text_analysis/pf/no_cover_story/'

# %%
colors_plot = 'tab:red'

# %%
# yaxis goes from negative (lower) to positive (higher)
fig,ax = plt.subplots(nrows=1,ncols=1,figsize=(5,4), sharey=False,sharex=True)
sns.lineplot(data=df.reset_index(),x = param_name,y = 'pos-neg', ax=ax,marker = 'o', ls = 'None', color = colors_plot, err_style='bars')
sns.regplot(data = df.groupby([param_name]).mean().reset_index(),x = param_name, y='pos-neg',  ax=ax,marker = 'o', color=colors_plot)#,legend=False)
# ax.set_title('Positive - Negative score\n', fontweight = 'bold')
ax.set_title('Without cover story', fontweight = 'bold')
ax.set_ylabel('More\n negative <---> positive')
ax.set_xlabel('charge speed')
ax.set_ylim(-.3,.3)
ax.hlines(0,1.4,9.1,color = 'grey',ls=':',alpha = .4)
ax.set_xticks(np.arange(1.5,9.1,1.25),['1.5','2.75','4','5.25','6.5','7.75','9'])
# ax.invert_xaxis()

plt.tight_layout()
plt.savefig(f'{results_dir}/sentiment_analysis_lineplot_negtopos_untilNov2024.png',dpi=300,bbox_inches ='tight')

# %%
# yaxis goes from positive (lower) to negative (higher) to match with the word similarity analysis

fig,ax = plt.subplots(nrows=1,ncols=1,figsize=(5,4), sharey=False,sharex=True)
sns.lineplot(data=df.reset_index(),x = param_name,y = 'pos-neg', ax=ax,marker = 'o', ls = 'None', color = colors_plot, err_style='bars')
sns.regplot(data = df.groupby([param_name]).mean().reset_index(),x = param_name, y='pos-neg',  ax=ax,marker = 'o', color=colors_plot)#,legend=False)
# ax.set_title('Positive - Negative score\n', fontweight = 'bold')
ax.set_title('Without cover story', fontweight = 'bold')
# ax.set_ylabel('More\n negative <---> positive')
ax.set_ylabel('More\n positive <---> negative')
ax.set_xlabel('charge speed')
ax.set_ylim(-.3,.3)
ax.hlines(0,1.4,9.1,color = 'grey',ls=':',alpha = .4)
ax.invert_yaxis() # make yacis go from positive to negative
ax.set_xticks(np.arange(1.5,9.1,1.25),['1.5','2.75','4','5.25','6.5','7.75','9'])
# ax.invert_xaxis()

plt.tight_layout()
plt.savefig(f'{results_dir}/sentiment_analysis_lineplot.png',dpi=300,bbox_inches ='tight')

# %%
pwd
# Out:
# '/Users/f0053cz/Dartmouth College Dropbox/Rekha Sreekumar Varrier/postdoc_Dartmouth/psyanim_behav_paper/version2/scripts_data_for_beh_paper/code/1_text_data'

# %%
df['chargeSpeed'] = df['chargeSpeed'] - 1.5
df['chargeSpeed'] = df['chargeSpeed']/7.5
df
# Out:
#      index  subID  stimset_rows  chargeSpeed  stim_dur  \
# 0        5  28024            65          0.0      7962
# 1        3  28022            59          0.0      8002
# 2        3  28083            46          0.0      8083
# 3        1  28050            98          0.0      8648
# 4        1  28070            26          0.0      8284
# ..     ...    ...           ...          ...       ...
# 716      4  28056             4          1.0      8167
# 717      6  28022            59          1.0      8031
# 718      5  28058            13          1.0      9886
# 719      3  28085            51          1.0      8101
# 720      0  28101            65          1.0      8018
#
#                                              responses  \
# 0                now they slowly met and touched twice
# 1                     The dots meet each other warmly.
# 2                             both meeting each other
# 3                                slowly came together
# 4    The dots moved to the left and down and collid...
# ..                                                 ...
# 716              The white dot attacked the black dot.
# 717  The dots looked like enemy of each other and f...
# 718                   the two dots seem to be fighting
# 719                                 Hitting each other
# 720               the dot fighting, hitting each other
#
#                                     movie  trial_num  neg_score  neu_score  \
# 0    1b1159fc-de2b-4ae5-a736-d98d8524a366          5   0.003994   0.731555
# 1    1a8cf3c1-690b-449c-bb36-fd3b251837c1          3   0.004204   0.169153
# 2    50919f52-6a9c-4824-b24f-2f1aebd58e1b          3   0.005532   0.861102
# 3    8ed7c0fc-1490-4e35-a000-7f7357a0772a          1   0.006125   0.355109
# 4    29e7c94f-a6bf-4f1d-8ea1-46efbdb6a836          1   0.006636   0.873458
# ..                                    ...        ...        ...        ...
# 716  abb20336-74c4-448b-a5f7-252c765a55f4          4   0.482806   0.497981
# 717  5b2465b2-47b6-4cc7-b06f-c362ff7454f8          6   0.493080   0.482383
# 718  6a57f963-5846-4eaa-a5d2-0e658499a4a9          5   0.500883   0.477192
# 719  9301277e-6b35-4aa7-bd52-4f56ae0f029b          3   0.543805   0.415098
# 720  5b2465b2-47b6-4cc7-b06f-c362ff7454f8          0   0.609392   0.355545
#
#      pos_score   pos-neg   pos-neu   neg-neu   neu-neg
# 0     0.264451  0.260457 -0.467103 -0.727561  0.727561
# 1     0.826644  0.822440  0.657491 -0.164949  0.164949
# 2     0.133366  0.127834 -0.727736 -0.855570  0.855570
# 3     0.638766  0.632641  0.283657 -0.348984  0.348984
# 4     0.119906  0.113270 -0.753552 -0.866822  0.866822
# ..         ...       ...       ...       ...       ...
# 716   0.019213 -0.463593 -0.478769 -0.015176  0.015176
# 717   0.024537 -0.468543 -0.457846  0.010698 -0.010698
# 718   0.021925 -0.478958 -0.455267  0.023691 -0.023691
# 719   0.041097 -0.502707 -0.374001  0.128706 -0.128706
# 720   0.035063 -0.574328 -0.320482  0.253847 -0.253847
#
# [721 rows x 15 columns]

# %% [markdown]
# ## Stats

# %%
from pymer4.models import Lmer
from pymer4.stats import vif

# %%
model = Lmer('neg_score ~ chargeSpeed +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# boundary (singular) fit: see ?isSingular
#
# Formula: neg_score~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 721	 Groups: {'movie': 140.0, 'subID': 103.0}
#
# Log-likelihood: 456.860 	 AIC: -913.720
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.000
# subID     (Intercept)  0.003  0.051
# Residual               0.014  0.120
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.085   0.066    0.103  0.009  350.054   8.930    0.0  ***
# chargeSpeed     0.076   0.050    0.102  0.013  617.000   5.675    0.0  ***

# %%
model = Lmer('neg_score ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: neg_score~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 721	 Groups: {'subID': 103.0}
#
# Log-likelihood: 456.860 	 AIC: -913.720
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.003  0.051
# Residual               0.014  0.120
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.085   0.066    0.103  0.009  350.052   8.930    0.0  ***
# chargeSpeed     0.076   0.050    0.102  0.013  617.000   5.675    0.0  ***

# %%
model = Lmer('pos_score ~ chargeSpeed +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: pos_score~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 721	 Groups: {'movie': 140.0, 'subID': 103.0}
#
# Log-likelihood: 573.263 	 AIC: -1146.527
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.017
# subID     (Intercept)  0.003  0.053
# Residual               0.010  0.099
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.141   0.123    0.158  0.009  167.245  15.873    0.0  ***
# chargeSpeed    -0.052  -0.076   -0.029  0.012  111.625  -4.386    0.0  ***

# %%
model = Lmer('pos_score ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: pos_score~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 721	 Groups: {'subID': 103.0}
#
# Log-likelihood: 572.719 	 AIC: -1145.439
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.003  0.053
# Residual               0.010  0.100
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.141   0.124    0.157  0.009  288.08  16.492    0.0  ***
# chargeSpeed    -0.052  -0.074   -0.030  0.011  617.00  -4.671    0.0  ***

# %% [markdown]
# ## Difference plots

# %%
df.rename(columns = {'pos-neg':'pos_neg','pos-neu':'pos_neu','neg-neu':'neg_neu','neu-neg':'neu_neg'},inplace=True)

# %%
model = Lmer('pos_neg ~ chargeSpeed +  (1|subID) + (1|movie)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: pos_neg~chargeSpeed+(1|subID)+(1|movie)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 721	 Groups: {'movie': 140.0, 'subID': 103.0}
#
# Log-likelihood: 168.960 	 AIC: -337.920
#
# Random effects:
#
#                  Name    Var    Std
# movie     (Intercept)  0.000  0.021
# subID     (Intercept)  0.005  0.071
# Residual               0.032  0.179
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.056   0.028    0.084  0.014  150.047   3.905    0.0  ***
# chargeSpeed    -0.128  -0.169   -0.088  0.021  109.720  -6.187    0.0  ***

# %%
model = Lmer('pos_neg ~ chargeSpeed +  (1|subID)', data=df) # ff: anglesm rfx: subject ID
model.fit()
# Out:
# Formula: pos_neg~chargeSpeed+(1|subID)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 721	 Groups: {'subID': 103.0}
#
# Log-likelihood: 168.840 	 AIC: -337.679
#
# Random effects:
#
#                  Name    Var    Std
# subID     (Intercept)  0.005  0.071
# Residual               0.032  0.180
#
# No random effect correlations specified
#
# Fixed effects:
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.056   0.028    0.083  0.014  368.676   3.995    0.0  ***
# chargeSpeed    -0.128  -0.168   -0.089  0.020  617.000  -6.381    0.0  ***
