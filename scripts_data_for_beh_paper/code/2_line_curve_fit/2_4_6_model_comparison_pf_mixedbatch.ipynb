# %% [markdown]
# - model comparison between the sigmoid and linear fits for mean subject-level playfight curves

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from func_fix_curvefit_params import *

# %%
root_folder = '../data/subtlety_playfight_data/'

# %%
df_linear = pd.read_csv(f'{root_folder}/curve_fit_pf_linear/all_params_1k_pf_mixed_linear.csv')#merged_apr_ses1.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 92   30118.0   0.600956  0.199803 -36.119624   -1.004827  0.209643   0.710655
# 97   30124.0   0.042037  0.316306 -31.337313   -0.199764  0.050357   0.510060
# 124  30160.0   0.911317  0.107599 -36.729385   -0.009083  0.524286   0.504762
# 195  30249.0   0.000000  0.306875 -46.511316        -inf  0.000000   0.684048
# 219  30286.0   0.795928  0.148290 -80.041061  -33.158520  0.014643   0.985536
# 251  30321.0   0.266618  0.270531 -25.296828   -0.090696  0.223143        NaN
# 260  30330.0   0.712939  0.194045 -44.611433   -2.111517  0.146786   0.809940
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 92    0.710655   0.079702         0.0         0.0    False
# 97    0.510060   0.439583         0.0         0.0    False
# 124   0.504762  -0.029048         0.0         0.0    False
# 195   0.684048   0.315952         0.0         0.0    False
# 219   0.985536  -0.000179         0.0         0.0    False
# 251   0.479762   0.743381         1.0         1.0     True
# 260   0.809940   0.043274         0.0         0.0    False

# %%
df_linear = fix_obj_center(df_linear)
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 44   30063.0   0.852254  0.129774 -31.856147         NaN  0.556357        NaN
# 177  30227.0   0.842325  0.134981 -33.281745         NaN  0.483571        NaN
# 251  30321.0   0.266618  0.270531 -25.296828         NaN  0.223143        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 44    0.825226   0.731131         1.0         1.0     True
# 177   0.716786   0.766786         1.0         1.0     True
# 251   0.479762   0.743381         1.0         1.0     True

# %%
df_sigmoid = pd.read_csv(f'{root_folder}/curve_fit_pf/all_params_1k_pf_mixed.csv')#('../data/ses1_data/curve_fit_rmse/all_params_1k.csv')
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 92   30118.0   0.579173  0.205289 -18.166683  0.531223         NaN  0.315880
# 97   30124.0   0.036874  0.317171 -12.076381  0.400178   -0.054884  1.000000
# 195  30249.0  -0.263323  0.345520 -10.877871  1.068182         NaN  1.000000
# 219  30286.0   0.760591  0.160899 -21.577665  0.412686         NaN  0.247385
# 251  30321.0   0.267563  0.270904 -14.283865  0.527594   -0.065880  0.469725
# 260  30330.0   0.942743  0.106527 -27.351000  0.219257         NaN  0.048327
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 92    0.721374   0.091007    0.676667    0.038333    False
# 97    0.503322   0.434777    0.401667    0.345000    False
# 195   0.672591   0.307338    0.650000    0.261667    False
# 219   0.985978   0.001420    0.983333    0.000000    False
# 251   0.487874   0.734089    0.610000    0.846000     True
# 260   0.776695   0.065000    0.775000    0.065000    False

# %%
df_sigmoid = fix_obj_center(df_sigmoid)
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 44   30063.0   0.840255  0.135085 -24.025918  0.355551         NaN  0.207596
# 177  30227.0   0.916173  0.106480 -27.357175  0.305133         NaN  0.143479
# 251  30321.0   0.267563  0.270904 -14.283865  0.527594         NaN  0.469725
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped
# 44    0.757791   0.720743    0.783333    0.811667     True
# 177   0.667625   0.789959    0.671667    0.845000     True
# 251   0.487874   0.734089    0.610000    0.846000     True

# %%
df_linear = add_new_params(df_linear)
df_linear.loc[df_linear['range']<0,:]
# Out:
#        subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 44   30063.0   0.852254  0.129774 -31.856147         NaN  0.556357        NaN
# 177  30227.0   0.842325  0.134981 -33.281745         NaN  0.483571        NaN
# 251  30321.0   0.266618  0.270531 -25.296828         NaN  0.223143        NaN
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 44    0.825226   0.731131         1.0         1.0     True -0.556357  0.530229
# 177   0.716786   0.766786         1.0         1.0     True -0.483571  0.483149
# 251   0.479762   0.743381         1.0         1.0     True -0.223143  0.392237

# %%
df_linear = df_linear.loc[df_linear['range']>0,:] # remove negative amplitudes
df_linear.loc[df_linear['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_linear['obj_center'])) | \
      (np.isinf(df_linear['obj_center'])) | \
    (df_linear['obj_center']<0)
df_linear.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_sigmoid = add_new_params(df_sigmoid)
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 44   30063.0   0.840255  0.135085 -24.025918  0.355551         NaN  0.207596
# 177  30227.0   0.916173  0.106480 -27.357175  0.305133         NaN  0.143479
# 251  30321.0   0.267563  0.270904 -14.283865  0.527594         NaN  0.469725
#
#      bias_xmin  bias_xmax  bias_lower  bias_upper  flipped     range      bias
# 44    0.757791   0.720743    0.783333    0.811667     True -0.478533  0.512529
# 177   0.667625   0.789959    0.671667    0.845000     True -0.457585  0.458036
# 251   0.487874   0.734089    0.610000    0.846000     True -0.221963  0.399254

# %%
df_sigmoid = df_sigmoid.loc[df_sigmoid['range']>0,:] # remove negative amplitudes
df_sigmoid.loc[df_sigmoid['range']<0,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
bad_rows = (np.isnan(df_sigmoid['obj_center'])) | \
      (np.isinf(df_sigmoid['obj_center'])) | \
    (df_sigmoid['obj_center']<0)
df_sigmoid.loc[bad_rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, center, obj_center, sigma, bias_xmin, bias_xmax, bias_lower, bias_upper, flipped, range, bias]
# Index: []

# %%
df_linear.rename({'obj_center':'PSE'},inplace=True)
df_linear.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_linear.head()
# Out:
#      subID  r_squared     nrmse        aic  obj_center     slope  intercept  \
# 0  30002.0   0.893032  0.114049 -29.636972    0.486946  0.784286   0.118095
# 1  30004.0   0.798324  0.146050 -31.603146    0.127093  0.469286   0.440357
# 2  30005.0   0.893113  0.113140 -28.646434    0.498304  0.842143   0.080357
# 3  30006.0   0.779614  0.154497 -24.726653    0.260263  0.725000   0.311310
# 4  30008.0   0.927597  0.093629 -38.630460    0.322409  0.511071   0.335226
#
#    bias_xmin  bias_xmax  flipped     range      bias
# 0   0.118095   0.097619    False  0.784286  0.547461
# 1   0.440357   0.090357    False  0.469286  0.829744
# 2   0.080357   0.077500    False  0.842143  0.509050
# 3   0.311310   0.000000    False  0.688690  1.000000
# 4   0.335226   0.153702    False  0.511071  0.685634

# %%
df_sigmoid.rename({'obj_center':'PSE'},inplace=True)
df_sigmoid.drop(columns=['bias_lower', 'bias_upper'],inplace=True)
df_sigmoid
# Out:
#        subID  r_squared     nrmse        aic    center  obj_center     sigma  \
# 0    30002.0   0.960575  0.072487 -32.740776  0.665858    0.591039  0.142704
# 1    30004.0   0.802323  0.144740 -23.059462  0.522624    0.136066  0.224573
# 2    30005.0   0.870139  0.124883 -25.125303  0.571110    0.530726  0.203235
# 3    30006.0   0.835463  0.137051 -23.823672  0.263991    0.228279  0.167483
# 4    30008.0   0.917580  0.099961 -28.241705  0.453739    0.340016  0.189201
# ..       ...        ...       ...        ...       ...         ...       ...
# 274  30344.0   0.787582  0.136192 -23.911645  0.500793    0.517119  0.286997
# 275  30345.0   0.800809  0.199203 -18.588009  0.205534    0.205534  0.024152
# 276  30346.0   0.804755  0.127870 -24.794383  0.612721    0.612721  0.273530
# 277  30348.0   0.919410  0.091742 -29.442839  0.577309    0.551969  0.215143
# 278  30352.0   0.885549  0.122916 -25.347517  0.655835    0.676260  0.142287
#
#      bias_xmin     bias_xmax  flipped     range      bias
# 0     0.212395  7.127578e-02    False  0.716329  0.748738
# 1     0.466189  1.007323e-01    False  0.433079  0.822317
# 2     0.162070  1.211174e-01    False  0.716813  0.572306
# 3     0.270824  5.014153e-02    False  0.679035  0.843779
# 4     0.362350  1.985016e-01    False  0.439149  0.646071
# ..         ...           ...      ...       ...       ...
# 274   0.242910  2.634025e-01    False  0.493688  0.479763
# 275   0.000201  5.107026e-15    False  0.999799  1.000000
# 276   0.096212  1.953123e-01    False  0.708476  0.330030
# 277   0.292621  2.927095e-01    False  0.414670  0.499924
# 278   0.218609  2.954028e-01    False  0.485988  0.425300
#
# [276 rows x 12 columns]

# %%
rows = (np.isnan(df_linear['aic'])) | (np.isinf(df_linear['aic']))
df_linear.loc[rows,:]
# Out:
# Empty DataFrame
# Columns: [subID, r_squared, nrmse, aic, obj_center, slope, intercept, bias_xmin, bias_xmax, flipped, range, bias]
# Index: []

# %%
rows = (np.isnan(df_sigmoid['aic'])) | (np.isinf(df_sigmoid['aic']))
df_sigmoid.loc[rows,:] # looks like a reasonable sub, but have to discard bc we need AIC
# Out:
#        subID  r_squared  nrmse  aic    center  obj_center  sigma  bias_xmin  \
# 193  30246.0        1.0    0.0 -inf  0.811881    0.811881    0.0        0.0
#
#      bias_xmax  flipped  range  bias
# 193        0.0    False    1.0   0.0

# %%
rows = ~(np.isnan(df_linear['aic'])) & ~(np.isinf(df_linear['aic']))
print('size, before:', df_linear.shape)
df_linear = df_linear.loc[rows,:]
print('size, after:', df_linear.shape)
# Out:
# size, before: (276, 12)
# size, after: (276, 12)

# %%
rows = ~(np.isnan(df_sigmoid['aic'])) & ~(np.isinf(df_sigmoid['aic']))
print('size, before:', df_sigmoid.shape)
df_sigmoid = df_sigmoid.loc[rows,:]
print('size, after:', df_sigmoid.shape)
# Out:
# size, before: (276, 12)
# size, after: (275, 12)

# %%
np.where(np.isnan(df_sigmoid))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
cols = list(df_linear.columns)
cols_new = [i + '_linear' for i in cols]
df_linear.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_linear
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  \
# 0         30002.0          0.893032      0.114049  -29.636972
# 1         30004.0          0.798324      0.146050  -31.603146
# 2         30005.0          0.893113      0.113140  -28.646434
# 3         30006.0          0.779614      0.154497  -24.726653
# 4         30008.0          0.927597      0.093629  -38.630460
# ..            ...               ...           ...         ...
# 274       30344.0          0.829957      0.121587  -30.426689
# 275       30345.0          0.624115      0.240431  -15.954534
# 276       30346.0          0.823147      0.121508  -25.508836
# 277       30348.0          0.945402      0.075505  -41.596652
# 278       30352.0          0.814803      0.153506  -30.993032
#
#      obj_center_linear  slope_linear  intercept_linear  bias_xmin_linear  \
# 0             0.486946      0.784286          0.118095          0.118095
# 1             0.127093      0.469286          0.440357          0.440357
# 2             0.498304      0.842143          0.080357          0.080357
# 3             0.260263      0.725000          0.311310          0.311310
# 4             0.322409      0.511071          0.335226          0.335226
# ..                 ...           ...               ...               ...
# 274           0.507141      0.566786          0.212560          0.212560
# 275           0.346911      0.929429          0.177571          0.177571
# 276           0.587496      0.786429          0.037976          0.037976
# 277           0.531699      0.480714          0.244405          0.244405
# 278           0.646049      0.516786          0.166131          0.166131
#
#      bias_xmax_linear  flipped_linear  range_linear  bias_linear
# 0            0.097619           False      0.784286     0.547461
# 1            0.090357           False      0.469286     0.829744
# 2            0.077500           False      0.842143     0.509050
# 3            0.000000           False      0.688690     1.000000
# 4            0.153702           False      0.511071     0.685634
# ..                ...             ...           ...          ...
# 274          0.220655           False      0.566786     0.490657
# 275          0.000000           False      0.822429     1.000000
# 276          0.175595           False      0.786429     0.177815
# 277          0.274881           False      0.480714     0.470656
# 278          0.317083           False      0.516786     0.343804
#
# [276 rows x 12 columns]

# %%
cols = list(df_sigmoid.columns)
cols_new = [i + '_sigmoid' for i in cols]
df_sigmoid.rename(columns = dict(zip(cols, cols_new)),inplace=True)
df_sigmoid
# Out:
# /Users/f0053cz/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      subID_sigmoid  r_squared_sigmoid  nrmse_sigmoid  aic_sigmoid  \
# 0          30002.0           0.960575       0.072487   -32.740776
# 1          30004.0           0.802323       0.144740   -23.059462
# 2          30005.0           0.870139       0.124883   -25.125303
# 3          30006.0           0.835463       0.137051   -23.823672
# 4          30008.0           0.917580       0.099961   -28.241705
# ..             ...                ...            ...          ...
# 274        30344.0           0.787582       0.136192   -23.911645
# 275        30345.0           0.800809       0.199203   -18.588009
# 276        30346.0           0.804755       0.127870   -24.794383
# 277        30348.0           0.919410       0.091742   -29.442839
# 278        30352.0           0.885549       0.122916   -25.347517
#
#      center_sigmoid  obj_center_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  \
# 0          0.665858            0.591039       0.142704           0.212395
# 1          0.522624            0.136066       0.224573           0.466189
# 2          0.571110            0.530726       0.203235           0.162070
# 3          0.263991            0.228279       0.167483           0.270824
# 4          0.453739            0.340016       0.189201           0.362350
# ..              ...                 ...            ...                ...
# 274        0.500793            0.517119       0.286997           0.242910
# 275        0.205534            0.205534       0.024152           0.000201
# 276        0.612721            0.612721       0.273530           0.096212
# 277        0.577309            0.551969       0.215143           0.292621
# 278        0.655835            0.676260       0.142287           0.218609
#
#      bias_xmax_sigmoid  flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0         7.127578e-02            False       0.716329      0.748738
# 1         1.007323e-01            False       0.433079      0.822317
# 2         1.211174e-01            False       0.716813      0.572306
# 3         5.014153e-02            False       0.679035      0.843779
# 4         1.985016e-01            False       0.439149      0.646071
# ..                 ...              ...            ...           ...
# 274       2.634025e-01            False       0.493688      0.479763
# 275       5.107026e-15            False       0.999799      1.000000
# 276       1.953123e-01            False       0.708476      0.330030
# 277       2.927095e-01            False       0.414670      0.499924
# 278       2.954028e-01            False       0.485988      0.425300
#
# [275 rows x 12 columns]

# %%
df_both =  df_linear.merge(df_sigmoid, left_on = 'subID_linear', right_on = 'subID_sigmoid')
#pd.concat([df_linear.set_index('subID_linear'),df_sigmoid.set_index('subID_sigmoid')]),axis=1)
print(df_both.shape)
# Out:
# (275, 24)

# %%
print(df_both.shape)
rows = (df_both['range_sigmoid']>0) & (df_both['slope_linear']>0)
df_both.loc[rows,:].shape
# Out:
# (275, 24)
# (274, 24)

# %%
df_both = df_both.loc[rows,:]
df_both.shape
# Out:
# (274, 24)

# %%
df_both.rename(columns={'obj_center_linear':'PSE_linear','obj_center_sigmoid':'PSE_sigmoid'},inplace=True)
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         30002.0          0.893032      0.114049  -29.636972    0.486946
# 1         30004.0          0.798324      0.146050  -31.603146    0.127093
# 2         30005.0          0.893113      0.113140  -28.646434    0.498304
# 3         30006.0          0.779614      0.154497  -24.726653    0.260263
# 4         30008.0          0.927597      0.093629  -38.630460    0.322409
# ..            ...               ...           ...         ...         ...
# 270       30344.0          0.829957      0.121587  -30.426689    0.507141
# 271       30345.0          0.624115      0.240431  -15.954534    0.346911
# 272       30346.0          0.823147      0.121508  -25.508836    0.587496
# 273       30348.0          0.945402      0.075505  -41.596652    0.531699
# 274       30352.0          0.814803      0.153506  -30.993032    0.646049
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.784286          0.118095          0.118095          0.097619
# 1        0.469286          0.440357          0.440357          0.090357
# 2        0.842143          0.080357          0.080357          0.077500
# 3        0.725000          0.311310          0.311310          0.000000
# 4        0.511071          0.335226          0.335226          0.153702
# ..            ...               ...               ...               ...
# 270      0.566786          0.212560          0.212560          0.220655
# 271      0.929429          0.177571          0.177571          0.000000
# 272      0.786429          0.037976          0.037976          0.175595
# 273      0.480714          0.244405          0.244405          0.274881
# 274      0.516786          0.166131          0.166131          0.317083
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.072487   -32.740776        0.665858
# 1             False  ...       0.144740   -23.059462        0.522624
# 2             False  ...       0.124883   -25.125303        0.571110
# 3             False  ...       0.137051   -23.823672        0.263991
# 4             False  ...       0.099961   -28.241705        0.453739
# ..              ...  ...            ...          ...             ...
# 270           False  ...       0.136192   -23.911645        0.500793
# 271           False  ...       0.199203   -18.588009        0.205534
# 272           False  ...       0.127870   -24.794383        0.612721
# 273           False  ...       0.091742   -29.442839        0.577309
# 274           False  ...       0.122916   -25.347517        0.655835
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.591039       0.142704           0.212395       7.127578e-02
# 1       0.136066       0.224573           0.466189       1.007323e-01
# 2       0.530726       0.203235           0.162070       1.211174e-01
# 3       0.228279       0.167483           0.270824       5.014153e-02
# 4       0.340016       0.189201           0.362350       1.985016e-01
# ..           ...            ...                ...                ...
# 270     0.517119       0.286997           0.242910       2.634025e-01
# 271     0.205534       0.024152           0.000201       5.107026e-15
# 272     0.612721       0.273530           0.096212       1.953123e-01
# 273     0.551969       0.215143           0.292621       2.927095e-01
# 274     0.676260       0.142287           0.218609       2.954028e-01
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.716329      0.748738
# 1              False       0.433079      0.822317
# 2              False       0.716813      0.572306
# 3              False       0.679035      0.843779
# 4              False       0.439149      0.646071
# ..               ...            ...           ...
# 270            False       0.493688      0.479763
# 271            False       0.999799      1.000000
# 272            False       0.708476      0.330030
# 273            False       0.414670      0.499924
# 274            False       0.485988      0.425300
#
# [274 rows x 24 columns]

# %%
# rows = (df_both['amplitude_sigmoid']>0) & (df_both['slope_linear']>0)
# df_both = df_both.loc[rows,:]
# print(df_both.shape)
# df_both.head()

# %% [markdown]
# # sanity checks

# %%
def get_p(p):
    if p < .001:
        return "p < .001"
    elif p < .01:
        return f"p={p:.3f}"
    else:
        return f"p={p:.2f}"
        
def explore_correlations(df, param, ax):

    from scipy.stats import pearsonr,spearmanr

    if param == 'slope':
        x = df[param+'_linear']
        y = df['sigma_sigmoid']
    else:
        x = df[param+'_linear']
        y = df[param+'_sigmoid']
    
    rows = (~np.isnan(x)) & (~np.isnan(y)) & (~np.isinf(x)) & (~np.isinf(y))
    x = x[rows]
    y = y[rows]

    sns.scatterplot(x=x, y=y,color='k',alpha=.3,ax=ax)
    r,p = pearsonr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_p={r:.2f} ({get_p(p)})',xy=(0.05,.9),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')


    r,p = spearmanr(x,y)
    if p < .05:
        color = 'k'
        fontweight = 'bold'
    else:
        color = 'k'
        fontweight = 'normal'
    ax.annotate(f'r_s={r:.2f} ({get_p(p)})',xy=(0.05,.8),xycoords='axes fraction', color = color, fontweight = fontweight, ha='left',va='top')

# %%
comparisons = ['bias_xmin','bias_xmax','bias','PSE','range','slope','r_squared']

# %%
df_both
# Out:
#      subID_linear  r_squared_linear  nrmse_linear  aic_linear  PSE_linear  \
# 0         30002.0          0.893032      0.114049  -29.636972    0.486946
# 1         30004.0          0.798324      0.146050  -31.603146    0.127093
# 2         30005.0          0.893113      0.113140  -28.646434    0.498304
# 3         30006.0          0.779614      0.154497  -24.726653    0.260263
# 4         30008.0          0.927597      0.093629  -38.630460    0.322409
# ..            ...               ...           ...         ...         ...
# 270       30344.0          0.829957      0.121587  -30.426689    0.507141
# 271       30345.0          0.624115      0.240431  -15.954534    0.346911
# 272       30346.0          0.823147      0.121508  -25.508836    0.587496
# 273       30348.0          0.945402      0.075505  -41.596652    0.531699
# 274       30352.0          0.814803      0.153506  -30.993032    0.646049
#
#      slope_linear  intercept_linear  bias_xmin_linear  bias_xmax_linear  \
# 0        0.784286          0.118095          0.118095          0.097619
# 1        0.469286          0.440357          0.440357          0.090357
# 2        0.842143          0.080357          0.080357          0.077500
# 3        0.725000          0.311310          0.311310          0.000000
# 4        0.511071          0.335226          0.335226          0.153702
# ..            ...               ...               ...               ...
# 270      0.566786          0.212560          0.212560          0.220655
# 271      0.929429          0.177571          0.177571          0.000000
# 272      0.786429          0.037976          0.037976          0.175595
# 273      0.480714          0.244405          0.244405          0.274881
# 274      0.516786          0.166131          0.166131          0.317083
#
#      flipped_linear  ...  nrmse_sigmoid  aic_sigmoid  center_sigmoid  \
# 0             False  ...       0.072487   -32.740776        0.665858
# 1             False  ...       0.144740   -23.059462        0.522624
# 2             False  ...       0.124883   -25.125303        0.571110
# 3             False  ...       0.137051   -23.823672        0.263991
# 4             False  ...       0.099961   -28.241705        0.453739
# ..              ...  ...            ...          ...             ...
# 270           False  ...       0.136192   -23.911645        0.500793
# 271           False  ...       0.199203   -18.588009        0.205534
# 272           False  ...       0.127870   -24.794383        0.612721
# 273           False  ...       0.091742   -29.442839        0.577309
# 274           False  ...       0.122916   -25.347517        0.655835
#
#      PSE_sigmoid  sigma_sigmoid  bias_xmin_sigmoid  bias_xmax_sigmoid  \
# 0       0.591039       0.142704           0.212395       7.127578e-02
# 1       0.136066       0.224573           0.466189       1.007323e-01
# 2       0.530726       0.203235           0.162070       1.211174e-01
# 3       0.228279       0.167483           0.270824       5.014153e-02
# 4       0.340016       0.189201           0.362350       1.985016e-01
# ..           ...            ...                ...                ...
# 270     0.517119       0.286997           0.242910       2.634025e-01
# 271     0.205534       0.024152           0.000201       5.107026e-15
# 272     0.612721       0.273530           0.096212       1.953123e-01
# 273     0.551969       0.215143           0.292621       2.927095e-01
# 274     0.676260       0.142287           0.218609       2.954028e-01
#
#      flipped_sigmoid  range_sigmoid  bias_sigmoid
# 0              False       0.716329      0.748738
# 1              False       0.433079      0.822317
# 2              False       0.716813      0.572306
# 3              False       0.679035      0.843779
# 4              False       0.439149      0.646071
# ..               ...            ...           ...
# 270            False       0.493688      0.479763
# 271            False       0.999799      1.000000
# 272            False       0.708476      0.330030
# 273            False       0.414670      0.499924
# 274            False       0.485988      0.425300
#
# [274 rows x 24 columns]

# %%
nrows = 3
ncols = 3
fig,axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (10,10))
for i,param in enumerate(comparisons):
    r = int(np.floor(i/ncols))
    c = i%ncols
    ax = axs[r,c]
    explore_correlations(df_both, param, ax)
    ax.set_title(param,fontweight='bold')
    if param == 'slope':
        ax.set_title ('slope vs. inv. sigma',fontweight='bold')

df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

ax = axs[2,1]
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-100,0)

ax = axs[2,2]
ax.axis('off')

plt.suptitle('Linear (X) vs. sigmoid(Y) fits (pf sess1)', fontweight='bold', fontsize=16)
plt.tight_layout()
# plt.savefig('../results/subtlety_playfight_mixed/linear_vs_sigmoid_mixedbatch.png',dpi=300,bbox_inches='tight')

# %%
df_both.to_csv('../data/subtlety_playfight_data/curvefits_pf_linear_sigmoid_params_mixedbatch.csv')

# %%
from scipy import stats

# %%
s=16 # CHANGE FONTSIZE HERE
plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend

# %%
df_melted = df_both.melt(value_vars=['aic_linear', 'aic_sigmoid'], var_name='Model', value_name='AIC')
df_melted = df_melted.reset_index().rename(columns={'index': 'Row'})

fig,ax = plt.subplots(figsize=(4,4),nrows=1,ncols=1)
sns.boxplot(x='Model', y='AIC', data=df_melted,ax=ax, color = 'w')
ax.set_xlabel('')
for i in df_both.index:
    ax.plot(['aic_linear', 'aic_sigmoid'], [df_both.loc[i, 'aic_linear'], df_both.loc[i, 'aic_sigmoid']], marker='o', color='k',alpha = .05)
ax.set_title('AIC',fontweight='bold')
ax.set_ylim(-100,0)
plt.savefig('../results/subtlety_playfight_mixed/AIC_pf_linear_vs_sigmoid.png')

# %%
stats.ttest_rel(df_both['aic_sigmoid'],df_both['aic_linear'])
# Out:
# Ttest_relResult(statistic=6.170426088379956, pvalue=2.4500864378887795e-09)

# %%
df_both['aic_sigmoid'].mean(),df_both['aic_linear'].mean(), df_both['aic_sigmoid'].std(),df_both['aic_linear'].std()
# Out:
# (-28.93879020390323, -32.413394934686934, 6.857437251973682, 7.517342229131587)

# %%
df_both['aic_diff'] = df_both['aic_sigmoid'] - df_both['aic_linear']
# len(np.where(df_both['aic_diff']>0)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<0)[0])
len(np.where(df_both['aic_diff']>5)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-5)[0])
# Out:
# (122, 0, 35)

# %%
len(np.where(df_both['aic_diff']>10)[0]), len(np.where(df_both['aic_diff']==0)[0]), len(np.where(df_both['aic_diff']<-10)[0])
# Out:
# (43, 0, 24)
